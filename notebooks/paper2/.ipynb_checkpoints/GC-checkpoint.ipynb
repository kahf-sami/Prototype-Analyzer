# %%
import sys, os, json, re

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

dirPath = os.path.dirname(os.path.realpath("__file__"))
packagesPath = os.path.join(dirPath, 'packages')
print(packagesPath)

if not packagesPath in sys.path:
    sys.path.append(packagesPath)
    
# IPython extension to reload modules before executing user code.
# autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %reload_ext autoreload
# %autoreload 2
# Out:
# /notebooks/paper2/packages
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import packages.dataset as dataset

datasetPath = os.path.join(dirPath, 'datasets')
dataProcessor = dataset.Brexit(datasetPath)
dataProcessor.loadFilePaths()
# Out:
# Dataset path:
# /notebooks/paper2/datasets/brexit
# Total files 49
# -------------------------------
# Training file count:  39
# Total files in list:  39
# -------------------------------
# Total validation file count 4
# Total files in list:  4
# -------------------------------
# Total test file count 6
# Total files in list:  6
# -------------------------------

# %%
from packages.gc.vocab import Vocab
vocabProcessor = Vocab(dataProcessor)
vocabProcessor.buildVocab()
# Out:
# Total vocab:  76
# Filtered vocab:  8
# Total vocab:  76
# Filtered vocab:  8
# Total vocab:  259
# Filtered vocab:  4
# Total vocab:  259
# Filtered vocab:  4
# Total vocab:  68
# Filtered vocab:  5
# Total vocab:  68
# Filtered vocab:  5
# Total vocab:  138
# Filtered vocab:  8
# Total vocab:  138
# Filtered vocab:  8
# Total vocab:  170
# Filtered vocab:  4
# Total vocab:  170
# Filtered vocab:  4
# Total vocab:  137
# Filtered vocab:  6
# Total vocab:  137
# Filtered vocab:  6
# Total vocab:  194
# Filtered vocab:  5
# Total vocab:  194
# Filtered vocab:  5
# Total vocab:  255
# Filtered vocab:  4
# Total vocab:  255
# Filtered vocab:  4
# Total vocab:  165
# Filtered vocab:  8
# Total vocab:  165
# Filtered vocab:  8
# Total vocab:  114
# Filtered vocab:  5
# Total vocab:  114
# Filtered vocab:  5
# Total vocab:  255
# Filtered vocab:  4
# Total vocab:  255
# Filtered vocab:  4
# Total vocab:  83
# Filtered vocab:  5
# Total vocab:  83
# Filtered vocab:  5
# Total vocab:  78
# Filtered vocab:  4
# Total vocab:  78
# Filtered vocab:  4
# Total vocab:  153
# Filtered vocab:  2
# Total vocab:  153
# Filtered vocab:  2
# Total vocab:  250
# Filtered vocab:  6
# Total vocab:  250
# Filtered vocab:  6
# Total vocab:  67
# Filtered vocab:  4
# Total vocab:  67
# Filtered vocab:  4
# Total vocab:  115
# Filtered vocab:  8
# Total vocab:  115
# Filtered vocab:  8
# Total vocab:  158
# Filtered vocab:  4
# Total vocab:  158
# Filtered vocab:  4
# Total vocab:  91
# Filtered vocab:  3
# Total vocab:  91
# Filtered vocab:  3
# Total vocab:  199
# Filtered vocab:  3
# Total vocab:  199
# Filtered vocab:  3
# Total vocab:  92
# Filtered vocab:  2
# Total vocab:  92
# Filtered vocab:  2
# Total vocab:  85
# Filtered vocab:  7
# Total vocab:  85
# Filtered vocab:  7
# Total vocab:  133
# Filtered vocab:  3
# Total vocab:  133
# Filtered vocab:  3
# Total vocab:  188
# Filtered vocab:  3
# Total vocab:  188
# Filtered vocab:  3
# Total vocab:  87
# Filtered vocab:  7
# Total vocab:  87
# Filtered vocab:  7
# Total vocab:  45
# Filtered vocab:  6
# Total vocab:  45
# Filtered vocab:  6
# Total vocab:  86
# Filtered vocab:  7
# Total vocab:  86
# Filtered vocab:  7
# Total vocab:  192
# Filtered vocab:  3
# Total vocab:  192
# Filtered vocab:  3
# Total vocab:  144
# Filtered vocab:  2
# Total vocab:  144
# Filtered vocab:  2
# Total vocab:  103
# Filtered vocab:  3
# Total vocab:  103
# Filtered vocab:  3
# Total vocab:  116
# Filtered vocab:  3
# Total vocab:  116
# Filtered vocab:  3
# Total vocab:  126
# Filtered vocab:  3
# Total vocab:  126
# Filtered vocab:  3
# Total vocab:  103
# Filtered vocab:  3
# Total vocab:  103
# Filtered vocab:  3
# Total vocab:  100
# Filtered vocab:  8
# Total vocab:  100
# Filtered vocab:  8
# Total vocab:  162
# Filtered vocab:  4
# Total vocab:  162
# Filtered vocab:  4
# Total vocab:  59
# Filtered vocab:  3
# Total vocab:  59
# Filtered vocab:  3
# Total vocab:  218
# Filtered vocab:  4
# Total vocab:  218
# Filtered vocab:  4
# Total vocab:  148
# Filtered vocab:  5
# Total vocab:  148
# Filtered vocab:  5
# Total vocab:  105
# Filtered vocab:  4
# Total vocab:  105
# Filtered vocab:  4
# Total vocab:  1861
# Total sentences:  1251
# Finished processing

# %%
from packages.gc.lda import LDA

ldaProcessor = LDA(dataProcessor)
ldaProcessor.buildWordCoOccurenceVectors()
# Out:
# <1861x1861 sparse matrix of type '<class 'numpy.float64'>'
# 	with 57190 stored elements in Compressed Sparse Row format>

# %%
ldaProcessor.train()
# Out:
# Finished training LDA

# %%
from packages.gc.peripheral import Peripheral
peripheralProcessor = Peripheral(dataProcessor)

wordInfo = peripheralProcessor.getPoints(100)
print(len(wordInfo))
    
from packages.gc.plotter import Plotter
plotProcessor = Plotter(wordInfo)
plotProcessor.displayPlot()
# Out:
# 100

# %%
from packages.gc.linear import Linear
linearProcessor = Linear(dataProcessor)

wordInfo = linearProcessor.getPoints(200)
print(len(wordInfo))
    
linearPlotProcessor = Plotter(wordInfo)
linearPlotProcessor.displayPlot()
# Out:
# 200

# %%
from packages.gc.tsne import TSNE
tsneProcessor = TSNE(dataProcessor)
tsneProcessor.train()
# Out:
# [autoreload of packages.gc.tsne failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py", line 376, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 674, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 781, in get_code
#   File "<frozen importlib._bootstrap_external>", line 741, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/notebooks/paper2/packages/gc/tsne.py", line 64
#     self.learnedEmbeddings =  embeddingFromFile[fileRef]:
#                                                         ^
# SyntaxError: invalid syntax
# ]

# %%
wordInfo = tsneProcessor.getPoints(100)
print(len(wordInfo))
    
linearPlotProcessor = Plotter(wordInfo)
linearPlotProcessor.displayPlot()
