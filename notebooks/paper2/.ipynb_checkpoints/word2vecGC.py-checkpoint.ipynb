# %%
import sys, os, json, re

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

dirPath = os.path.dirname(os.path.realpath("__file__"))
packagesPath = os.path.join(dirPath, 'packages')
print(packagesPath)

if not packagesPath in sys.path:
    sys.path.append(packagesPath)
    
# IPython extension to reload modules before executing user code.
# autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %reload_ext autoreload
# %autoreload 2
# Out:
# /notebooks/paper2/packages
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import packages.dataset as dataset

datasetPath = os.path.join(dirPath, 'datasets')
dataProcessor = dataset.Brexit(datasetPath)
dataProcessor.loadFilePaths()
# Out:
# Dataset path:
# /notebooks/paper2/datasets/brexit
# Total files 49
# -------------------------------
# Training file count:  39
# Total files in list:  39
# -------------------------------
# Total validation file count 4
# Total files in list:  4
# -------------------------------
# Total test file count 6
# Total files in list:  6
# -------------------------------

# %%
from packages.gc.word2vec import Word2Vec
word2vecProcessor = Word2Vec(dataProcessor)
#word2vecProcessor.train()

skipWindow = 2
word2vecProcessor.resetIndex()
word2vecProcessor.setSkipWindow(skipWindow)
word2vecProcessor.setBatchSize(128)

# %%
#print('The skip-gram pairs : target,context')
#for i in range(100):
#    print('(', x_batch[i], word2vecProcessor.id2Word[x_batch[i]],
#          ',', y_batch[i], word2vecProcessor.id2Word[y_batch[i]], ')')

# %%
word2vecProcessor.train()
# Out:
# Batches:  14
# --------------------------
#
# Average loss after epoch  0 :  12.088309151785714
#
# Average loss after epoch  0 :  13.010142112264829
#
# Average loss after epoch  0 :  12.645555412804072
#
# Average loss after epoch  0 :  11.431791163344823
#
# Average loss after epoch  0 :  12.040008398525746
#
# Average loss after epoch  0 :  11.993538982288669
#
# Average loss after epoch  0 :  11.13565779630745
#
# Average loss after epoch  0 :  10.56343783715254
#
# Average loss after epoch  0 :  11.795549078909334
#
# Average loss after epoch  0 :  11.20986949859118
#
# Average loss after epoch  0 :  11.335654130619236
#
# Average loss after epoch  0 :  9.412276599452714
#
# Average loss after epoch  0 :  11.066532635521735
#
# Average loss after epoch  0 :  10.065299206108694
# Similar to news: attack, advertising, Dover, patients, digits,
# Similar to Vince: misuse, McDonnell, development, 09bn, Dartford,
# Similar to people: HQ, pleasure, Brittany, Prime, operations,
# Similar to problems: Kit, effect, Ramsgate, Asian, Tokyo,
# Similar to congestion: Jan, sensitivities, Rzeczpospolita, citizens, Information,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: Norinchukin, Liaison, zone, gun, IFG,
# Similar to membership: Affairs, night, St, Brotons, Copyright,
# --------------------------
#
# Average loss after epoch  1 :  8.570595332554408
#
# Average loss after epoch  1 :  9.129106288053551
#
# Average loss after epoch  1 :  10.153175473560745
#
# Average loss after epoch  1 :  8.839454659418681
#
# Average loss after epoch  1 :  9.936299460884817
#
# Average loss after epoch  1 :  8.117984032187922
#
# Average loss after epoch  1 :  8.583452716863869
#
# Average loss after epoch  1 :  8.456362214499764
#
# Average loss after epoch  1 :  8.790669745406513
#
# Average loss after epoch  1 :  9.966109501904038
#
# Average loss after epoch  1 :  9.21589873430174
#
# Average loss after epoch  1 :  8.47191744063372
#
# Average loss after epoch  1 :  7.803589500851627
#
# Average loss after epoch  1 :  7.85448896302121
# Similar to news: attack, advertising, Dover, patients, digits,
# Similar to Vince: misuse, McDonnell, development, 09bn, Dartford,
# Similar to people: HQ, pleasure, Brittany, Prime, Russian,
# Similar to problems: Kit, effect, Ramsgate, Asian, Tokyo,
# Similar to congestion: Jan, sensitivities, Rzeczpospolita, Information, citizens,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: Norinchukin, gun, zone, Liaison, IFG,
# Similar to membership: Affairs, night, Brotons, St, Copyright,
# --------------------------
#
# Average loss after epoch  2 :  8.45773424421038
#
# Average loss after epoch  2 :  8.720863420136121
#
# Average loss after epoch  2 :  6.881062104472614
#
# Average loss after epoch  2 :  6.590131254009484
#
# Average loss after epoch  2 :  7.054348364544204
#
# Average loss after epoch  2 :  6.919371767772968
#
# Average loss after epoch  2 :  8.036390520556607
#
# Average loss after epoch  2 :  7.360351441688754
#
# Average loss after epoch  2 :  9.129084987185356
#
# Average loss after epoch  2 :  7.84640907693065
#
# Average loss after epoch  2 :  8.008662921650181
#
# Average loss after epoch  2 :  8.042028953806486
#
# Average loss after epoch  2 :  6.722337351680933
#
# Average loss after epoch  2 :  7.584442793360859
# Similar to news: attack, advertising, Dover, patients, Bonnysa,
# Similar to Vince: misuse, McDonnell, development, 09bn, cancelling,
# Similar to people: HQ, pleasure, Brittany, Britain, Prime,
# Similar to problems: Kit, effect, Ramsgate, Asian, Tokyo,
# Similar to congestion: Jan, sensitivities, Information, Rzeczpospolita, citizens,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: Norinchukin, gun, zone, Liaison, IFG,
# Similar to membership: Affairs, night, Brotons, St, Copyright,
# --------------------------
#
# Average loss after epoch  3 :  6.89533942086356
#
# Average loss after epoch  3 :  7.544432464911013
#
# Average loss after epoch  3 :  6.291173036870039
#
# Average loss after epoch  3 :  6.164974557216442
#
# Average loss after epoch  3 :  6.965905077887112
#
# Average loss after epoch  3 :  7.834624214373354
#
# Average loss after epoch  3 :  5.994220115131021
#
# Average loss after epoch  3 :  6.637245406521635
#
# Average loss after epoch  3 :  5.991082888970295
#
# Average loss after epoch  3 :  5.8684415634281235
#
# Average loss after epoch  3 :  6.9041101578857695
#
# Average loss after epoch  3 :  6.129995905529787
#
# Average loss after epoch  3 :  5.737832654315185
#
# Average loss after epoch  3 :  7.607732065291486
# Similar to news: attack, advertising, Dover, patients, climate,
# Similar to Vince: misuse, McDonnell, development, 09bn, cancelling,
# Similar to people: HQ, pleasure, Brittany, Britain, response,
# Similar to problems: Kit, effect, Ramsgate, Asian, Tokyo,
# Similar to congestion: Jan, sensitivities, Information, Rzeczpospolita, Kelly,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: Norinchukin, gun, zone, Liaison, costs,
# Similar to membership: Affairs, night, Brotons, St, Copyright,
# --------------------------
#
# Average loss after epoch  4 :  6.214901515415737
#
# Average loss after epoch  4 :  6.798073671302016
#
# Average loss after epoch  4 :  6.771149287765993
#
# Average loss after epoch  4 :  7.507376032936131
#
# Average loss after epoch  4 :  4.855714956768039
#
# Average loss after epoch  4 :  4.770998421158654
#
# Average loss after epoch  4 :  6.976504900827739
#
# Average loss after epoch  4 :  6.074312727988811
#
# Average loss after epoch  4 :  6.578585661688096
#
# Average loss after epoch  4 :  6.625233448491114
#
# Average loss after epoch  4 :  6.549549973929611
#
# Average loss after epoch  4 :  7.70865283104101
#
# Average loss after epoch  4 :  5.48449464191448
#
# Average loss after epoch  4 :  6.527220416316994
# Similar to news: attack, advertising, Dover, patients, climate,
# Similar to Vince: misuse, McDonnell, development, 09bn, cancelling,
# Similar to people: HQ, pleasure, Britain, Brittany, response,
# Similar to problems: Kit, effect, Ramsgate, Asian, Tokyo,
# Similar to congestion: Jan, sensitivities, Information, Rzeczpospolita, Kelly,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: gun, Norinchukin, week, costs, zone,
# Similar to membership: Affairs, night, Brotons, St, Copyright,
# --------------------------
#
# Average loss after epoch  5 :  5.949461800711496
#
# Average loss after epoch  5 :  5.3313979324029415
#
# Average loss after epoch  5 :  5.380595065414384
#
# Average loss after epoch  5 :  4.550743569735933
#
# Average loss after epoch  5 :  5.288209131062332
#
# Average loss after epoch  5 :  3.6006446005829957
#
# Average loss after epoch  5 :  3.265776328543317
#
# Average loss after epoch  5 :  4.067186538115817
#
# Average loss after epoch  5 :  4.420275156252134
#
# Average loss after epoch  5 :  5.847858050362875
#
# Average loss after epoch  5 :  5.779710197654268
#
# Average loss after epoch  5 :  4.91406913486314
#
# Average loss after epoch  5 :  4.298038956584811
#
# Average loss after epoch  5 :  5.971779175958624
# Similar to news: attack, advertising, Dover, patients, climate,
# Similar to Vince: misuse, McDonnell, development, 09bn, cancelling,
# Similar to people: HQ, pleasure, Britain, response, Brittany,
# Similar to problems: Kit, effect, Ramsgate, Asian, Tokyo,
# Similar to congestion: Jan, Information, sensitivities, Rzeczpospolita, Kelly,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: week, gun, costs, Norinchukin, zone,
# Similar to membership: Affairs, night, Brotons, St, Copyright,
# --------------------------
#
# Average loss after epoch  6 :  4.062905992780413
#
# Average loss after epoch  6 :  5.761149931927116
#
# Average loss after epoch  6 :  6.276062798569571
#
# Average loss after epoch  6 :  4.145385253434378
#
# Average loss after epoch  6 :  3.655187026943834
#
# Average loss after epoch  6 :  4.542738055635497
#
# Average loss after epoch  6 :  5.056220878834455
#
# Average loss after epoch  6 :  4.0806110834560885
#
# Average loss after epoch  6 :  3.9611657583676783
#
# Average loss after epoch  6 :  5.174752327118339
#
# Average loss after epoch  6 :  5.744157593329324
#
# Average loss after epoch  6 :  5.161802141501759
#
# Average loss after epoch  6 :  4.52177360005565
#
# Average loss after epoch  6 :  4.500696405305314
# Similar to news: attack, Dover, advertising, patients, climate,
# Similar to Vince: misuse, McDonnell, development, 09bn, cancelling,
# Similar to people: HQ, pleasure, Britain, response, trade,
# Similar to problems: Kit, effect, Ramsgate, Asian, Tokyo,
# Similar to congestion: Jan, Information, Rzeczpospolita, Kelly, sensitivities,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: week, costs, gun, EU, benefits,
# Similar to membership: Affairs, night, Brotons, St, Copyright,
# --------------------------
#
# Average loss after epoch  7 :  2.903489794049944
#
# Average loss after epoch  7 :  3.5344293944689693
#
# Average loss after epoch  7 :  3.4634768511046476
#
# Average loss after epoch  7 :  3.5155551571589814
#
# Average loss after epoch  7 :  5.003827147107338
#
# Average loss after epoch  7 :  4.667038308184844
#
# Average loss after epoch  7 :  3.694093183860999
#
# Average loss after epoch  7 :  4.010102234864932
#
# Average loss after epoch  7 :  3.9608956037947607
#
# Average loss after epoch  7 :  4.283668250264079
#
# Average loss after epoch  7 :  4.035791650444365
#
# Average loss after epoch  7 :  3.1661710920099773
#
# Average loss after epoch  7 :  3.136363643848927
# Average loss after epoch  7 :  3.8958557431502023
# Similar to news: Dover, attack, advertising, patients, climate,
# Similar to Vince: misuse, McDonnell, development, 09bn, cancelling,
# Similar to people: HQ, Britain, pleasure, response, trade,
# Similar to problems: Kit, effect, Ramsgate, Asian, Tokyo,
# Similar to congestion: Jan, Information, Rzeczpospolita, Kelly, issue,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: week, costs, EU, benefits, gun,
# Similar to membership: Affairs, night, St, Brotons, worries,
# --------------------------
#
# Average loss after epoch  8 :  2.885742732456752
#
# Average loss after epoch  8 :  2.785154654055226
#
# Average loss after epoch  8 :  1.9163954820994387
#
# Average loss after epoch  8 :  3.660889919079229
#
# Average loss after epoch  8 :  4.355317886065648
#
# Average loss after epoch  8 :  3.4720896181174123
#
# Average loss after epoch  8 :  3.0184681649485374
#
# Average loss after epoch  8 :  2.2089113013764163
#
# Average loss after epoch  8 :  1.8919050609555979
#
# Average loss after epoch  8 :  2.182476196370573
#
# Average loss after epoch  8 :  3.5669029889846167
#
# Average loss after epoch  8 :  2.0339677584905305
#
# Average loss after epoch  8 :  3.271538174242767
#
# Average loss after epoch  8 :  3.6927615855485905
# Similar to news: Dover, attack, advertising, climate, patients,
# Similar to Vince: misuse, development, McDonnell, 09bn, cancelling,
# Similar to people: HQ, Britain, pleasure, response, trade,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Jan, Information, Rzeczpospolita, Kelly, issue,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: week, EU, costs, trade, benefits,
# Similar to membership: Affairs, night, St, Brotons, worries,
# --------------------------
#
# Average loss after epoch  9 :  3.0762386322021484
#
# Average loss after epoch  9 :  3.4524905341012135
#
# Average loss after epoch  9 :  3.4367849291587365
#
# Average loss after epoch  9 :  1.6258938785197088
#
# Average loss after epoch  9 :  2.642062684438071
#
# Average loss after epoch  9 :  1.9359285846027192
#
# Average loss after epoch  9 :  2.712145413775334
#
# Average loss after epoch  9 :  4.141591929666988
#
# Average loss after epoch  9 :  2.4271974494963025
#
# Average loss after epoch  9 :  5.0612295009615105
#
# Average loss after epoch  9 :  3.084724139159081
#
# Average loss after epoch  9 :  4.363458340436586
#
# Average loss after epoch  9 :  3.9992715081338632
#
# Average loss after epoch  9 :  2.366640916614054
# Similar to news: Dover, attack, advertising, climate, patients,
# Similar to Vince: misuse, development, McDonnell, 09bn, cancelling,
# Similar to people: HQ, Britain, response, pleasure, trade,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Jan, Information, Rzeczpospolita, issue, Kelly,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: week, EU, trade, benefits, costs,
# Similar to membership: Affairs, night, St, Brotons, worries,
# --------------------------
#
# Average loss after epoch  10 :  1.6416256768362862
#
# Average loss after epoch  10 :  3.339240297979238
#
# Average loss after epoch  10 :  3.01112850970499
#
# Average loss after epoch  10 :  3.638121815285847
#
# Average loss after epoch  10 :  2.6999903556677394
#
# Average loss after epoch  10 :  2.6984828599646877
#
# Average loss after epoch  10 :  2.7732876616457753
#
# Average loss after epoch  10 :  2.146751600204051
#
# Average loss after epoch  10 :  2.7521634923346086
#
# Average loss after epoch  10 :  2.8734945968994587
#
# Average loss after epoch  10 :  3.3147592183820485
#
# Average loss after epoch  10 :  3.9094285258003083
#
# Average loss after epoch  10 :  2.7345987678166517
#
# Average loss after epoch  10 :  3.362231842964861
# Similar to news: Dover, attack, advertising, climate, patients,
# Similar to Vince: misuse, 09bn, development, McDonnell, Arron,
# Similar to people: HQ, Britain, response, trade, pleasure,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Jan, Information, Rzeczpospolita, issue, Kelly,
# Similar to Concerns: vote, comedy, doctors, counterparts, Article,
# Similar to supply: week, EU, trade, benefits, costs,
# Similar to membership: Affairs, night, St, Brotons, worries,
# --------------------------
#
# Average loss after epoch  11 :  2.3640959603445872
#
# Average loss after epoch  11 :  2.2783391329706935
#
# Average loss after epoch  11 :  2.633036731630998
#
# Average loss after epoch  11 :  2.187663154868174
#
# Average loss after epoch  11 :  1.7737022863305671
#
# Average loss after epoch  11 :  2.1615142582887485
#
# Average loss after epoch  11 :  2.0346829533508424
#
# Average loss after epoch  11 :  2.4051584320404062
#
# Average loss after epoch  11 :  1.7900867058914185
#
# Average loss after epoch  11 :  2.976626938255637
#
# Average loss after epoch  11 :  2.211595914596036
#
# Average loss after epoch  11 :  2.4712970187148677
#
# Average loss after epoch  11 :  2.5552740602967368
#
# Average loss after epoch  11 :  2.045101373743991
# Similar to news: Dover, attack, climate, advertising, patients,
# Similar to Vince: misuse, 09bn, development, McDonnell, Arron,
# Similar to people: HQ, Britain, response, trade, Secretary,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Jan, Rzeczpospolita, issue, Kelly,
# Similar to Concerns: vote, comedy, doctors, Article, counterparts,
# Similar to supply: week, EU, trade, benefits, Agreement,
# Similar to membership: Affairs, night, St, Brotons, worries,
# --------------------------
#
# Average loss after epoch  12 :  2.26953615461077
#
# Average loss after epoch  12 :  2.9604119670634366
#
# Average loss after epoch  12 :  2.3167702088203095
#
# Average loss after epoch  12 :  1.8441661860931917
#
# Average loss after epoch  12 :  1.6099003657442401
#
# Average loss after epoch  12 :  1.32862124347078
#
# Average loss after epoch  12 :  1.2569021735186998
#
# Average loss after epoch  12 :  1.904724492583925
#
# Average loss after epoch  12 :  1.931677436115788
#
# Average loss after epoch  12 :  3.1390963008916413
#
# Average loss after epoch  12 :  2.393290726988912
#
# Average loss after epoch  12 :  1.9502770026985663
#
# Average loss after epoch  12 :  2.7134817435660805
#
# Average loss after epoch  12 :  2.615136816347772
# Similar to news: Dover, attack, climate, advertising, patients,
# Similar to Vince: misuse, 09bn, development, McDonnell, Arron,
# Similar to people: HQ, Britain, response, trade, Secretary,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Jan, Rzeczpospolita, issue, Kelly,
# Similar to Concerns: vote, comedy, doctors, Article, counterparts,
# Similar to supply: week, benefits, trade, EU, Agreement,
# Similar to membership: Affairs, night, St, Brotons, worries,
# --------------------------
#
# Average loss after epoch  13 :  2.414025442940848
#
# Average loss after epoch  13 :  2.312163430817273
#
# Average loss after epoch  13 :  2.0822691973027263
#
# Average loss after epoch  13 :  1.3167295119306635
#
# Average loss after epoch  13 :  2.172410894441755
#
# Average loss after epoch  13 :  1.3605465157406778
#
# Average loss after epoch  13 :  1.9509806240142615
#
# Average loss after epoch  13 :  2.9741423101974473
#
# Average loss after epoch  13 :  2.0535473310646055
#
# Average loss after epoch  13 :  1.8709763422161103
#
# Average loss after epoch  13 :  2.760957233498137
#
# Average loss after epoch  13 :  3.0355217451417476
#
# Average loss after epoch  13 :  2.439170786274076
#
# Average loss after epoch  13 :  1.6303378477360948
# Similar to news: Dover, attack, climate, advertising, patients,
# Similar to Vince: misuse, 09bn, development, McDonnell, Arron,
# Similar to people: Britain, HQ, response, trade, Secretary,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Jan, Rzeczpospolita, issue, Kelly,
# Similar to Concerns: vote, comedy, doctors, Article, counterparts,
# Similar to supply: week, benefits, Border, Agreement, Andrew,
# Similar to membership: Affairs, night, St, Brotons, worries,
# --------------------------
#
# Average loss after epoch  14 :  1.3608085087367467
#
# Average loss after epoch  14 :  0.9353434115040059
#
# Average loss after epoch  14 :  1.2626907248538717
#
# Average loss after epoch  14 :  1.7986152641776203
#
# Average loss after epoch  14 :  1.7595521926369198
#
# Average loss after epoch  14 :  1.5934575080835105
#
# Average loss after epoch  14 :  1.9066846915651168
# Average loss after epoch  14 :  2.4068558425319253
#
# Average loss after epoch  14 :  1.266534278865457
#
# Average loss after epoch  14 :  1.3078418083187937
#
# Average loss after epoch  14 :  1.6323872656140797
#
# Average loss after epoch  14 :  1.4213731022854224
#
# Average loss after epoch  14 :  1.6128693800042042
#
# Average loss after epoch  14 :  1.5185853496965198
# Similar to news: Dover, attack, climate, advertising, patients,
# Similar to Vince: misuse, 09bn, development, McDonnell, Arron,
# Similar to people: Britain, HQ, response, Secretary, trade,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Jan, Rzeczpospolita, issue, Kelly,
# Similar to Concerns: vote, comedy, doctors, Article, counterparts,
# Similar to supply: week, benefits, Agreement, Border, Andrew,
# Similar to membership: Affairs, night, St, worries, Brotons,
# --------------------------
#
# Average loss after epoch  15 :  1.4172683443341936
#
# Average loss after epoch  15 :  1.4336783253416723
#
# Average loss after epoch  15 :  1.4131427958129794
#
# Average loss after epoch  15 :  1.9464647851850232
#
# Average loss after epoch  15 :  1.8808196107721444
#
# Average loss after epoch  15 :  0.9086985114087386
#
# Average loss after epoch  15 :  1.158864801290984
#
# Average loss after epoch  15 :  1.5361663149342193
#
# Average loss after epoch  15 :  0.9894809130156696
#
# Average loss after epoch  15 :  1.4235632717845317
#
# Average loss after epoch  15 :  1.699751873103192
#
# Average loss after epoch  15 :  1.0367019530767068
#
# Average loss after epoch  15 :  0.6667402667419815
#
# Average loss after epoch  15 :  0.9324331175898989
# Similar to news: Dover, attack, climate, advertising, Guernsey,
# Similar to Vince: misuse, 09bn, development, McDonnell, Arron,
# Similar to people: Britain, HQ, response, Secretary, trade,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, Jan, issue, Kelly,
# Similar to Concerns: vote, comedy, doctors, Article, counterparts,
# Similar to supply: week, benefits, Andrew, Agreement, Border,
# Similar to membership: Affairs, night, St, worries, Brotons,
# --------------------------
#
# Average loss after epoch  16 :  2.138911655970982
#
# Average loss after epoch  16 :  2.114227937192333
#
# Average loss after epoch  16 :  0.8625682199661655
#
# Average loss after epoch  16 :  2.1937242462852504
#
# Average loss after epoch  16 :  2.35239891292523
#
# Average loss after epoch  16 :  1.1325097794205452
#
# Average loss after epoch  16 :  1.2678025500751002
#
# Average loss after epoch  16 :  1.756323768530406
#
# Average loss after epoch  16 :  0.6876769033098588
#
# Average loss after epoch  16 :  1.1806204316660363
#
# Average loss after epoch  16 :  2.0145371470965414
#
# Average loss after epoch  16 :  1.6760534084561145
#
# Average loss after epoch  16 :  1.9250550528134807
#
# Average loss after epoch  16 :  1.9055485403237307
# Similar to news: Dover, attack, climate, advertising, Guernsey,
# Similar to Vince: misuse, 09bn, development, McDonnell, Arron,
# Similar to people: Britain, HQ, response, Secretary, trade,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, Jan, issue, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, counterparts,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, night, St, worries, time,
# --------------------------
#
# Average loss after epoch  17 :  1.4536304473876953
#
# Average loss after epoch  17 :  1.7181743894304549
#
# Average loss after epoch  17 :  1.3826351457712602
#
# Average loss after epoch  17 :  1.1558734369695014
#
# Average loss after epoch  17 :  1.0528740300480797
#
# Average loss after epoch  17 :  1.4234124891370838
#
# Average loss after epoch  17 :  2.6300574830061647
#
# Average loss after epoch  17 :  1.0287822420461297
#
# Average loss after epoch  17 :  0.5868800277870562
#
# Average loss after epoch  17 :  0.7702279984621894
#
# Average loss after epoch  17 :  0.9799528526384823
#
# Average loss after epoch  17 :  1.875352794266309
#
# Average loss after epoch  17 :  0.8040724435261719
#
# Average loss after epoch  17 :  1.0560738063909598
# Similar to news: Dover, attack, climate, advertising, Guernsey,
# Similar to Vince: misuse, 09bn, development, opposition, Arron,
# Similar to people: Britain, HQ, response, Secretary, trade,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, issue, Jan, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, counterparts,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  18 :  1.0728401456560408
#
# Average loss after epoch  18 :  1.1134560059527963
#
# Average loss after epoch  18 :  1.555132133272577
#
# Average loss after epoch  18 :  1.582381128023585
#
# Average loss after epoch  18 :  1.0266957196983921
#
# Average loss after epoch  18 :  0.8556417390944931
#
# Average loss after epoch  18 :  0.7141294065347907
#
# Average loss after epoch  18 :  1.5063012638491649
#
# Average loss after epoch  18 :  0.7766985453225478
#
# Average loss after epoch  18 :  1.1289469483144035
#
# Average loss after epoch  18 :  1.568537213139924
#
# Average loss after epoch  18 :  1.45197313014476
#
# Average loss after epoch  18 :  1.2777372208264672
#
# Average loss after epoch  18 :  1.1099552143686384
# Similar to news: Dover, attack, climate, Guernsey, advertising,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, Secretary, caption,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Jan, Media,
# Similar to Concerns: vote, comedy, Article, doctors, counterparts,
# Similar to supply: week, benefits, Andrew, Agreement, Border,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  19 :  0.6459727968488421
#
# Average loss after epoch  19 :  0.694795374967614
#
# Average loss after epoch  19 :  0.5001787291323826
#
# Average loss after epoch  19 :  0.8922964103616113
#
# Average loss after epoch  19 :  1.269594778387297
#
# Average loss after epoch  19 :  1.1752567709747204
#
# Average loss after epoch  19 :  0.8133832416453762
#
# Average loss after epoch  19 :  0.7285445176527529
#
# Average loss after epoch  19 :  0.9763564584011523
#
# Average loss after epoch  19 :  1.4611794573732408
#
# Average loss after epoch  19 :  1.5175958163870813
#
# Average loss after epoch  19 :  0.6987283264408043
#
# Average loss after epoch  19 :  0.9351261516043794
#
# Average loss after epoch  19 :  0.9881957489793446
# Similar to news: Dover, attack, climate, Guernsey, advertising,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, Secretary, caption,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Media, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, counterparts,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  20 :  0.5211502483912877
#
# Average loss after epoch  20 :  0.5355380359961062
#
# Average loss after epoch  20 :  1.0000865344750987
#
# Average loss after epoch  20 :  0.514052373203125
#
# Average loss after epoch  20 :  1.4908689077434432
#
# Average loss after epoch  20 :  1.3243008583481646
#
# Average loss after epoch  20 :  1.0026138235394126
#
# Average loss after epoch  20 :  1.0995067727655454
#
# Average loss after epoch  20 :  1.002634621603789
#
# Average loss after epoch  20 :  0.5877292225008566
#
# Average loss after epoch  20 :  0.9829567335137679
#
# Average loss after epoch  20 :  1.546071109758168
#
# Average loss after epoch  20 :  1.7122073214385019
#
# Average loss after epoch  20 :  0.901935407385465
# Similar to news: Dover, attack, climate, Guernsey, advertising,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, Secretary, caption,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Media, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, Farry,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  21 :  0.6251818111964634
#
# Average loss after epoch  21 :  0.8467879052064857
#
# Average loss after epoch  21 :  0.8376633422367775
#
# Average loss after epoch  21 :  0.5594548277684124
#
# Average loss after epoch  21 :  0.9306957997922959
#
# Average loss after epoch  21 :  0.8476325633841247
#
# Average loss after epoch  21 :  0.5091484385070169
#
# Average loss after epoch  21 :  0.5801238899950255
#
# Average loss after epoch  21 :  0.592320918224568
#
# Average loss after epoch  21 :  1.0949939659083396
#
# Average loss after epoch  21 :  1.6059701369691783
#
# Average loss after epoch  21 :  0.7689956080806318
#
# Average loss after epoch  21 :  1.2884653867134883
#
# Average loss after epoch  21 :  0.5891555637181475
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, Secretary, caption,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Media, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, Farry,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  22 :  1.0903493336268835
#
# Average loss after epoch  22 :  0.7978459864246602
#
# Average loss after epoch  22 :  0.6331655061627268
#
# Average loss after epoch  22 :  0.8381826641757206
#
# Average loss after epoch  22 :  0.7923971057122585
#
# Average loss after epoch  22 :  0.4431282171194443
#
# Average loss after epoch  22 :  0.3698243150298417
#
# Average loss after epoch  22 :  0.637289926049146
#
# Average loss after epoch  22 :  0.38718836113363736
#
# Average loss after epoch  22 :  0.5279926860648608
#
# Average loss after epoch  22 :  1.4700413062765356
#
# Average loss after epoch  22 :  0.601756506836089
#
# Average loss after epoch  22 :  1.039238073547374
#
# Average loss after epoch  22 :  0.5268398763253356
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, Secretary, operations,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Media, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, Farry,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  23 :  0.9387235641479492
# Average loss after epoch  23 :  0.5098474366324288
#
# Average loss after epoch  23 :  0.7564624912884771
#
# Average loss after epoch  23 :  1.0076642999148577
#
# Average loss after epoch  23 :  0.7649665288208227
#
# Average loss after epoch  23 :  0.5284516500013094
#
# Average loss after epoch  23 :  0.9875823237113799
#
# Average loss after epoch  23 :  0.6926068662008547
#
# Average loss after epoch  23 :  0.7669617065248099
#
# Average loss after epoch  23 :  0.8144242176587895
#
# Average loss after epoch  23 :  1.245409808053683
#
# Average loss after epoch  23 :  0.6742706867551599
#
# Average loss after epoch  23 :  0.4140523883025972
#
# Average loss after epoch  23 :  0.7894850728931961
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, Secretary, operations,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Media, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, Farry,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  24 :  0.4942710740225656
#
# Average loss after epoch  24 :  0.8132704180114123
#
# Average loss after epoch  24 :  0.517374811297603
#
# Average loss after epoch  24 :  0.775404304104614
#
# Average loss after epoch  24 :  1.0654997378472464
#
# Average loss after epoch  24 :  0.6066814458787724
#
# Average loss after epoch  24 :  0.3719595230507019
#
# Average loss after epoch  24 :  0.5098456198040017
#
# Average loss after epoch  24 :  0.7986383356797083
#
# Average loss after epoch  24 :  0.8097993299943165
#
# Average loss after epoch  24 :  0.6673522092443276
#
# Average loss after epoch  24 :  0.4429699019132737
#
# Average loss after epoch  24 :  0.49398811257693515
#
# Average loss after epoch  24 :  0.3792929362660457
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, Secretary, operations,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Media, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, Farry,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, time, worries,
# --------------------------
#
# Average loss after epoch  25 :  0.9091502598353794
#
# Average loss after epoch  25 :  0.6503432916135204
#
# Average loss after epoch  25 :  1.221021541006016
#
# Average loss after epoch  25 :  0.5639041412477441
#
# Average loss after epoch  25 :  0.3982140233729904
#
# Average loss after epoch  25 :  0.3332944371204619
#
# Average loss after epoch  25 :  0.356682065398218
#
# Average loss after epoch  25 :  0.48750650905929305
#
# Average loss after epoch  25 :  0.9531238164386311
#
# Average loss after epoch  25 :  0.43708227422891033
#
# Average loss after epoch  25 :  0.8298924979333778
#
# Average loss after epoch  25 :  0.5044674094004624
#
# Average loss after epoch  25 :  0.3451636463083198
#
# Average loss after epoch  25 :  0.39943751713830355
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, Secretary, operations,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Media, Kelly,
# Similar to Concerns: vote, comedy, Article, doctors, Farry,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  26 :  1.1561573573521204
#
# Average loss after epoch  26 :  0.5026234461336719
#
# Average loss after epoch  26 :  0.5999537115541909
#
# Average loss after epoch  26 :  0.3705510114292858
#
# Average loss after epoch  26 :  0.4174222195053424
#
# Average loss after epoch  26 :  0.39710361080442386
#
# Average loss after epoch  26 :  1.1004935207232651
#
# Average loss after epoch  26 :  1.127658169200483
#
# Average loss after epoch  26 :  0.4257799415879635
#
# Average loss after epoch  26 :  0.2998173494359793
#
# Average loss after epoch  26 :  0.4563819528989916
#
# Average loss after epoch  26 :  1.2078291458840378
#
# Average loss after epoch  26 :  0.3735342812180179
#
# Average loss after epoch  26 :  0.39025756852711707
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Secretary,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, doctors, Farry,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, night, worries, time,
# --------------------------
#
# Average loss after epoch  27 :  0.8872684751238141
#
# Average loss after epoch  27 :  0.5850243179165587
#
# Average loss after epoch  27 :  0.4878539670660614
#
# Average loss after epoch  27 :  0.5604375744799384
#
# Average loss after epoch  27 :  0.3622004910944446
#
# Average loss after epoch  27 :  0.44326647636889377
#
# Average loss after epoch  27 :  0.7905635553581367
#
# Average loss after epoch  27 :  0.5172904539532807
#
# Average loss after epoch  27 :  0.3543289630783977
#
# Average loss after epoch  27 :  0.4042405296590597
#
# Average loss after epoch  27 :  0.30078815852763163
#
# Average loss after epoch  27 :  0.31279899352729457
#
# Average loss after epoch  27 :  0.33397681491285575
#
# Average loss after epoch  27 :  0.6679874878388856
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Secretary,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, doctors,
# Similar to supply: week, benefits, Andrew, Border, Agreement,
# Similar to membership: Affairs, St, worries, time, night,
# --------------------------
#
# Average loss after epoch  28 :  0.7457584653581891
#
# Average loss after epoch  28 :  0.4532329987506477
#
# Average loss after epoch  28 :  0.8614754162446403
#
# Average loss after epoch  28 :  0.8311301943958923
#
# Average loss after epoch  28 :  1.075405745827734
#
# Average loss after epoch  28 :  0.4744725673768903
#
# Average loss after epoch  28 :  0.3038779188435275
#
# Average loss after epoch  28 :  0.45376437681942466
#
# Average loss after epoch  28 :  0.6089589551644874
#
# Average loss after epoch  28 :  0.409846935638057
#
# Average loss after epoch  28 :  0.38406383380778253
#
# Average loss after epoch  28 :  0.7513411466461475
#
# Average loss after epoch  28 :  0.3347605496941724
#
# Average loss after epoch  28 :  0.6684833171133393
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, doctors,
# Similar to supply: week, benefits, Andrew, Border, costs,
# Similar to membership: Affairs, St, worries, time, night,
# --------------------------
#
# Average loss after epoch  29 :  0.8381271362304688
#
# Average loss after epoch  29 :  0.34024252210344585
#
# Average loss after epoch  29 :  0.3596738163305789
#
# Average loss after epoch  29 :  0.3449376195929836
#
# Average loss after epoch  29 :  0.34406473360077533
#
# Average loss after epoch  29 :  0.4550699521541709
#
# Average loss after epoch  29 :  0.5354100929089963
#
# Average loss after epoch  29 :  0.4429603081827262
#
# Average loss after epoch  29 :  0.2863962853372444
#
# Average loss after epoch  29 :  0.2389920964441154
#
# Average loss after epoch  29 :  0.38229849519191367
#
# Average loss after epoch  29 :  0.6841643896712136
#
# Average loss after epoch  29 :  0.4407790973570607
#
# Average loss after epoch  29 :  0.3131866545534323
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, doctors,
# Similar to supply: week, benefits, Andrew, costs, Agreement,
# Similar to membership: Affairs, St, worries, time, night,
# --------------------------
#
# Average loss after epoch  30 :  0.3910024506705148
#
# Average loss after epoch  30 :  0.324281848206812
#
# Average loss after epoch  30 :  0.39266260441816236
#
# Average loss after epoch  30 :  0.31259704202177724
#
# Average loss after epoch  30 :  0.3166370906785575
#
# Average loss after epoch  30 :  0.2853902955733271
#
# Average loss after epoch  30 :  0.2982165074056283
#
# Average loss after epoch  30 :  0.3985931309611024
#
# Average loss after epoch  30 :  0.32367223950050006
#
# Average loss after epoch  30 :  0.32143418735820745
#
# Average loss after epoch  30 :  0.703798442189579
#
# Average loss after epoch  30 :  0.30218554601106506
#
# Average loss after epoch  30 :  0.7480078091685499
#
# Average loss after epoch  30 :  0.4382036778931428
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, doctors,
# Similar to supply: week, benefits, Andrew, costs, Border,
# Similar to membership: Affairs, St, worries, time, start,
# --------------------------
#
# Average loss after epoch  31 :  0.5693375723702567
#
# Average loss after epoch  31 :  0.3245113382534105
#
# Average loss after epoch  31 :  0.7384991510268898
#
# Average loss after epoch  31 :  0.40414622754963275
#
# Average loss after epoch  31 :  0.3402518568515153
#
# Average loss after epoch  31 :  0.35103473874840974
#
# Average loss after epoch  31 :  0.35777654662935066
#
# Average loss after epoch  31 :  0.3666689668490831
#
# Average loss after epoch  31 :  0.2317762224049394
#
# Average loss after epoch  31 :  0.538434879043067
#
# Average loss after epoch  31 :  0.5106038973486399
#
# Average loss after epoch  31 :  0.8199127055758236
#
# Average loss after epoch  31 :  0.3632818484416604
#
# Average loss after epoch  31 :  0.25748550057489955
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: week, benefits, Andrew, costs, Border,
# Similar to membership: Affairs, St, worries, time, start,
# --------------------------
#
# Average loss after epoch  32 :  0.7455502237592425
#
# Average loss after epoch  32 :  0.40130302370811
#
# Average loss after epoch  32 :  0.2756180572092707
#
# Average loss after epoch  32 :  0.36328857149098726
#
# Average loss after epoch  32 :  0.4259806140586126
#
# Average loss after epoch  32 :  0.6236515759309444
#
# Average loss after epoch  32 :  0.6567551800103437
#
# Average loss after epoch  32 :  0.3291745676064169
#
# Average loss after epoch  32 :  0.22844689583113986
#
# Average loss after epoch  32 :  0.25119118569530985
#
# Average loss after epoch  32 :  0.2593135866936033
#
# Average loss after epoch  32 :  0.7453621457972411
#
# Average loss after epoch  32 :  0.31999443990104454
#
# Average loss after epoch  32 :  0.6152841356695501
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: week, benefits, Andrew, costs, Border,
# Similar to membership: Affairs, St, worries, time, start,
# --------------------------
#
# Average loss after epoch  33 :  0.32114475114004953
#
# Average loss after epoch  33 :  0.3762805583525677
#
# Average loss after epoch  33 :  0.27973539575543416
#
# Average loss after epoch  33 :  0.270444142637229
#
# Average loss after epoch  33 :  0.5325351944862076
#
# Average loss after epoch  33 :  0.3713870133054985
#
# Average loss after epoch  33 :  0.4362627784772482
#
# Average loss after epoch  33 :  0.2896341037208393
#
# Average loss after epoch  33 :  0.8820138910799832
#
# Average loss after epoch  33 :  0.2634298868079243
#
# Average loss after epoch  33 :  0.2636736465855671
#
# Average loss after epoch  33 :  0.2514392892048773
#
# Average loss after epoch  33 :  0.6088915691455632
#
# Average loss after epoch  33 :  0.49712535899083127
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: week, benefits, Andrew, costs, Border,
# Similar to membership: Affairs, St, worries, time, start,
# --------------------------
#
# Average loss after epoch  34 :  0.3200141361781529
#
# Average loss after epoch  34 :  0.33663682548367246
#
# Average loss after epoch  34 :  0.3654872550908748
#
# Average loss after epoch  34 :  0.29473588561972
#
# Average loss after epoch  34 :  0.6637406332833142
#
# Average loss after epoch  34 :  0.503695930636657
#
# Average loss after epoch  34 :  0.28119642149811225
#
# Average loss after epoch  34 :  0.6678621986163551
#
# Average loss after epoch  34 :  0.2634712473172013
#
# Average loss after epoch  34 :  0.47342079888935645
#
# Average loss after epoch  34 :  0.4576572137298724
#
# Average loss after epoch  34 :  0.2618418162580228
#
# Average loss after epoch  34 :  0.22597767927473428
#
# Average loss after epoch  34 :  0.2759476914421615
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, traffic,
# Similar to supply: week, benefits, Andrew, costs, Border,
# Similar to membership: Affairs, St, worries, time, start,
# --------------------------
#
# Average loss after epoch  35 :  0.28877343450273785
#
# Average loss after epoch  35 :  0.2563787625760448
#
# Average loss after epoch  35 :  0.3133335534059619
#
# Average loss after epoch  35 :  0.23783978694481236
#
# Average loss after epoch  35 :  0.36896869744133565
#
# Average loss after epoch  35 :  0.24055794108855696
#
# Average loss after epoch  35 :  0.33261416868719884
#
# Average loss after epoch  35 :  0.3095514593495879
#
# Average loss after epoch  35 :  0.5852637448337388
#
# Average loss after epoch  35 :  0.25671247185998525
#
# Average loss after epoch  35 :  0.26032829535981966
#
# Average loss after epoch  35 :  0.26658902867420864
#
# Average loss after epoch  35 :  0.27576861090871857
#
# Average loss after epoch  35 :  0.26282971906336516
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: week, benefits, Andrew, costs, Agreement,
# Similar to membership: Affairs, St, worries, time, start,
# --------------------------
#
# Average loss after epoch  36 :  0.33122287477765766
#
# Average loss after epoch  36 :  0.2885282623524569
#
# Average loss after epoch  36 :  0.5015717105337204
#
# Average loss after epoch  36 :  0.2719448674027992
#
# Average loss after epoch  36 :  0.24375706817638926
#
# Average loss after epoch  36 :  0.2513190890394024
#
# Average loss after epoch  36 :  0.23537568808341575
#
# Average loss after epoch  36 :  0.35523927535382377
#
# Average loss after epoch  36 :  0.2201628261561674
#
# Average loss after epoch  36 :  0.21680535286491456
#
# Average loss after epoch  36 :  0.30855355192495626
#
# Average loss after epoch  36 :  0.6587254557788891
#
# Average loss after epoch  36 :  0.4482766358184
#
# Average loss after epoch  36 :  0.24991543781279937
# Similar to news: Dover, attack, climate, Guernsey, digits,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, traffic,
# Similar to supply: week, benefits, Andrew, costs, Border,
# Similar to membership: Affairs, St, worries, time, start,
# --------------------------
#
# Average loss after epoch  37 :  0.3195258549281529
#
# Average loss after epoch  37 :  0.26898448077999815
#
# Average loss after epoch  37 :  0.28756105361109924
#
# Average loss after epoch  37 :  0.5811809893574927
#
# Average loss after epoch  37 :  0.2823652497084837
#
# Average loss after epoch  37 :  0.34118113681781786
#
# Average loss after epoch  37 :  0.2373966899408531
#
# Average loss after epoch  37 :  0.28646869125035285
#
# Average loss after epoch  37 :  0.19085088419209412
#
# Average loss after epoch  37 :  0.2241037339307655
#
# Average loss after epoch  37 :  0.29461040135180516
#
# Average loss after epoch  37 :  0.5599337575236641
#
# Average loss after epoch  37 :  0.2607872213451613
#
# Average loss after epoch  37 :  0.5558556980003101
# Similar to news: Dover, attack, climate, digits, Guernsey,
# Similar to Vince: misuse, 09bn, opposition, Arron, US,
# Similar to people: Britain, HQ, response, operations, Prime,
# Similar to problems: Kit, effect, Ramsgate, SNP, Asian,
# Similar to congestion: Information, Rzeczpospolita, issue, Kelly, Media,
# Similar to Concerns: vote, comedy, Article, Farry, traffic,
# Similar to supply: week, benefits, Andrew, costs, Border,
# Similar to membership: Affairs, St, worries, time, start,
# --------------------------
#
# Average loss after epoch  38 :  0.2984950542449951
#
# Average loss after epoch  38 :  0.2730412312916347
#
# Average loss after epoch  38 :  0.24582373974274616
#
# Average loss after epoch  38 :  0.42359092397175446
#
# Average loss after epoch  38 :  0.27658338387997533
#
# Average loss after epoch  38 :  0.3099015575364882
#
# Average loss after epoch  38 :  0.263523737743608
#
# Average loss after epoch  38 :  0.30478485426413954
#
# Average loss after epoch  38 :  0.2641826754532456
#
# Average loss after epoch  38 :  0.5995207931720231
#
# Average loss after epoch  38 :  0.25204649075243457
#
# Average loss after epoch  38 :  0.2413068772102918
#
# Average loss after epoch  38 :  0.46865385601027754
#
# ...
#
# Average loss after epoch  487 :  0.13641020757311625
#
# Average loss after epoch  487 :  0.09734260830308286
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, Kelly, confines, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, time,
# --------------------------
#
# Average loss after epoch  488 :  0.2035546132496425
#
# Average loss after epoch  488 :  0.13518558959571683
#
# Average loss after epoch  488 :  0.13287409644780285
#
# Average loss after epoch  488 :  0.12074441320942819
#
# Average loss after epoch  488 :  0.09953670459648468
#
# Average loss after epoch  488 :  0.13292677399492017
#
# Average loss after epoch  488 :  0.11757088218201893
#
# Average loss after epoch  488 :  0.09778196507555367
#
# Average loss after epoch  488 :  0.11969629845013371
#
# Average loss after epoch  488 :  0.10617757973287088
#
# Average loss after epoch  488 :  0.10011044651072194
#
# Average loss after epoch  488 :  0.09790247076309931
#
# Average loss after epoch  488 :  0.09289546906490923
#
# Average loss after epoch  488 :  0.08433020689625102
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, confines, Kelly, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, time,
# --------------------------
#
# Average loss after epoch  489 :  0.2017362458365304
#
# Average loss after epoch  489 :  0.1383154586869843
#
# Average loss after epoch  489 :  0.17984681609073117
#
# Average loss after epoch  489 :  0.13852405071457144
#
# Average loss after epoch  489 :  0.07873507874366778
#
# Average loss after epoch  489 :  0.12893369973923277
#
# Average loss after epoch  489 :  0.1662077756021885
#
# Average loss after epoch  489 :  0.12477253059045522
#
# Average loss after epoch  489 :  0.12184834351106488
#
# Average loss after epoch  489 :  0.09011277972939753
#
# Average loss after epoch  489 :  0.08566555623446415
#
# Average loss after epoch  489 :  0.11437006312057696
#
# Average loss after epoch  489 :  0.11903422752834879
#
# Average loss after epoch  489 :  0.1166551579178923
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, confines, Kelly, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, time,
# --------------------------
#
# Average loss after epoch  490 :  0.2050031934465681
#
# Average loss after epoch  490 :  0.12870297626573213
#
# Average loss after epoch  490 :  0.15301790251328715
#
# Average loss after epoch  490 :  0.14749609743838804
#
# Average loss after epoch  490 :  0.0976717211769346
#
# Average loss after epoch  490 :  0.13114812358480354
#
# Average loss after epoch  490 :  0.12189003568622446
#
# Average loss after epoch  490 :  0.10579555144035602
#
# Average loss after epoch  490 :  0.13396472087227432
#
# Average loss after epoch  490 :  0.0882404661964257
#
# Average loss after epoch  490 :  0.07852315630792776
#
# Average loss after epoch  490 :  0.10279863201882102
#
# Average loss after epoch  490 :  0.0998477972144922
#
# Average loss after epoch  490 :  0.08903668633951346
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, confines, Kelly, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, department,
# --------------------------
#
# Average loss after epoch  491 :  0.18425313064030238
#
# Average loss after epoch  491 :  0.14929568159336948
#
# Average loss after epoch  491 :  0.1357499016095876
#
# Average loss after epoch  491 :  0.16505594518049613
#
# Average loss after epoch  491 :  0.08498615556264495
#
# Average loss after epoch  491 :  0.10366826010126769
#
# Average loss after epoch  491 :  0.1405794994833774
#
# Average loss after epoch  491 :  0.1351929589169558
#
# Average loss after epoch  491 :  0.12020658371035071
#
# Average loss after epoch  491 :  0.07967642298566714
#
# Average loss after epoch  491 :  0.07995525666023111
#
# Average loss after epoch  491 :  0.08935826425605219
#
# Average loss after epoch  491 :  0.1651568365982978
#
# Average loss after epoch  491 :  0.09665553025469757
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, confines, Kelly, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, department,
# --------------------------
#
# Average loss after epoch  492 :  0.1967198508126395
#
# Average loss after epoch  492 :  0.14887959373240567
# Average loss after epoch  492 :  0.12559663015621397
#
# Average loss after epoch  492 :  0.12185926860146401
#
# Average loss after epoch  492 :  0.08363721741492738
#
# Average loss after epoch  492 :  0.13185202931595358
#
# Average loss after epoch  492 :  0.11240227723067184
#
# Average loss after epoch  492 :  0.10130228861736768
#
# Average loss after epoch  492 :  0.0958966628884755
#
# Average loss after epoch  492 :  0.11175213978528609
#
# Average loss after epoch  492 :  0.08078468606999915
#
# Average loss after epoch  492 :  0.09429678800995252
#
# Average loss after epoch  492 :  0.11272313586536979
#
# Average loss after epoch  492 :  0.08347445044607203
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, confines, Kelly, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, department,
# --------------------------
#
# Average loss after epoch  493 :  0.1968552385057722
#
# Average loss after epoch  493 :  0.1382833159699732
#
# Average loss after epoch  493 :  0.1312191361241021
#
# Average loss after epoch  493 :  0.12824522508079436
#
# Average loss after epoch  493 :  0.0912572564489037
#
# Average loss after epoch  493 :  0.09888455996773349
#
# Average loss after epoch  493 :  0.11211539856724917
#
# Average loss after epoch  493 :  0.11018315493502288
#
# Average loss after epoch  493 :  0.1103641245616604
#
# Average loss after epoch  493 :  0.09240652304215892
#
# Average loss after epoch  493 :  0.08969551408668619
#
# Average loss after epoch  493 :  0.08265905301086977
#
# Average loss after epoch  493 :  0.09606440061636827
#
# Average loss after epoch  493 :  0.08752842970852913
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, confines, Kelly, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, plenty,
# --------------------------
#
# Average loss after epoch  494 :  0.20146887642996653
#
# Average loss after epoch  494 :  0.14789502474726463
#
# Average loss after epoch  494 :  0.11844237691806982
#
# Average loss after epoch  494 :  0.1617668072713608
#
# Average loss after epoch  494 :  0.09584529343341926
#
# Average loss after epoch  494 :  0.09548991573928023
#
# Average loss after epoch  494 :  0.10404460320378926
#
# Average loss after epoch  494 :  0.09550855322218053
#
# Average loss after epoch  494 :  0.09383811110792849
#
# Average loss after epoch  494 :  0.09604754728542786
#
# Average loss after epoch  494 :  0.0898745164150759
#
# Average loss after epoch  494 :  0.11296728753528966
#
# Average loss after epoch  494 :  0.1062325349190987
#
# Average loss after epoch  494 :  0.09348023867847775
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, confines, Kelly, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, department,
# --------------------------
#
# Average loss after epoch  495 :  0.21509524754115514
#
# Average loss after epoch  495 :  0.13973130255329366
#
# Average loss after epoch  495 :  0.136339452628144
#
# Average loss after epoch  495 :  0.1530845354542738
#
# Average loss after epoch  495 :  0.08883774415755276
#
# Average loss after epoch  495 :  0.10745217128602096
#
# Average loss after epoch  495 :  0.11458866207656934
#
# Average loss after epoch  495 :  0.11295321470843729
#
# Average loss after epoch  495 :  0.1511249222119273
#
# Average loss after epoch  495 :  0.10039496193158925
#
# Average loss after epoch  495 :  0.0862869022643483
#
# Average loss after epoch  495 :  0.11595910786415789
#
# Average loss after epoch  495 :  0.09752210123115045
#
# Average loss after epoch  495 :  0.10453885519985164
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, Kelly, confines, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, time,
# --------------------------
#
# Average loss after epoch  496 :  0.18146392277308873
#
# Average loss after epoch  496 :  0.134676743526848
#
# Average loss after epoch  496 :  0.13003652783941597
#
# Average loss after epoch  496 :  0.14538373655698936
#
# Average loss after epoch  496 :  0.1141959954632338
#
# Average loss after epoch  496 :  0.10653553214337866
#
# Average loss after epoch  496 :  0.11268413762724573
#
# Average loss after epoch  496 :  0.1087655430042149
#
# Average loss after epoch  496 :  0.10333099964831131
#
# Average loss after epoch  496 :  0.09266564037372234
#
# Average loss after epoch  496 :  0.10044242426467052
#
# Average loss after epoch  496 :  0.11441495694199637
#
# Average loss after epoch  496 :  0.11317065973897734
#
# Average loss after epoch  496 :  0.08667874593097537
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, Britain, response, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, Kelly, confines, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, department,
# --------------------------
#
# Average loss after epoch  497 :  0.18204665184020996
#
# Average loss after epoch  497 :  0.1597252062388829
#
# Average loss after epoch  497 :  0.1483563282051865
#
# Average loss after epoch  497 :  0.15530963524437505
#
# Average loss after epoch  497 :  0.13500548812907123
#
# Average loss after epoch  497 :  0.10274572132113517
#
# Average loss after epoch  497 :  0.1302727595383801
#
# Average loss after epoch  497 :  0.11948930461786246
#
# Average loss after epoch  497 :  0.10588324016019138
#
# Average loss after epoch  497 :  0.09636019805051346
#
# Average loss after epoch  497 :  0.09233369084978207
#
# Average loss after epoch  497 :  0.10556903173014102
#
# Average loss after epoch  497 :  0.11188606895824597
#
# Average loss after epoch  497 :  0.09949563548523778
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, opposition, Arron, capacity,
# Similar to people: operations, Prime, response, Britain, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, Kelly, confines, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, department,
# --------------------------
#
# Average loss after epoch  498 :  0.1854862826211112
#
# Average loss after epoch  498 :  0.16643864524607754
#
# Average loss after epoch  498 :  0.15930407857060777
#
# Average loss after epoch  498 :  0.12872229702072507
#
# Average loss after epoch  498 :  0.11361829630448504
#
# Average loss after epoch  498 :  0.11075988283605383
#
# Average loss after epoch  498 :  0.11198131730929088
#
# Average loss after epoch  498 :  0.11455606881406696
#
# Average loss after epoch  498 :  0.10740254568459505
#
# Average loss after epoch  498 :  0.10918445122199535
#
# Average loss after epoch  498 :  0.08240275349784272
#
# Average loss after epoch  498 :  0.08078921179442773
#
# Average loss after epoch  498 :  0.12121700413203607
#
# Average loss after epoch  498 :  0.08805676809888253
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, Arron, opposition, capacity,
# Similar to people: operations, Prime, response, Britain, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, Kelly, confines, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, department,
# --------------------------
#
# Average loss after epoch  499 :  0.18111184665134974
#
# Average loss after epoch  499 :  0.15302843950232684
#
# Average loss after epoch  499 :  0.15500112594737953
#
# Average loss after epoch  499 :  0.13001099386497222
#
# Average loss after epoch  499 :  0.14296349681465673
#
# Average loss after epoch  499 :  0.11298641760934594
#
# Average loss after epoch  499 :  0.13672287776341693
#
# Average loss after epoch  499 :  0.12633743138133816
#
# Average loss after epoch  499 :  0.10148338920376083
#
# Average loss after epoch  499 :  0.10541124318788546
#
# Average loss after epoch  499 :  0.07894957574687551
#
# Average loss after epoch  499 :  0.10285948891900987
#
# Average loss after epoch  499 :  0.12067735136936321
# Average loss after epoch  499 :  0.08641352819643576
# Similar to news: attack, Dover, climate, digits, strait,
# Similar to Vince: misuse, 09bn, Arron, opposition, capacity,
# Similar to people: operations, Prime, response, Britain, HQ,
# Similar to problems: Kit, effect, Ramsgate, Asian, SNP,
# Similar to congestion: Information, Rzeczpospolita, Kelly, confines, citizens,
# Similar to Concerns: vote, comedy, Article, Farry, Disaster,
# Similar to supply: benefits, week, costs, Andrew, drives,
# Similar to membership: Affairs, St, worries, start, department,
# Saving model in  /notebooks/paper2/datasets/brexit/model.ckpt
# Trained for TSNE

# %%
from packages.gc.plotter import Plotter
wordInfo = word2vecProcessor.getPoints(5)
print(len(wordInfo))
    
linearPlotProcessor = Plotter(wordInfo)
linearPlotProcessor.displayPlot()
# Out:
# 50
