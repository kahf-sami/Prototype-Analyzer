# %%
import sys, os, json, re

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

dirPath = os.path.dirname(os.path.realpath("__file__"))
packagesPath = os.path.join(dirPath, 'packages')
print(packagesPath)

if not packagesPath in sys.path:
    sys.path.append(packagesPath)
    
# IPython extension to reload modules before executing user code.
# autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %reload_ext autoreload
# %autoreload 2
# Out:
# /notebooks/paper2/packages
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import packages.dataset as dataset

datasetPath = os.path.join(dirPath, 'datasets')
dataProcessor = dataset.Brexit(datasetPath)
dataProcessor.loadFilePaths()
# Out:
# Dataset path:
# /notebooks/paper2/datasets/brexit
# Total files 49
# -------------------------------
# Training file count:  39
# Total files in list:  39
# -------------------------------
# Total validation file count 4
# Total files in list:  4
# -------------------------------
# Total test file count 6
# Total files in list:  6
# -------------------------------

# %%
from packages.gc.word2vec import Word2Vec
word2vecProcessor = Word2Vec(dataProcessor)
#word2vecProcessor.train()

skipWindow = 2
word2vecProcessor.resetIndex()
word2vecProcessor.setSkipWindow(skipWindow)
word2vecProcessor.setBatchSize(128)

# in skip-gram input is the target word and output is the context word
x_batch, y_batch = word2vecProcessor.nextBatchSkipGram()

print(x_batch)
print(y_batch)
# Out:
# ----- nextBatchSkipGram -----
#
# total length  512
#
# ----- Sentence -----
#
# Sentence index:  0
# [0, 1, 2, 3]
# totalInASentence:  4
#
# ----- Sentence -----
#
# Sentence index:  1
# [0, 1, 2, 3]
# totalInASentence:  4
#
# ----- Sentence -----
#
# Sentence index:  2
# [2, 0, 3, 1, 4, 5]
# totalInASentence:  6
#
# ----- Sentence -----
#
# Sentence index:  3
# [6, 7, 8, 9, 10, 0, 11, 12, 13]
# totalInASentence:  9
#
# ----- Sentence -----
#
# Sentence index:  4
# [14, 15, 4, 16, 17, 7, 9, 10]
# totalInASentence:  8
#
# ----- Sentence -----
#
# Sentence index:  5
# [18, 19, 20, 21]
# totalInASentence:  4
#
# ----- Sentence -----
#
# Sentence index:  6
# [0, 22, 23, 24, 25, 21, 19, 26, 27]
# totalInASentence:  9
#
# ----- Sentence -----
#
# Sentence index:  7
# [28, 29, 30, 31, 32, 19]
# totalInASentence:  6
#
# ----- Sentence -----
#
# Sentence index:  8
# [3, 33, 7, 9, 10, 0, 34]
# totalInASentence:  7
#
# ----- Sentence -----
#
# Sentence index:  9
# [35, 36, 37, 38, 39]
# totalInASentence:  5
#
# ----- Sentence -----
#
# Sentence index:  10
# [40, 41, 0]
# totalInASentence:  3
#
# ----- Sentence -----
#
# Sentence index:  11
# [42, 43, 44, 45, 46, 47, 48, 49, 3, 13, 50, 4, 11, 51, 52, 16, 17, 53]
# totalInASentence:  18
#
# ----- Sentence -----
#
# Sentence index:  12
# [54, 19, 55, 25, 56, 57, 4, 58, 7, 9, 10]
# totalInASentence:  11
#
# ----- Sentence -----
#
# Sentence index:  13
# [59, 47, 48, 49, 60, 0, 11, 61]
# totalInASentence:  8
#
# ----- Sentence -----
#
# Sentence index:  14
# [62, 63, 64, 65, 0, 66, 67, 68, 69, 11, 51, 70, 4]
# totalInASentence:  13
#
# ----- Sentence -----
#
# Sentence index:  15
# [7, 9, 10, 12, 11, 71, 4, 13]
# totalInASentence:  8
#
# ----- Sentence -----
#
# Sentence index:  16
# [38, 72, 73, 11, 74, 75]
# totalInASentence:  6
#
# ----- Sentence -----
#
# Sentence index:  17
# [3, 76, 77, 49, 78, 79]
# totalInASentence:  6
#
# ----- Sentence -----
#
# Sentence index:  18
# [3, 76, 77, 49, 78, 79]
# totalInASentence:  6
#
# ----- Sentence -----
#
# Sentence index:  19
# [80, 19, 21, 81, 25, 82, 83, 77]
# totalInASentence:  8
#
# ----- Sentence -----
#
# Sentence index:  20
# [77, 3, 84, 30, 85, 86, 87, 88, 58]
# totalInASentence:  9
#
# ----- Sentence -----
#
# Sentence index:  21
# [89, 3, 19, 21, 90, 91, 92, 93, 38, 94]
# totalInASentence:  10
# [ 0  0  1  1  1  2  2  3  3  0  0  1  1  1  2  2  3  3  2  2  0  0  0  3
#   3  3  3  1  1  1  1  4  4  5  5  6  6  7  7  7  8  8  8  8  9  9  9  9
#  10 10 10 10  0  0  0  0 11 11 11 11 12 12 13 13 14 14 15 15 15  4  4  4
#   4 16 16 16 16 17 17 17 17  7  7  7  7  9  9 10 10 18 18 19 19 19 20 20
#  21 21  0  0 22 22 22 23 23 23 23 24 24 24 24 25 25 25 25 21 21 21 21 19
#  19 19 19 26 26 27 27 28 28 29 29 29 30 30 30 30 31 31 31 31 32 32 19 19
#   3  3 33 33 33  7  7  7  7  9  9  9  9 10 10 10 10  0  0 34 34 35 35 36
#  36 36 37 37 37 37 38 38 39 39 40 40 41  0  0 42 42 43 43 43 44 44 44 44
#  45 45 45 45 46 46 46 46 47 47 47 47 48 48 48 48 49 49 49 49  3  3  3  3
#  13 13 13 13 50 50 50 50  4  4  4  4 11 11 11 11 51 51 51 51 52 52 52 52
#  16 16 16 16 17 17 53 53 54 54 19 19 19 55 55 55 55 25 25 25 25 56 56 56
#  56 57 57 57 57  4  4  4  4 58 58 58 58  7  7  7  7  9  9 10 10 59 59 47
#  47 47 48 48 48 48 49 49 49 49 60 60 60 60  0  0  0  0 11 11 61 61 62 62
#  63 63 63 64 64 64 64 65 65 65 65  0  0  0  0 66 66 66 66 67 67 67 67 68
#  68 68 68 69 69 69 69 11 11 11 11 51 51 51 51 70 70  4  4  7  7  9  9  9
#  10 10 10 10 12 12 12 12 11 11 11 11 71 71 71 71  4  4 13 13 38 38 72 72
#  72 73 73 73 73 11 11 11 11 74 74 75 75  3  3 76 76 76 77 77 77 77 49 49
#  49 49 78 78 79 79  3  3 76 76 76 77 77 77 77 49 49 49 49 78 78 79 79 80
#  80 19 19 19 21 21 21 21 81 81 81 81 25 25 25 25 82 82 82 82 83 83 77 77
#  77 77  3  3  3 84 84 84 84 30 30 30 30 85 85 85 85 86 86 86 86 87 87 87
#  87 88 88 58 58 89 89  3  3  3 19 19 19 19 21 21 21 21 90 90 90 90 91 91
#  91 91 92 92 92 92 93 93]
# [ 1  2  0  2  3  0  1  1  2  1  2  0  2  3  0  1  1  2  0  3  2  3  1  2
#   0  1  4  0  3  4  5  3  1  1  4  7  8  6  8  9  6  7  9 10  7  8 10  0
#   8  9  0 11  9 10 11 12 10  0 12 13  0 11 11 12 15  4 14  4 16 14 15 16
#  17 15  4 17  7  4 16  7  9 16 17  9 10 17  7  7  9 19 20 18 20 21 18 19
#  19 20 22 23  0 23 24  0 22 24 25 22 23 25 21 23 24 21 19 24 25 19 26 25
#  21 26 27 21 19 19 26 29 30 28 30 31 28 29 31 32 29 30 32 19 30 31 31 32
#  33  7  3  7  9  3 33  9 10 33  7 10  0  7  9  0 34  9 10 10  0 36 37 35
#  37 38 35 36 38 39 36 37 37 38 41  0 40 40 41 43 44 42 44 45 42 43 45 46
#  43 44 46 47 44 45 47 48 45 46 48 49 46 47 49  3 47 48  3 13 48 49 13 50
#  49  3 50  4  3 13  4 11 13 50 11 51 50  4 51 52  4 11 52 16 11 51 16 17
#  51 52 17 53 52 16 16 17 19 55 54 55 25 54 19 25 56 19 55 56 57 55 25 57
#   4 25 56  4 58 56 57 58  7 57  4  7  9  4 58  9 10 58  7  7  9 47 48 59
#  48 49 59 47 49 60 47 48 60  0 48 49  0 11 49 60 11 61 60  0  0 11 63 64
#  62 64 65 62 63 65  0 63 64  0 66 64 65 66 67 65  0 67 68  0 66 68 69 66
#  67 69 11 67 68 11 51 68 69 51 70 69 11 70  4 11 51 51 70  9 10  7 10 12
#   7  9 12 11  9 10 11 71 10 12 71  4 12 11  4 13 11 71 71  4 72 73 38 73
#  11 38 72 11 74 72 73 74 75 73 11 11 74 76 77  3 77 49  3 76 49 78 76 77
#  78 79 77 49 49 78 76 77  3 77 49  3 76 49 78 76 77 78 79 77 49 49 78 19
#  21 80 21 81 80 19 81 25 19 21 25 82 21 81 82 83 81 25 83 77 25 82 82 83
#   3 84 77 84 30 77  3 30 85  3 84 85 86 84 30 86 87 30 85 87 88 85 86 88
#  58 86 87 87 88  3 19 89 19 21 89  3 21 90  3 19 90 91 19 21 91 92 21 90
#  92 93 90 91 93 38 91 92]

# %%
print('The skip-gram pairs : target,context')
for i in range(512):
    print('(', x_batch[i], word2vecProcessor.id2Word[x_batch[i]],
          ',', y_batch[i], word2vecProcessor.id2Word[y_batch[i]], ')')
# Out:
# The skip-gram pairs : target,context
# ( 0 guernsey , 1 minist )
# ( 0 guernsey , 2 point )
# ( 1 minist , 0 guernsey )
# ( 1 minist , 2 point )
# ( 1 minist , 3 brexit )
# ( 2 point , 0 guernsey )
# ( 2 point , 1 minist )
# ( 3 brexit , 1 minist )
# ( 3 brexit , 2 point )
# ( 0 guernsey , 1 minist )
# ( 0 guernsey , 2 point )
# ( 1 minist , 0 guernsey )
# ( 1 minist , 2 point )
# ( 1 minist , 3 brexit )
# ( 2 point , 0 guernsey )
# ( 2 point , 1 minist )
# ( 3 brexit , 1 minist )
# ( 3 brexit , 2 point )
# ( 2 point , 0 guernsey )
# ( 2 point , 3 brexit )
# ( 0 guernsey , 2 point )
# ( 0 guernsey , 3 brexit )
# ( 0 guernsey , 1 minist )
# ( 3 brexit , 2 point )
# ( 3 brexit , 0 guernsey )
# ( 3 brexit , 1 minist )
# ( 3 brexit , 4 island )
# ( 1 minist , 0 guernsey )
# ( 1 minist , 3 brexit )
# ( 1 minist , 4 island )
# ( 1 minist , 5 politician )
# ( 4 island , 3 brexit )
# ( 4 island , 1 minist )
# ( 5 politician , 1 minist )
# ( 5 politician , 4 island )
# ( 6 updat , 7 deputi )
# ( 6 updat , 8 gavin )
# ( 7 deputi , 6 updat )
# ( 7 deputi , 8 gavin )
# ( 7 deputi , 9 st )
# ( 8 gavin , 6 updat )
# ( 8 gavin , 7 deputi )
# ( 8 gavin , 9 st )
# ( 8 gavin , 10 pier )
# ( 9 st , 7 deputi )
# ( 9 st , 8 gavin )
# ( 9 st , 10 pier )
# ( 9 st , 0 guernsey )
# ( 10 pier , 8 gavin )
# ( 10 pier , 9 st )
# ( 10 pier , 0 guernsey )
# ( 10 pier , 11 food )
# ( 0 guernsey , 9 st )
# ( 0 guernsey , 10 pier )
# ( 0 guernsey , 11 food )
# ( 0 guernsey , 12 shortag )
# ( 11 food , 10 pier )
# ( 11 food , 0 guernsey )
# ( 11 food , 12 shortag )
# ( 11 food , 13 scenario )
# ( 12 shortag , 0 guernsey )
# ( 12 shortag , 11 food )
# ( 13 scenario , 11 food )
# ( 13 scenario , 12 shortag )
# ( 14 say , 15 referendum )
# ( 14 say , 4 island )
# ( 15 referendum , 14 say )
# ( 15 referendum , 4 island )
# ( 15 referendum , 16 conting )
# ( 4 island , 14 say )
# ( 4 island , 15 referendum )
# ( 4 island , 16 conting )
# ( 4 island , 17 plan )
# ( 16 conting , 15 referendum )
# ( 16 conting , 4 island )
# ( 16 conting , 17 plan )
# ( 16 conting , 7 deputi )
# ( 17 plan , 4 island )
# ( 17 plan , 16 conting )
# ( 17 plan , 7 deputi )
# ( 17 plan , 9 st )
# ( 7 deputi , 16 conting )
# ( 7 deputi , 17 plan )
# ( 7 deputi , 9 st )
# ( 7 deputi , 10 pier )
# ( 9 st , 17 plan )
# ( 9 st , 7 deputi )
# ( 10 pier , 7 deputi )
# ( 10 pier , 9 st )
# ( 18 depend , 19 uk )
# ( 18 depend , 20 member )
# ( 19 uk , 18 depend )
# ( 19 uk , 20 member )
# ( 19 uk , 21 eu )
# ( 20 member , 18 depend )
# ( 20 member , 19 uk )
# ( 21 eu , 19 uk )
# ( 21 eu , 20 member )
# ( 0 guernsey , 22 jersey )
# ( 0 guernsey , 23 isl )
# ( 22 jersey , 0 guernsey )
# ( 22 jersey , 23 isl )
# ( 22 jersey , 24 man )
# ( 23 isl , 0 guernsey )
# ( 23 isl , 22 jersey )
# ( 23 isl , 24 man )
# ( 23 isl , 25 trade )
# ( 24 man , 22 jersey )
# ( 24 man , 23 isl )
# ( 24 man , 25 trade )
# ( 24 man , 21 eu )
# ( 25 trade , 23 isl )
# ( 25 trade , 24 man )
# ( 25 trade , 21 eu )
# ( 25 trade , 19 uk )
# ( 21 eu , 24 man )
# ( 21 eu , 25 trade )
# ( 21 eu , 19 uk )
# ( 21 eu , 26 access )
# ( 19 uk , 25 trade )
# ( 19 uk , 21 eu )
# ( 19 uk , 26 access )
# ( 19 uk , 27 treati )
# ( 26 access , 21 eu )
# ( 26 access , 19 uk )
# ( 27 treati , 19 uk )
# ( 27 treati , 26 access )
# ( 28 area , 29 immigr )
# ( 28 area , 30 transport )
# ( 29 immigr , 28 area )
# ( 29 immigr , 30 transport )
# ( 29 immigr , 31 energi )
# ( 30 transport , 28 area )
# ( 30 transport , 29 immigr )
# ( 30 transport , 31 energi )
# ( 30 transport , 32 cooper )
# ( 31 energi , 29 immigr )
# ( 31 energi , 30 transport )
# ( 31 energi , 32 cooper )
# ( 31 energi , 19 uk )
# ( 32 cooper , 30 transport )
# ( 32 cooper , 31 energi )
# ( 19 uk , 31 energi )
# ( 19 uk , 32 cooper )
# ( 3 brexit , 33 process )
# ( 3 brexit , 7 deputi )
# ( 33 process , 3 brexit )
# ( 33 process , 7 deputi )
# ( 33 process , 9 st )
# ( 7 deputi , 3 brexit )
# ( 7 deputi , 33 process )
# ( 7 deputi , 9 st )
# ( 7 deputi , 10 pier )
# ( 9 st , 33 process )
# ( 9 st , 7 deputi )
# ( 9 st , 10 pier )
# ( 9 st , 0 guernsey )
# ( 10 pier , 7 deputi )
# ( 10 pier , 9 st )
# ( 10 pier , 0 guernsey )
# ( 10 pier , 34 parliament )
# ( 0 guernsey , 9 st )
# ( 0 guernsey , 10 pier )
# ( 34 parliament , 10 pier )
# ( 34 parliament , 0 guernsey )
# ( 35 time , 36 peopl )
# ( 35 time , 37 money )
# ( 36 peopl , 35 time )
# ( 36 peopl , 37 money )
# ( 36 peopl , 38 govern )
# ( 37 money , 35 time )
# ( 37 money , 36 peopl )
# ( 37 money , 38 govern )
# ( 37 money , 39 prioriti )
# ( 38 govern , 36 peopl )
# ( 38 govern , 37 money )
# ( 39 prioriti , 37 money )
# ( 39 prioriti , 38 govern )
# ( 40 stori , 41 news )
# ( 40 stori , 0 guernsey )
# ( 41 news , 40 stori )
# ( 0 guernsey , 40 stori )
# ( 0 guernsey , 41 news )
# ( 42 imag , 43 caption )
# ( 42 imag , 44 sir )
# ( 43 caption , 42 imag )
# ( 43 caption , 44 sir )
# ( 43 caption , 45 vinc )
# ( 44 sir , 42 imag )
# ( 44 sir , 43 caption )
# ( 44 sir , 45 vinc )
# ( 44 sir , 46 cabl )
# ( 45 vinc , 43 caption )
# ( 45 vinc , 44 sir )
# ( 45 vinc , 46 cabl )
# ( 45 vinc , 47 congest )
# ( 46 cabl , 44 sir )
# ( 46 cabl , 45 vinc )
# ( 46 cabl , 47 congest )
# ( 46 cabl , 48 portsmouth )
# ( 47 congest , 45 vinc )
# ( 47 congest , 46 cabl )
# ( 47 congest , 48 portsmouth )
# ( 47 congest , 49 port )
# ( 48 portsmouth , 46 cabl )
# ( 48 portsmouth , 47 congest )
# ( 48 portsmouth , 49 port )
# ( 48 portsmouth , 3 brexit )
# ( 49 port , 47 congest )
# ( 49 port , 48 portsmouth )
# ( 49 port , 3 brexit )
# ( 49 port , 13 scenario )
# ( 3 brexit , 48 portsmouth )
# ( 3 brexit , 49 port )
# ( 3 brexit , 13 scenario )
# ( 3 brexit , 50 problem )
# ( 13 scenario , 49 port )
# ( 13 scenario , 3 brexit )
# ( 13 scenario , 50 problem )
# ( 13 scenario , 4 island )
# ( 50 problem , 3 brexit )
# ( 50 problem , 13 scenario )
# ( 50 problem , 4 island )
# ( 50 problem , 11 food )
# ( 4 island , 13 scenario )
# ( 4 island , 50 problem )
# ( 4 island , 11 food )
# ( 4 island , 51 suppli )
# ( 11 food , 50 problem )
# ( 11 food , 4 island )
# ( 11 food , 51 suppli )
# ( 11 food , 52 3m )
# ( 51 suppli , 4 island )
# ( 51 suppli , 11 food )
# ( 51 suppli , 52 3m )
# ( 51 suppli , 16 conting )
# ( 52 3m , 11 food )
# ( 52 3m , 51 suppli )
# ( 52 3m , 16 conting )
# ( 52 3m , 17 plan )
# ( 16 conting , 51 suppli )
# ( 16 conting , 52 3m )
# ( 16 conting , 17 plan )
# ( 16 conting , 53 law )
# ( 17 plan , 52 3m )
# ( 17 plan , 16 conting )
# ( 53 law , 16 conting )
# ( 53 law , 17 plan )
# ( 54 extens , 19 uk )
# ( 54 extens , 55 world )
# ( 19 uk , 54 extens )
# ( 19 uk , 55 world )
# ( 19 uk , 25 trade )
# ( 55 world , 54 extens )
# ( 55 world , 19 uk )
# ( 55 world , 25 trade )
# ( 55 world , 56 organis )
# ( 25 trade , 19 uk )
# ( 25 trade , 55 world )
# ( 25 trade , 56 organis )
# ( 25 trade , 57 membership )
# ( 56 organis , 55 world )
# ( 56 organis , 25 trade )
# ( 56 organis , 57 membership )
# ( 56 organis , 4 island )
# ( 57 membership , 25 trade )
# ( 57 membership , 56 organis )
# ( 57 membership , 4 island )
# ( 57 membership , 58 week )
# ( 4 island , 56 organis )
# ( 4 island , 57 membership )
# ( 4 island , 58 week )
# ( 4 island , 7 deputi )
# ( 58 week , 57 membership )
# ( 58 week , 4 island )
# ( 58 week , 7 deputi )
# ( 58 week , 9 st )
# ( 7 deputi , 4 island )
# ( 7 deputi , 58 week )
# ( 7 deputi , 9 st )
# ( 7 deputi , 10 pier )
# ( 9 st , 58 week )
# ( 9 st , 7 deputi )
# ( 10 pier , 7 deputi )
# ( 10 pier , 9 st )
# ( 59 concern , 47 congest )
# ( 59 concern , 48 portsmouth )
# ( 47 congest , 59 concern )
# ( 47 congest , 48 portsmouth )
# ( 47 congest , 49 port )
# ( 48 portsmouth , 59 concern )
# ( 48 portsmouth , 47 congest )
# ( 48 portsmouth , 49 port )
# ( 48 portsmouth , 60 major )
# ( 49 port , 47 congest )
# ( 49 port , 48 portsmouth )
# ( 49 port , 60 major )
# ( 49 port , 0 guernsey )
# ( 60 major , 48 portsmouth )
# ( 60 major , 49 port )
# ( 60 major , 0 guernsey )
# ( 60 major , 11 food )
# ( 0 guernsey , 49 port )
# ( 0 guernsey , 60 major )
# ( 0 guernsey , 11 food )
# ( 0 guernsey , 61 product )
# ( 11 food , 60 major )
# ( 11 food , 0 guernsey )
# ( 61 product , 0 guernsey )
# ( 61 product , 11 food )
# ( 62 earlier , 63 advisor )
# ( 62 earlier , 64 theresa )
# ( 63 advisor , 62 earlier )
# ( 63 advisor , 64 theresa )
# ( 63 advisor , 65 may )
# ( 64 theresa , 62 earlier )
# ( 64 theresa , 63 advisor )
# ( 64 theresa , 65 may )
# ( 64 theresa , 0 guernsey )
# ( 65 may , 63 advisor )
# ( 65 may , 64 theresa )
# ( 65 may , 0 guernsey )
# ( 65 may , 66 resid )
# ( 0 guernsey , 64 theresa )
# ( 0 guernsey , 65 may )
# ( 0 guernsey , 66 resid )
# ( 0 guernsey , 67 joshua )
# ( 66 resid , 65 may )
# ( 66 resid , 0 guernsey )
# ( 66 resid , 67 joshua )
# ( 66 resid , 68 livestro )
# ( 67 joshua , 0 guernsey )
# ( 67 joshua , 66 resid )
# ( 67 joshua , 68 livestro )
# ( 67 joshua , 69 medicin )
# ( 68 livestro , 66 resid )
# ( 68 livestro , 67 joshua )
# ( 68 livestro , 69 medicin )
# ( 68 livestro , 11 food )
# ( 69 medicin , 67 joshua )
# ( 69 medicin , 68 livestro )
# ( 69 medicin , 11 food )
# ( 69 medicin , 51 suppli )
# ( 11 food , 68 livestro )
# ( 11 food , 69 medicin )
# ( 11 food , 51 suppli )
# ( 11 food , 70 consequ )
# ( 51 suppli , 69 medicin )
# ( 51 suppli , 11 food )
# ( 51 suppli , 70 consequ )
# ( 51 suppli , 4 island )
# ( 70 consequ , 11 food )
# ( 70 consequ , 51 suppli )
# ( 4 island , 51 suppli )
# ( 4 island , 70 consequ )
# ( 7 deputi , 9 st )
# ( 7 deputi , 10 pier )
# ( 9 st , 7 deputi )
# ( 9 st , 10 pier )
# ( 9 st , 12 shortag )
# ( 10 pier , 7 deputi )
# ( 10 pier , 9 st )
# ( 10 pier , 12 shortag )
# ( 10 pier , 11 food )
# ( 12 shortag , 9 st )
# ( 12 shortag , 10 pier )
# ( 12 shortag , 11 food )
# ( 12 shortag , 71 price )
# ( 11 food , 10 pier )
# ( 11 food , 12 shortag )
# ( 11 food , 71 price )
# ( 11 food , 4 island )
# ( 71 price , 12 shortag )
# ( 71 price , 11 food )
# ( 71 price , 4 island )
# ( 71 price , 13 scenario )
# ( 4 island , 11 food )
# ( 4 island , 71 price )
# ( 13 scenario , 71 price )
# ( 13 scenario , 4 island )
# ( 38 govern , 72 hampshir )
# ( 38 govern , 73 author )
# ( 72 hampshir , 38 govern )
# ( 72 hampshir , 73 author )
# ( 72 hampshir , 11 food )
# ( 73 author , 38 govern )
# ( 73 author , 72 hampshir )
# ( 73 author , 11 food )
# ( 73 author , 74 provid )
# ( 11 food , 72 hampshir )
# ( 11 food , 73 author )
# ( 11 food , 74 provid )
# ( 11 food , 75 impact )
# ( 74 provid , 73 author )
# ( 74 provid , 11 food )
# ( 75 impact , 11 food )
# ( 75 impact , 74 provid )
# ( 3 brexit , 76 could )
# ( 3 brexit , 77 channel )
# ( 76 could , 3 brexit )
# ( 76 could , 77 channel )
# ( 76 could , 49 port )
# ( 77 channel , 3 brexit )
# ( 77 channel , 76 could )
# ( 77 channel , 49 port )
# ( 77 channel , 78 cope )
# ( 49 port , 76 could )
# ( 49 port , 77 channel )
# ( 49 port , 78 cope )
# ( 49 port , 79 deal )
# ( 78 cope , 77 channel )
# ( 78 cope , 49 port )
# ( 79 deal , 49 port )
# ( 79 deal , 78 cope )
# ( 3 brexit , 76 could )
# ( 3 brexit , 77 channel )
# ( 76 could , 3 brexit )
# ( 76 could , 77 channel )
# ( 76 could , 49 port )
# ( 77 channel , 3 brexit )
# ( 77 channel , 76 could )
# ( 77 channel , 49 port )
# ( 77 channel , 78 cope )
# ( 49 port , 76 could )
# ( 49 port , 77 channel )
# ( 49 port , 78 cope )
# ( 49 port , 79 deal )
# ( 78 cope , 77 channel )
# ( 78 cope , 49 port )
# ( 79 deal , 49 port )
# ( 79 deal , 78 cope )
# ( 80 month , 19 uk )
# ( 80 month , 21 eu )
# ( 19 uk , 80 month )
# ( 19 uk , 21 eu )
# ( 19 uk , 81 attent )
# ( 21 eu , 80 month )
# ( 21 eu , 19 uk )
# ( 21 eu , 81 attent )
# ( 21 eu , 25 trade )
# ( 81 attent , 19 uk )
# ( 81 attent , 21 eu )
# ( 81 attent , 25 trade )
# ( 81 attent , 82 rout )
# ( 25 trade , 21 eu )
# ( 25 trade , 81 attent )
# ( 25 trade , 82 rout )
# ( 25 trade , 83 english )
# ( 82 rout , 81 attent )
# ( 82 rout , 25 trade )
# ( 82 rout , 83 english )
# ( 82 rout , 77 channel )
# ( 83 english , 25 trade )
# ( 83 english , 82 rout )
# ( 77 channel , 82 rout )
# ( 77 channel , 83 english )
# ( 77 channel , 3 brexit )
# ( 77 channel , 84 circumst )
# ( 3 brexit , 77 channel )
# ( 3 brexit , 84 circumst )
# ( 3 brexit , 30 transport )
# ( 84 circumst , 77 channel )
# ( 84 circumst , 3 brexit )
# ( 84 circumst , 30 transport )
# ( 84 circumst , 85 secretari )
# ( 30 transport , 3 brexit )
# ( 30 transport , 84 circumst )
# ( 30 transport , 85 secretari )
# ( 30 transport , 86 chri )
# ( 85 secretari , 84 circumst )
# ( 85 secretari , 30 transport )
# ( 85 secretari , 86 chri )
# ( 85 secretari , 87 grayl )
# ( 86 chri , 30 transport )
# ( 86 chri , 85 secretari )
# ( 86 chri , 87 grayl )
# ( 86 chri , 88 bbc )
# ( 87 grayl , 85 secretari )
# ( 87 grayl , 86 chri )
# ( 87 grayl , 88 bbc )
# ( 87 grayl , 58 week )
# ( 88 bbc , 86 chri )
# ( 88 bbc , 87 grayl )
# ( 58 week , 87 grayl )
# ( 58 week , 88 bbc )
# ( 89 event , 3 brexit )
# ( 89 event , 19 uk )
# ( 3 brexit , 89 event )
# ( 3 brexit , 19 uk )
# ( 3 brexit , 21 eu )
# ( 19 uk , 89 event )
# ( 19 uk , 3 brexit )
# ( 19 uk , 21 eu )
# ( 19 uk , 90 withdraw )
# ( 21 eu , 3 brexit )
# ( 21 eu , 19 uk )
# ( 21 eu , 90 withdraw )
# ( 21 eu , 91 agreement )
# ( 90 withdraw , 19 uk )
# ( 90 withdraw , 21 eu )
# ( 90 withdraw , 91 agreement )
# ( 90 withdraw , 92 transit )
# ( 91 agreement , 21 eu )
# ( 91 agreement , 90 withdraw )
# ( 91 agreement , 92 transit )
# ( 91 agreement , 93 period )
# ( 92 transit , 90 withdraw )
# ( 92 transit , 91 agreement )
# ( 92 transit , 93 period )
# ( 92 transit , 38 govern )
# ( 93 period , 91 agreement )
# ( 93 period , 92 transit )

# %%
word2vecProcessor.train()
