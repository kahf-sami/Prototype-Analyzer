# %%
import sys, os, json, re

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

dirPath = os.path.dirname(os.path.realpath("__file__"))
packagesPath = os.path.join(dirPath, 'packages')
print(packagesPath)

if not packagesPath in sys.path:
    sys.path.append(packagesPath)
    
# IPython extension to reload modules before executing user code.
# autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %reload_ext autoreload
# %autoreload 2
# Out:
# /notebooks/paper2/packages
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import packages.dataset as dataset

datasetPath = os.path.join(dirPath, 'datasets')
dataProcessor = dataset.Brexit(datasetPath)
dataProcessor.loadFilePaths()
# Out:
# Dataset path:
# /notebooks/paper2/datasets/brexit
# Total files 49
# -------------------------------
# Training file count:  39
# Total files in list:  39
# -------------------------------
# Total validation file count 4
# Total files in list:  4
# -------------------------------
# Total test file count 6
# Total files in list:  6
# -------------------------------

# %%
from packages.gc.word2vec import Word2Vec
word2vecProcessor = Word2Vec(dataProcessor)
#word2vecProcessor.train()

skipWindow = 2
word2vecProcessor.resetIndex()
word2vecProcessor.setSkipWindow(skipWindow)
word2vecProcessor.setBatchSize(128)

# %%
#print('The skip-gram pairs : target,context')
#for i in range(100):
#    print('(', x_batch[i], word2vecProcessor.id2Word[x_batch[i]],
#          ',', y_batch[i], word2vecProcessor.id2Word[y_batch[i]], ')')

# %%
word2vecProcessor.train()
# Out:
# Batches:  14
# --------------------------
#
# Average loss after epoch  0 :  12.48813956124442
#
# Average loss after epoch  0 :  12.710629832987882
#
# Average loss after epoch  0 :  12.26533490506275
#
# Average loss after epoch  0 :  11.438480909443657
#
# Average loss after epoch  0 :  10.90685194275044
#
# Average loss after epoch  0 :  10.77249739392972
#
# Average loss after epoch  0 :  10.847105177970425
#
# Average loss after epoch  0 :  11.087131919799228
#
# Average loss after epoch  0 :  11.552627865923158
#
# Average loss after epoch  0 :  11.007252306062034
#
# Average loss after epoch  0 :  10.372859722824186
#
# Average loss after epoch  0 :  11.11324281397684
#
# Average loss after epoch  0 :  11.067467260150133
#
# Average loss after epoch  0 :  10.807840112262397
# Similar to prices: Angela, SMMT, fac, cuckoo, sites,
# Similar to update: devastation, process, start, concessions, December,
# Similar to parliament: info, postBrexit, Motor, Malaysia, market,
# Similar to accession: rollout, minster, Czech, breakthrough, leap,
# Similar to Vince: District, journey, providers, Chris, patients,
# Similar to impact: shelflife, chatter, strain, sites, table,
# Similar to Man: clutches, councillor, Wales, 45000, intention,
# Similar to caption: preclearance, broadband, HMRC, desk, Several,
# --------------------------
#
# Average loss after epoch  1 :  8.0927734375
#
# Average loss after epoch  1 :  9.177440098353795
#
# Average loss after epoch  1 :  10.678168939084424
#
# Average loss after epoch  1 :  8.983273075203854
#
# Average loss after epoch  1 :  8.486509360456804
#
# Average loss after epoch  1 :  9.313564166964827
#
# Average loss after epoch  1 :  8.259967521935824
#
# Average loss after epoch  1 :  8.92890083478392
#
# Average loss after epoch  1 :  8.256115444846452
#
# Average loss after epoch  1 :  7.891930478552091
#
# Average loss after epoch  1 :  7.868479108366166
#
# Average loss after epoch  1 :  8.56813664773765
#
# Average loss after epoch  1 :  7.615322007692756
#
# Average loss after epoch  1 :  8.68936565191667
# Similar to prices: Angela, SMMT, fac, cuckoo, sites,
# Similar to update: devastation, process, concessions, start, December,
# Similar to parliament: postBrexit, info, Motor, Malaysia, market,
# Similar to accession: rollout, minster, Czech, breakthrough, leap,
# Similar to Vince: District, journey, providers, Chris, patients,
# Similar to impact: shelflife, chatter, strain, sites, table,
# Similar to Man: clutches, Wales, councillor, 45000, intention,
# Similar to caption: preclearance, Agreement, broadband, HMRC, desk,
# --------------------------
#
# Average loss after epoch  2 :  9.659123011997767
#
# Average loss after epoch  2 :  8.312616932148837
#
# Average loss after epoch  2 :  6.649868189419672
#
# Average loss after epoch  2 :  7.770293929685111
#
# Average loss after epoch  2 :  7.720155969865901
#
# Average loss after epoch  2 :  10.340384501474798
#
# Average loss after epoch  2 :  8.073335308280566
#
# Average loss after epoch  2 :  8.84684110670196
#
# Average loss after epoch  2 :  10.244801743391658
#
# Average loss after epoch  2 :  6.792278101299739
#
# Average loss after epoch  2 :  8.630290699165105
#
# Average loss after epoch  2 :  9.249696711142931
#
# Average loss after epoch  2 :  8.583053723647486
#
# Average loss after epoch  2 :  6.649898538679898
# Similar to prices: Angela, SMMT, fac, cuckoo, sites,
# Similar to update: devastation, process, concessions, start, preclearance,
# Similar to parliament: postBrexit, info, market, Secretary, days,
# Similar to accession: rollout, minster, Czech, breakthrough, leap,
# Similar to Vince: District, journey, providers, Chris, patients,
# Similar to impact: shelflife, chatter, strain, sites, table,
# Similar to Man: clutches, Wales, councillor, 45000, intention,
# Similar to caption: preclearance, Agreement, people, broadband, desk,
# --------------------------
#
# Average loss after epoch  3 :  7.250499180385044
#
# Average loss after epoch  3 :  8.997977354088608
#
# Average loss after epoch  3 :  6.846587528640257
#
# Average loss after epoch  3 :  6.540111498453378
#
# Average loss after epoch  3 :  7.2646067452159775
#
# Average loss after epoch  3 :  6.277397992438696
#
# Average loss after epoch  3 :  5.811471726371179
#
# Average loss after epoch  3 :  5.593007344991915
#
# Average loss after epoch  3 :  6.8486647789670565
#
# Average loss after epoch  3 :  7.106853043642737
#
# Average loss after epoch  3 :  6.274113487317952
#
# Average loss after epoch  3 :  6.606812941965233
#
# Average loss after epoch  3 :  6.47621600882899
#
# Average loss after epoch  3 :  6.682798431782985
# Similar to prices: Angela, SMMT, fac, cuckoo, sites,
# Similar to update: devastation, process, concessions, start, preclearance,
# Similar to parliament: postBrexit, days, market, Secretary, Mr,
# Similar to accession: rollout, minster, Czech, breakthrough, leap,
# Similar to Vince: District, journey, providers, Chris, patients,
# Similar to impact: shelflife, chatter, strain, sites, table,
# Similar to Man: clutches, Wales, councillor, 45000, intention,
# Similar to caption: preclearance, Agreement, people, broadband, desk,
# --------------------------
#
# Average loss after epoch  4 :  5.598178318568638
#
# Average loss after epoch  4 :  5.723736042879066
#
# Average loss after epoch  4 :  7.458703466476574
#
# Average loss after epoch  4 :  5.74210639994922
#
# Average loss after epoch  4 :  4.612883360755999
#
# Average loss after epoch  4 :  5.5531506390495355
#
# Average loss after epoch  4 :  5.923534153835569
#
# Average loss after epoch  4 :  5.835888164308568
#
# Average loss after epoch  4 :  5.030471002563615
#
# Average loss after epoch  4 :  5.746184155735571
#
# Average loss after epoch  4 :  6.031286975130667
#
# Average loss after epoch  4 :  4.94233858730007
#
# Average loss after epoch  4 :  5.8901902353093805
#
# Average loss after epoch  4 :  5.363648013808371
# Similar to prices: Angela, SMMT, fac, cuckoo, Just,
# Similar to update: devastation, process, concessions, start, preclearance,
# Similar to parliament: Mr, Secretary, days, market, postBrexit,
# Similar to accession: rollout, minster, Czech, breakthrough, leap,
# Similar to Vince: District, providers, journey, Chris, patients,
# Similar to impact: shelflife, chatter, strain, table, sites,
# Similar to Man: clutches, Wales, councillor, 45000, intention,
# Similar to caption: preclearance, Agreement, people, desk, broadband,
# --------------------------
#
# Average loss after epoch  5 :  5.1030409676688055
#
# Average loss after epoch  5 :  4.948073134130361
#
# Average loss after epoch  5 :  5.346697039923932
#
# Average loss after epoch  5 :  6.867202908334411
#
# Average loss after epoch  5 :  4.9788747621815315
#
# Average loss after epoch  5 :  4.897055801843185
#
# Average loss after epoch  5 :  5.150705554449457
#
# Average loss after epoch  5 :  6.0219967860809325
#
# Average loss after epoch  5 :  3.7893116339248656
#
# Average loss after epoch  5 :  4.72717157335652
#
# Average loss after epoch  5 :  4.265314283350801
#
# Average loss after epoch  5 :  3.6854208666923287
#
# Average loss after epoch  5 :  3.070238649553079
#
# Average loss after epoch  5 :  4.761510206099494
# Similar to prices: Angela, SMMT, fac, cuckoo, Just,
# Similar to update: devastation, process, concessions, start, preclearance,
# Similar to parliament: Mr, Secretary, days, market, postBrexit,
# Similar to accession: rollout, minster, Czech, breakthrough, leap,
# Similar to Vince: District, providers, journey, Chris, patients,
# Similar to impact: shelflife, chatter, strain, imports, table,
# Similar to Man: clutches, Wales, councillor, 45000, intention,
# Similar to caption: Agreement, preclearance, people, port, desk,
# --------------------------
#
# Average loss after epoch  6 :  5.0913238525390625
#
# Average loss after epoch  6 :  4.0308636256626675
#
# Average loss after epoch  6 :  4.4579251737010726
#
# Average loss after epoch  6 :  4.356673196175356
#
# Average loss after epoch  6 :  6.241794514884456
#
# Average loss after epoch  6 :  5.881481982996769
#
# Average loss after epoch  6 :  4.696773859555573
#
# Average loss after epoch  6 :  4.982903367897943
#
# Average loss after epoch  6 :  4.745542313841204
#
# Average loss after epoch  6 :  4.6615778907556775
#
# Average loss after epoch  6 :  3.5836009092587764
#
# Average loss after epoch  6 :  4.0924149858629315
#
# Average loss after epoch  6 :  4.429590506977095
#
# Average loss after epoch  6 :  4.107273803128107
# Similar to prices: Angela, SMMT, fac, cuckoo, Just,
# Similar to update: devastation, process, concessions, start, preclearance,
# Similar to parliament: Mr, Secretary, days, market, postBrexit,
# Similar to accession: rollout, minster, Czech, leap, breakthrough,
# Similar to Vince: District, providers, journey, Chris, patients,
# Similar to impact: shelflife, chatter, strain, imports, table,
# Similar to Man: clutches, Wales, councillor, 45000, intention,
# Similar to caption: Agreement, preclearance, people, port, desk,
# --------------------------
#
# Average loss after epoch  7 :  4.3001267569405695
#
# Average loss after epoch  7 :  3.165696942076391
#
# Average loss after epoch  7 :  4.4107501054991785
#
# Average loss after epoch  7 :  3.2736267840946676
#
# Average loss after epoch  7 :  5.125056571875903
#
# Average loss after epoch  7 :  4.309176534919149
#
# Average loss after epoch  7 :  3.2271223813655974
#
# Average loss after epoch  7 :  2.85519893361247
#
# Average loss after epoch  7 :  4.476092548166795
#
# Average loss after epoch  7 :  4.48965176308404
#
# Average loss after epoch  7 :  6.24122163821136
#
# Average loss after epoch  7 :  4.422250694582061
#
# Average loss after epoch  7 :  3.516619406040878
#
# Average loss after epoch  7 :  4.3357415001943265
# Similar to prices: Angela, SMMT, fac, cuckoo, Just,
# Similar to update: devastation, process, concessions, start, preclearance,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: rollout, minster, Czech, leap, breakthrough,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: shelflife, strain, chatter, imports, table,
# Similar to Man: clutches, Wales, 45000, councillor, intention,
# Similar to caption: Agreement, people, preclearance, port, UK,
# --------------------------
#
# Average loss after epoch  8 :  4.063272203717913
#
# Average loss after epoch  8 :  3.710904919371313
#
# Average loss after epoch  8 :  4.236722526327862
#
# Average loss after epoch  8 :  3.978939435125539
#
# Average loss after epoch  8 :  3.2194968902810097
#
# Average loss after epoch  8 :  2.4893354123812608
#
# Average loss after epoch  8 :  3.613507227854939
#
# Average loss after epoch  8 :  3.6754415345161453
#
# Average loss after epoch  8 :  4.051093767881175
#
# Average loss after epoch  8 :  2.689129400168131
#
# Average loss after epoch  8 :  3.2146500553342747
#
# Average loss after epoch  8 :  3.515996994047314
#
# Average loss after epoch  8 :  2.2685485610982457
#
# Average loss after epoch  8 :  3.1462991970608676
# Similar to prices: Angela, SMMT, fac, cuckoo, Just,
# Similar to update: devastation, process, concessions, start, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: rollout, minster, Czech, leap, system,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: shelflife, strain, imports, chatter, table,
# Similar to Man: clutches, Wales, 45000, intention, councillor,
# Similar to caption: Agreement, people, preclearance, port, UK,
# --------------------------
#
# Average loss after epoch  9 :  3.258692060198103
#
# Average loss after epoch  9 :  2.9623665323062816
# Average loss after epoch  9 :  4.061233142374556
#
# Average loss after epoch  9 :  3.037203897986994
#
# Average loss after epoch  9 :  2.809628290076638
#
# Average loss after epoch  9 :  3.7730405530858313
#
# Average loss after epoch  9 :  2.546391335282498
#
# Average loss after epoch  9 :  3.4071214431207646
#
# Average loss after epoch  9 :  1.9022493208709308
#
# Average loss after epoch  9 :  2.023084980002918
#
# Average loss after epoch  9 :  2.7355770626062355
#
# Average loss after epoch  9 :  2.3020654715128894
#
# Average loss after epoch  9 :  4.680302388590206
#
# Average loss after epoch  9 :  3.118684275315037
# Similar to prices: Angela, SMMT, fac, cuckoo, Brexit,
# Similar to update: devastation, process, concessions, start, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: minster, rollout, Czech, leap, system,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: shelflife, imports, strain, chatter, table,
# Similar to Man: clutches, Wales, 45000, intention, councillor,
# Similar to caption: Agreement, people, preclearance, port, Channel,
# --------------------------
#
# Average loss after epoch  10 :  2.3963143484933034
#
# Average loss after epoch  10 :  3.3693900594905934
#
# Average loss after epoch  10 :  3.076652087553597
#
# Average loss after epoch  10 :  3.3170007664379804
#
# Average loss after epoch  10 :  3.5227595326334047
#
# Average loss after epoch  10 :  3.1547696998930386
#
# Average loss after epoch  10 :  3.910911545946601
#
# Average loss after epoch  10 :  2.8050618842807844
#
# Average loss after epoch  10 :  1.7607419538751063
#
# Average loss after epoch  10 :  2.5182167976261236
#
# Average loss after epoch  10 :  2.7341999119886404
#
# Average loss after epoch  10 :  2.874058069972542
#
# Average loss after epoch  10 :  3.2057912223529494
#
# Average loss after epoch  10 :  1.7316338496051493
# Similar to prices: Angela, SMMT, fac, cuckoo, Brexit,
# Similar to update: devastation, process, concessions, start, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: minster, Czech, rollout, system, leap,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: shelflife, imports, strain, chatter, table,
# Similar to Man: clutches, Wales, 45000, intention, councillor,
# Similar to caption: Agreement, people, preclearance, port, Channel,
# --------------------------
#
# Average loss after epoch  11 :  2.1090502057756697
#
# Average loss after epoch  11 :  1.943033588175871
#
# Average loss after epoch  11 :  2.299363026466036
#
# Average loss after epoch  11 :  2.6876820758301636
#
# Average loss after epoch  11 :  1.987901614076457
#
# Average loss after epoch  11 :  1.3872335926384132
#
# Average loss after epoch  11 :  1.7464408773445685
#
# Average loss after epoch  11 :  2.3234669814383957
#
# Average loss after epoch  11 :  2.917944207431844
#
# Average loss after epoch  11 :  2.0468564895392864
#
# Average loss after epoch  11 :  1.7990089546186685
#
# Average loss after epoch  11 :  2.316473525837369
#
# Average loss after epoch  11 :  2.022718875328367
#
# Average loss after epoch  11 :  1.931136435605207
# Similar to prices: Angela, SMMT, fac, Brexit, cuckoo,
# Similar to update: devastation, process, concessions, start, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: minster, Czech, system, rollout, leap,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: shelflife, imports, strain, chatter, states,
# Similar to Man: clutches, Wales, 45000, intention, councillor,
# Similar to caption: Agreement, people, preclearance, port, Channel,
# --------------------------
#
# Average loss after epoch  12 :  1.8746881484985352
#
# Average loss after epoch  12 :  1.401672295161656
#
# Average loss after epoch  12 :  1.9547221271359192
#
# Average loss after epoch  12 :  2.623132890236968
#
# Average loss after epoch  12 :  2.2253144259802355
#
# Average loss after epoch  12 :  1.444337797133354
#
# Average loss after epoch  12 :  2.897451806066166
#
# Average loss after epoch  12 :  2.1554809587340786
#
# Average loss after epoch  12 :  1.6022372655722443
#
# Average loss after epoch  12 :  1.807304214953333
#
# Average loss after epoch  12 :  2.440434852634083
#
# Average loss after epoch  12 :  2.2595951499963243
#
# Average loss after epoch  12 :  1.444163543428867
#
# Average loss after epoch  12 :  2.119066731024774
# Similar to prices: Angela, SMMT, fac, Brexit, cuckoo,
# Similar to update: devastation, process, concessions, start, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: minster, Czech, system, leap, rollout,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: shelflife, imports, strain, chatter, states,
# Similar to Man: clutches, 45000, intention, Wales, councillor,
# Similar to caption: Agreement, people, port, preclearance, Channel,
# --------------------------
#
# Average loss after epoch  13 :  2.840310505458287
#
# Average loss after epoch  13 :  1.9843047978926678
#
# Average loss after epoch  13 :  1.6263951156994345
#
# Average loss after epoch  13 :  1.7342118457276243
#
# Average loss after epoch  13 :  2.338267797766119
#
# Average loss after epoch  13 :  2.646427392572022
#
# Average loss after epoch  13 :  2.0813518421713693
#
# Average loss after epoch  13 :  1.8753896160981782
#
# Average loss after epoch  13 :  2.0177303410999956
#
# Average loss after epoch  13 :  2.2139584411995252
#
# Average loss after epoch  13 :  2.3846384924779094
#
# Average loss after epoch  13 :  1.9320868554720547
#
# Average loss after epoch  13 :  1.2872883869282494
#
# Average loss after epoch  13 :  2.29502539686555
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, start, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: minster, Czech, system, leap, rollout,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: imports, shelflife, strain, chatter, states,
# Similar to Man: clutches, 45000, intention, Wales, councillor,
# Similar to caption: Agreement, people, port, preclearance, Channel,
# --------------------------
#
# Average loss after epoch  14 :  1.582543236868722
#
# Average loss after epoch  14 :  2.1616648849175903
#
# Average loss after epoch  14 :  1.7435146003700903
#
# Average loss after epoch  14 :  2.163339040320101
#
# Average loss after epoch  14 :  2.3346220696001523
#
# Average loss after epoch  14 :  1.435065723913264
#
# Average loss after epoch  14 :  1.4514598489841786
#
# Average loss after epoch  14 :  1.967940736675837
#
# Average loss after epoch  14 :  1.135455773619284
#
# Average loss after epoch  14 :  1.293140797838389
#
# Average loss after epoch  14 :  1.5729340420610012
#
# Average loss after epoch  14 :  2.3950400274881742
#
# Average loss after epoch  14 :  2.6670508719759964
#
# Average loss after epoch  14 :  1.580940623633051
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, start, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: minster, system, Czech, leap, USChina,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: imports, strain, shelflife, chatter, states,
# Similar to Man: clutches, 45000, intention, Wales, councillor,
# Similar to caption: Agreement, people, port, preclearance, response,
# --------------------------
#
# Average loss after epoch  15 :  1.4607643399919783
#
# Average loss after epoch  15 :  0.754871533841503
#
# Average loss after epoch  15 :  1.0498844673612722
#
# Average loss after epoch  15 :  1.370335010477326
#
# Average loss after epoch  15 :  2.465959031510099
#
# Average loss after epoch  15 :  1.675423857649717
#
# Average loss after epoch  15 :  0.906612344943381
#
# Average loss after epoch  15 :  1.1673128908846275
#
# Average loss after epoch  15 :  1.638015902510523
#
# Average loss after epoch  15 :  1.8080056165280258
#
# Average loss after epoch  15 :  0.9466617650547363
#
# Average loss after epoch  15 :  1.9348741808587506
#
# Average loss after epoch  15 :  1.4528614200229744
#
# Average loss after epoch  15 :  2.017094994705882
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: system, minster, Czech, leap, USChina,
# Similar to Vince: District, providers, journey, Chris, country,
# Similar to impact: imports, strain, shelflife, chatter, states,
# Similar to Man: clutches, intention, 45000, Wales, councillor,
# Similar to caption: Agreement, people, port, preclearance, response,
# --------------------------
#
# Average loss after epoch  16 :  1.4591576712472099
#
# Average loss after epoch  16 :  1.3261275778011399
#
# Average loss after epoch  16 :  1.5293784516893392
#
# Average loss after epoch  16 :  0.735363588289438
#
# Average loss after epoch  16 :  1.4199638782197535
#
# Average loss after epoch  16 :  0.8512900245917291
#
# Average loss after epoch  16 :  1.7934269420641693
#
# Average loss after epoch  16 :  1.5020883048740032
#
# Average loss after epoch  16 :  0.8475129772166908
# Average loss after epoch  16 :  1.0307036650247554
#
# Average loss after epoch  16 :  1.449020326223169
#
# Average loss after epoch  16 :  0.9175085297713814
#
# Average loss after epoch  16 :  2.296801800326862
#
# Average loss after epoch  16 :  1.8554193799549878
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, Dover, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: system, minster, Czech, leap, USChina,
# Similar to Vince: District, providers, journey, Chris, country,
# Similar to impact: imports, strain, shelflife, chatter, states,
# Similar to Man: clutches, intention, 45000, Wales, councillor,
# Similar to caption: Agreement, people, port, preclearance, response,
# --------------------------
#
# Average loss after epoch  17 :  1.573155130658831
#
# Average loss after epoch  17 :  1.1942230438699526
#
# Average loss after epoch  17 :  0.9506642220666734
#
# Average loss after epoch  17 :  0.7015351354951712
#
# Average loss after epoch  17 :  1.6917877814590578
#
# Average loss after epoch  17 :  1.255694938709478
#
# Average loss after epoch  17 :  1.1862208213841732
#
# Average loss after epoch  17 :  1.146706627709779
#
# Average loss after epoch  17 :  1.1261383498639659
#
# Average loss after epoch  17 :  0.650598706269057
#
# Average loss after epoch  17 :  1.1876755570701043
#
# Average loss after epoch  17 :  0.9086397773831464
#
# Average loss after epoch  17 :  1.353581555448894
#
# Average loss after epoch  17 :  1.301663884645624
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, Dover, December,
# Similar to parliament: Mr, Secretary, days, market, future,
# Similar to accession: system, Czech, minster, leap, USChina,
# Similar to Vince: District, providers, journey, Chris, country,
# Similar to impact: imports, strain, shelflife, chatter, states,
# Similar to Man: clutches, intention, 45000, Wales, beginning,
# Similar to caption: Agreement, people, port, response, preclearance,
# --------------------------
#
# Average loss after epoch  18 :  1.0421758379255022
#
# Average loss after epoch  18 :  1.1736239413825833
#
# Average loss after epoch  18 :  1.379735122269166
#
# Average loss after epoch  18 :  0.9100234941461095
#
# Average loss after epoch  18 :  1.3492734633444208
#
# Average loss after epoch  18 :  1.3875225456169564
#
# Average loss after epoch  18 :  1.2405709430689706
#
# Average loss after epoch  18 :  1.056204381479501
#
# Average loss after epoch  18 :  0.9362034501698527
#
# Average loss after epoch  18 :  1.3589443798722747
#
# Average loss after epoch  18 :  1.154111212462626
#
# Average loss after epoch  18 :  1.0358284077453075
#
# Average loss after epoch  18 :  0.7333873209599048
#
# Average loss after epoch  18 :  0.8955677130197016
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, Dover, December,
# Similar to parliament: Secretary, Mr, market, days, future,
# Similar to accession: system, Czech, leap, minster, USChina,
# Similar to Vince: District, providers, journey, Chris, country,
# Similar to impact: imports, strain, shelflife, states, chatter,
# Similar to Man: intention, clutches, 45000, Wales, beginning,
# Similar to caption: Agreement, people, desk, response, port,
# --------------------------
#
# Average loss after epoch  19 :  0.6508236612592425
#
# Average loss after epoch  19 :  0.9608779683405039
#
# Average loss after epoch  19 :  1.6087579438707225
#
# Average loss after epoch  19 :  0.95291566642708
#
# Average loss after epoch  19 :  1.4988978588812312
#
# Average loss after epoch  19 :  0.89470674795929
#
# Average loss after epoch  19 :  1.0654132722410583
#
# Average loss after epoch  19 :  1.9070916030988312
#
# Average loss after epoch  19 :  1.1935088624144254
#
# Average loss after epoch  19 :  0.5976400885524116
#
# Average loss after epoch  19 :  0.9301370929645766
#
# Average loss after epoch  19 :  1.164402514348195
#
# Average loss after epoch  19 :  1.0067260967585137
#
# Average loss after epoch  19 :  1.288042942022232
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, Dover, December,
# Similar to parliament: Secretary, Mr, market, days, future,
# Similar to accession: system, Czech, leap, minster, USChina,
# Similar to Vince: District, providers, journey, Chris, country,
# Similar to impact: imports, strain, shelflife, states, table,
# Similar to Man: intention, 45000, clutches, Wales, beginning,
# Similar to caption: Agreement, people, desk, response, preclearance,
# --------------------------
#
# Average loss after epoch  20 :  1.2751508440290178
#
# Average loss after epoch  20 :  0.9235522795696648
#
# Average loss after epoch  20 :  0.9992335697652299
#
# Average loss after epoch  20 :  1.3701499080419641
#
# Average loss after epoch  20 :  0.8553029680235053
#
# Average loss after epoch  20 :  1.6133909337859982
#
# Average loss after epoch  20 :  0.5194272321827471
#
# Average loss after epoch  20 :  1.2786008922994652
#
# Average loss after epoch  20 :  0.9180592270744735
#
# Average loss after epoch  20 :  0.8672273412492509
#
# Average loss after epoch  20 :  0.44231106734805614
#
# Average loss after epoch  20 :  1.2691804865261866
#
# Average loss after epoch  20 :  0.6003884722736688
#
# Average loss after epoch  20 :  1.220159731095371
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, Dover, December,
# Similar to parliament: Secretary, market, Mr, days, future,
# Similar to accession: system, Czech, leap, minster, USChina,
# Similar to Vince: District, providers, journey, Chris, country,
# Similar to impact: imports, strain, shelflife, states, table,
# Similar to Man: intention, 45000, clutches, Wales, beginning,
# Similar to caption: Agreement, people, desk, response, Channel,
# --------------------------
#
# Average loss after epoch  21 :  0.5908760343279157
#
# Average loss after epoch  21 :  0.9167805009958696
#
# Average loss after epoch  21 :  1.4345971537053412
#
# Average loss after epoch  21 :  0.6167891464944385
#
# Average loss after epoch  21 :  0.5088711327194863
#
# Average loss after epoch  21 :  0.5963965182210696
#
# Average loss after epoch  21 :  0.8525603890752913
#
# Average loss after epoch  21 :  1.08989132217237
#
# Average loss after epoch  21 :  0.6548702977751469
#
# Average loss after epoch  21 :  1.1227823855100272
#
# Average loss after epoch  21 :  0.6870380580540086
#
# Average loss after epoch  21 :  0.6743662438230542
#
# Average loss after epoch  21 :  0.6184628526471686
#
# Average loss after epoch  21 :  0.7854771821279087
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, Dover,
# Similar to parliament: Secretary, market, Mr, days, future,
# Similar to accession: system, Czech, leap, minster, USChina,
# Similar to Vince: District, providers, journey, Chris, country,
# Similar to impact: imports, strain, shelflife, states, table,
# Similar to Man: intention, 45000, clutches, Wales, beginning,
# Similar to caption: Agreement, people, desk, response, Channel,
# --------------------------
#
# Average loss after epoch  22 :  1.0891616003853934
#
# Average loss after epoch  22 :  1.0044579311292998
#
# Average loss after epoch  22 :  0.9724944305141883
#
# Average loss after epoch  22 :  0.7457984733561683
#
# Average loss after epoch  22 :  0.49034206390366675
#
# Average loss after epoch  22 :  0.675897933414994
#
# Average loss after epoch  22 :  0.8707283123172053
#
# Average loss after epoch  22 :  1.1869798940124734
#
# Average loss after epoch  22 :  0.42073962547738375
#
# Average loss after epoch  22 :  0.8120405655945759
#
# Average loss after epoch  22 :  0.9178284405373776
#
# Average loss after epoch  22 :  0.6861773133185878
#
# Average loss after epoch  22 :  0.48863234264444294
#
# Average loss after epoch  22 :  0.9822757685062368
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, Dover,
# Similar to parliament: Secretary, market, Mr, days, future,
# Similar to accession: system, Czech, leap, minster, USChina,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: imports, strain, shelflife, table, states,
# Similar to Man: intention, 45000, clutches, Wales, beginning,
# Similar to caption: Agreement, people, desk, response, Channel,
# --------------------------
#
# Average loss after epoch  23 :  0.9046637671334403
#
# Average loss after epoch  23 :  0.7213633887621821
#
# Average loss after epoch  23 :  0.4910815672693725
#
# Average loss after epoch  23 :  0.5171310115188223
#
# Average loss after epoch  23 :  0.5144735177949061
#
# Average loss after epoch  23 :  1.1969362383839273
#
# Average loss after epoch  23 :  0.40320155369211363
#
# Average loss after epoch  23 :  0.8930741359413871
#
# Average loss after epoch  23 :  0.555034780854421
#
# Average loss after epoch  23 :  0.41129671848632304
#
# Average loss after epoch  23 :  0.9152547201349746
#
# Average loss after epoch  23 :  0.5887179465580158
#
# Average loss after epoch  23 :  0.5640103823477893
#
# Average loss after epoch  23 :  0.7205473866245212
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, minster, USChina,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: imports, strain, shelflife, table, states,
# Similar to Man: intention, 45000, clutches, Wales, beginning,
# Similar to caption: Agreement, people, desk, response, Channel,
# --------------------------
#
# Average loss after epoch  24 :  0.6810476439339774
#
# Average loss after epoch  24 :  0.5459395622720524
#
# Average loss after epoch  24 :  0.427159726445946
#
# Average loss after epoch  24 :  0.9801104026057234
#
# Average loss after epoch  24 :  0.5181516405870369
#
# Average loss after epoch  24 :  0.5806750484657419
#
# Average loss after epoch  24 :  0.4189623709828522
#
# Average loss after epoch  24 :  0.4936999857163916
#
# Average loss after epoch  24 :  0.8731708496790308
#
# Average loss after epoch  24 :  0.2894507133533641
# Average loss after epoch  24 :  0.6695203829632634
#
# Average loss after epoch  24 :  0.7751366754999219
#
# Average loss after epoch  24 :  0.5406089315856529
#
# Average loss after epoch  24 :  1.1415932894465828
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: imports, strain, table, shelflife, states,
# Similar to Man: intention, 45000, clutches, Wales, beginning,
# Similar to caption: Agreement, people, desk, response, preclearance,
# --------------------------
#
# Average loss after epoch  25 :  0.48835250309535433
#
# Average loss after epoch  25 :  0.46749756774123835
#
# Average loss after epoch  25 :  0.6520823566976164
#
# Average loss after epoch  25 :  0.6675177239865275
#
# Average loss after epoch  25 :  0.5037589117422715
#
# Average loss after epoch  25 :  0.7180695877510523
#
# Average loss after epoch  25 :  0.4629884131326435
#
# Average loss after epoch  25 :  0.8239871800483278
#
# Average loss after epoch  25 :  0.8369219086038286
#
# Average loss after epoch  25 :  0.5169167673408078
#
# Average loss after epoch  25 :  0.5629517702532602
#
# Average loss after epoch  25 :  0.6391476709805273
#
# Average loss after epoch  25 :  0.7388834209609766
#
# Average loss after epoch  25 :  0.4237557766790102
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: imports, strain, table, states, shelflife,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, response, shakeup,
# --------------------------
#
# Average loss after epoch  26 :  0.41644218989780973
#
# Average loss after epoch  26 :  0.9084357047567562
#
# Average loss after epoch  26 :  0.42284555963455067
#
# Average loss after epoch  26 :  0.4540138725239453
#
# Average loss after epoch  26 :  0.36376592434444893
#
# Average loss after epoch  26 :  0.6884017139084274
#
# Average loss after epoch  26 :  0.29522092107794917
#
# Average loss after epoch  26 :  0.7228533589867341
#
# Average loss after epoch  26 :  0.755142939686971
#
# Average loss after epoch  26 :  0.7991882571578166
#
# Average loss after epoch  26 :  0.4855007189299389
#
# Average loss after epoch  26 :  0.7150996345692144
#
# Average loss after epoch  26 :  0.3819589147852522
#
# Average loss after epoch  26 :  0.5803427662869768
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: imports, strain, table, states, shelflife,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, response, shakeup,
# --------------------------
#
# Average loss after epoch  27 :  0.6901929037911552
#
# Average loss after epoch  27 :  0.680702053770727
#
# Average loss after epoch  27 :  0.4340234713373657
#
# Average loss after epoch  27 :  0.36113634078714163
#
# Average loss after epoch  27 :  1.067500925042099
#
# Average loss after epoch  27 :  0.32617693969024547
#
# Average loss after epoch  27 :  1.0661046376032584
#
# Average loss after epoch  27 :  0.6554940589141488
#
# Average loss after epoch  27 :  0.3567857972771756
#
# Average loss after epoch  27 :  0.3088142888318274
#
# Average loss after epoch  27 :  0.3989223924177798
#
# Average loss after epoch  27 :  0.4025550873996098
#
# Average loss after epoch  27 :  0.3127711911422956
#
# Average loss after epoch  27 :  1.0498479682733826
# Similar to prices: Angela, SMMT, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, shelflife,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, response, shakeup,
# --------------------------
#
# Average loss after epoch  28 :  0.3963442189352853
#
# Average loss after epoch  28 :  0.9833086583079124
#
# Average loss after epoch  28 :  0.42706389833817326
#
# Average loss after epoch  28 :  0.46042561219514083
#
# Average loss after epoch  28 :  0.7314045937901315
#
# Average loss after epoch  28 :  0.647933026949888
#
# Average loss after epoch  28 :  0.3347392096973832
#
# Average loss after epoch  28 :  0.4461150511024777
#
# Average loss after epoch  28 :  0.32562981577088707
#
# Average loss after epoch  28 :  0.3095216485229066
#
# Average loss after epoch  28 :  0.49706700680062127
#
# Average loss after epoch  28 :  0.500509775279111
#
# Average loss after epoch  28 :  0.7317464377623333
#
# Average loss after epoch  28 :  0.3447463684574588
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, response, shakeup,
# --------------------------
#
# Average loss after epoch  29 :  0.3518588202340262
#
# Average loss after epoch  29 :  0.3587522993282396
#
# Average loss after epoch  29 :  0.6921474627781192
#
# Average loss after epoch  29 :  0.659970434592794
#
# Average loss after epoch  29 :  0.39904867978937786
#
# Average loss after epoch  29 :  0.4161858469049472
#
# Average loss after epoch  29 :  0.31864660062818545
#
# Average loss after epoch  29 :  0.30711042389871734
#
# Average loss after epoch  29 :  0.5840557724986771
#
# Average loss after epoch  29 :  0.29085267378286445
#
# Average loss after epoch  29 :  0.42177231878992766
#
# Average loss after epoch  29 :  0.3378902388264429
#
# Average loss after epoch  29 :  0.6722905019397515
#
# Average loss after epoch  29 :  0.6481432700403743
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, leap, Czech, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, response, shakeup,
# --------------------------
#
# Average loss after epoch  30 :  0.30635169574192594
#
# Average loss after epoch  30 :  0.2928830239237571
#
# Average loss after epoch  30 :  0.33594561370399184
#
# Average loss after epoch  30 :  0.7433391644501874
#
# Average loss after epoch  30 :  0.4896914351124436
#
# Average loss after epoch  30 :  0.31905076750785727
#
# Average loss after epoch  30 :  0.2834719233915001
#
# Average loss after epoch  30 :  0.6097792118305592
#
# Average loss after epoch  30 :  0.2497277666381046
#
# Average loss after epoch  30 :  0.26180580974512896
#
# Average loss after epoch  30 :  0.5714041361644818
#
# Average loss after epoch  30 :  0.5869615189336237
#
# Average loss after epoch  30 :  0.6074273764526738
#
# Average loss after epoch  30 :  0.3378639744820758
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, shakeup, response,
# --------------------------
#
# Average loss after epoch  31 :  0.33734399931771414
#
# Average loss after epoch  31 :  0.37737385350830704
#
# Average loss after epoch  31 :  0.3133916627213837
#
# Average loss after epoch  31 :  0.854972633370654
#
# Average loss after epoch  31 :  1.0070605130883126
#
# Average loss after epoch  31 :  0.352463857417249
#
# Average loss after epoch  31 :  0.5765717466732535
#
# Average loss after epoch  31 :  0.3818078242601431
#
# Average loss after epoch  31 :  0.9217268072626525
#
# Average loss after epoch  31 :  0.4495341511217011
#
# Average loss after epoch  31 :  0.3811350701227589
#
# Average loss after epoch  31 :  0.6814202640594103
#
# Average loss after epoch  31 :  0.3215214821138627
#
# Average loss after epoch  31 :  0.5853327144642575
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, shakeup, response,
# --------------------------
#
# Average loss after epoch  32 :  0.3746683256966727
#
# Average loss after epoch  32 :  0.568988678406696
#
# Average loss after epoch  32 :  0.6555243132760851
#
# Average loss after epoch  32 :  0.3273387338309822
#
# Average loss after epoch  32 :  0.30329682419406045
#
# Average loss after epoch  32 :  0.2389442083308432
#
# Average loss after epoch  32 :  0.24715150507482272
#
# Average loss after epoch  32 :  0.3255643597047899
#
# Average loss after epoch  32 :  0.29466691862118655
#
# Average loss after epoch  32 :  0.2791536984348385
#
# Average loss after epoch  32 :  0.3343622254296718
#
# Average loss after epoch  32 :  0.25393918275098415
#
# Average loss after epoch  32 :  0.26754069549644305
# Average loss after epoch  32 :  0.330172590005117
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, shakeup, response,
# --------------------------
#
# Average loss after epoch  33 :  0.35783168247767855
#
# Average loss after epoch  33 :  0.2950358366479679
#
# Average loss after epoch  33 :  0.26470153654977113
#
# Average loss after epoch  33 :  0.5805632849004754
#
# Average loss after epoch  33 :  0.5967836194057329
#
# Average loss after epoch  33 :  0.2864403200491487
#
# Average loss after epoch  33 :  0.3028656547434573
#
# Average loss after epoch  33 :  0.9062454126077567
#
# Average loss after epoch  33 :  0.30728106429035945
#
# Average loss after epoch  33 :  0.3138781649228047
#
# Average loss after epoch  33 :  0.29638003353814363
#
# Average loss after epoch  33 :  0.2742793553248332
#
# Average loss after epoch  33 :  0.31024205679819195
#
# Average loss after epoch  33 :  0.2667585696458286
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, Czech, leap, USChina, minster,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, shakeup, response,
# --------------------------
#
# Average loss after epoch  34 :  0.35882554735456196
#
# Average loss after epoch  34 :  0.2878057518783881
#
# Average loss after epoch  34 :  0.26050480461676684
#
# Average loss after epoch  34 :  0.2646361648018586
#
# Average loss after epoch  34 :  0.28235918325310255
#
# Average loss after epoch  34 :  0.2751199220206945
#
# Average loss after epoch  34 :  0.2461365050828642
#
# Average loss after epoch  34 :  0.3897033985651404
#
# Average loss after epoch  34 :  0.5699855689221682
#
# Average loss after epoch  34 :  0.2691940197207677
#
# Average loss after epoch  34 :  0.3972265644361444
#
# Average loss after epoch  34 :  0.2509463679470467
#
# Average loss after epoch  34 :  0.2709833443993461
#
# Average loss after epoch  34 :  0.2912841273264809
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, leap, Czech, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, clutches, beginning, Wales,
# Similar to caption: Agreement, people, desk, shakeup, response,
# --------------------------
#
# Average loss after epoch  35 :  0.3005694661821638
#
# Average loss after epoch  35 :  0.7776673813255466
#
# Average loss after epoch  35 :  0.32962484714241136
#
# Average loss after epoch  35 :  0.6390048915125439
#
# Average loss after epoch  35 :  0.36920862151027795
#
# Average loss after epoch  35 :  0.25410822796881277
#
# Average loss after epoch  35 :  0.2301771667514955
#
# Average loss after epoch  35 :  0.2631946804049094
#
# Average loss after epoch  35 :  0.2272845081057043
#
# Average loss after epoch  35 :  0.3561233166538952
#
# Average loss after epoch  35 :  0.3105200605994412
#
# Average loss after epoch  35 :  0.8207203240437588
#
# Average loss after epoch  35 :  0.5634545690335211
#
# Average loss after epoch  35 :  0.628658971662446
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Secretary, market, days, Mr, future,
# Similar to accession: system, leap, Czech, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, beginning, clutches, Wales,
# Similar to caption: Agreement, people, desk, shakeup, response,
# --------------------------
#
# Average loss after epoch  36 :  0.2772792748042515
#
# Average loss after epoch  36 :  0.29718512418318765
#
# Average loss after epoch  36 :  0.30910929194692277
#
# Average loss after epoch  36 :  0.2662434806082955
#
# Average loss after epoch  36 :  0.2860409718869294
#
# Average loss after epoch  36 :  0.3358190194632195
#
# Average loss after epoch  36 :  0.22437158749121697
#
# Average loss after epoch  36 :  0.3437033490947444
#
# Average loss after epoch  36 :  0.5413805132580056
#
# Average loss after epoch  36 :  0.2400634706408655
#
# Average loss after epoch  36 :  0.25635172937874906
#
# Average loss after epoch  36 :  0.24669163710628586
#
# Average loss after epoch  36 :  0.2897232893582999
#
# Average loss after epoch  36 :  0.2505052694499267
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Secretary, days, Mr, future,
# Similar to accession: system, leap, Czech, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, beginning, clutches, Wales,
# Similar to caption: Agreement, people, desk, shakeup, response,
# --------------------------
#
# Average loss after epoch  37 :  0.29162665775844027
#
# Average loss after epoch  37 :  0.2743651161388475
#
# Average loss after epoch  37 :  0.26122131865504183
#
# Average loss after epoch  37 :  0.24617831403391902
#
# Average loss after epoch  37 :  0.2886523636284168
#
# Average loss after epoch  37 :  0.43693003932707863
#
# Average loss after epoch  37 :  0.2301816499517598
#
# Average loss after epoch  37 :  0.2841473445742346
#
# Average loss after epoch  37 :  0.21804060840499553
#
# Average loss after epoch  37 :  0.25784737035198735
#
# Average loss after epoch  37 :  0.4073287803250861
#
# Average loss after epoch  37 :  0.2965972378021075
#
# Average loss after epoch  37 :  0.2177733520252761
#
# Average loss after epoch  37 :  0.23784555097125298
# Similar to prices: SMMT, Angela, fac, Brexit, check,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Secretary, days, Mr, Motor,
# Similar to accession: system, leap, Czech, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, imports, table, states, chaos,
# Similar to Man: intention, 45000, beginning, clutches, Wales,
# Similar to caption: Agreement, people, desk, shakeup, Scottish,
# --------------------------
#
# Average loss after epoch  38 :  0.2670929431915283
#
# Average loss after epoch  38 :  0.24190635340554373
#
# Average loss after epoch  38 :  0.24736123060693546
#
# Average loss after epoch  38 :  0.2654173918959003
#
# Average loss after epoch  38 :  0.19044013071909194
#
# Average loss after epoch  38 :  0.24678769796295866
#
# Average loss after epoch  38 :  0.21216274378498673
#
# Average loss after epoch  38 :  0.8497631046586095
#
# ...
#
# Average loss after epoch  487 :  0.1200272662603336
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, Oxford, states,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  488 :  0.1964461122240339
#
# Average loss after epoch  488 :  0.15046225640238547
#
# Average loss after epoch  488 :  0.12736614165778756
#
# Average loss after epoch  488 :  0.12541175429173582
#
# Average loss after epoch  488 :  0.07982624041477007
#
# Average loss after epoch  488 :  0.10794164486402498
#
# Average loss after epoch  488 :  0.13633487178291184
#
# Average loss after epoch  488 :  0.1296860473165947
#
# Average loss after epoch  488 :  0.09289800621789153
#
# Average loss after epoch  488 :  0.09697562420490345
#
# Average loss after epoch  488 :  0.09399107096033646
#
# Average loss after epoch  488 :  0.10221079630329308
#
# Average loss after epoch  488 :  0.11680095794844776
#
# Average loss after epoch  488 :  0.11773124294837893
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  489 :  0.20117175579071045
#
# Average loss after epoch  489 :  0.14776976619447982
#
# Average loss after epoch  489 :  0.12336239340353986
# Average loss after epoch  489 :  0.13680513211832798
#
# Average loss after epoch  489 :  0.08763570977729442
#
# Average loss after epoch  489 :  0.12310295118709538
#
# Average loss after epoch  489 :  0.1294133697335352
#
# Average loss after epoch  489 :  0.09744145213411272
#
# Average loss after epoch  489 :  0.10593344607441625
#
# Average loss after epoch  489 :  0.12215657024049263
#
# Average loss after epoch  489 :  0.1265871148652005
#
# Average loss after epoch  489 :  0.10947749175731744
#
# Average loss after epoch  489 :  0.10490336386795866
#
# Average loss after epoch  489 :  0.10054949519778719
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  490 :  0.19231438636779785
#
# Average loss after epoch  490 :  0.15503982135227748
#
# Average loss after epoch  490 :  0.14978868864020525
#
# Average loss after epoch  490 :  0.12827286202427945
#
# Average loss after epoch  490 :  0.09249055178301477
#
# Average loss after epoch  490 :  0.10946521573927924
#
# Average loss after epoch  490 :  0.14132059288427015
#
# Average loss after epoch  490 :  0.11855264268631367
#
# Average loss after epoch  490 :  0.11580390288880513
#
# Average loss after epoch  490 :  0.09614710761993488
#
# Average loss after epoch  490 :  0.09095449444359922
#
# Average loss after epoch  490 :  0.11456199713881979
#
# Average loss after epoch  490 :  0.11442146714836088
#
# Average loss after epoch  490 :  0.0870291065717806
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  491 :  0.1945539883204869
#
# Average loss after epoch  491 :  0.145345680567683
#
# Average loss after epoch  491 :  0.12037563271842266
#
# Average loss after epoch  491 :  0.13845011162440116
#
# Average loss after epoch  491 :  0.12573528046244678
#
# Average loss after epoch  491 :  0.11311335205665252
#
# Average loss after epoch  491 :  0.10310811289692991
#
# Average loss after epoch  491 :  0.1166190380770146
#
# Average loss after epoch  491 :  0.12587385003707366
#
# Average loss after epoch  491 :  0.1116267475520866
#
# Average loss after epoch  491 :  0.08752094871256534
#
# Average loss after epoch  491 :  0.12674947236723402
#
# Average loss after epoch  491 :  0.1148174544563937
#
# Average loss after epoch  491 :  0.0953619617819151
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  492 :  0.17361458710261754
#
# Average loss after epoch  492 :  0.12691553758115184
#
# Average loss after epoch  492 :  0.11311507815869835
#
# Average loss after epoch  492 :  0.11954112606016808
#
# Average loss after epoch  492 :  0.0820607427733058
#
# Average loss after epoch  492 :  0.11393895662949848
#
# Average loss after epoch  492 :  0.11087486780621207
#
# Average loss after epoch  492 :  0.11494004558731942
#
# Average loss after epoch  492 :  0.12852206388485563
#
# Average loss after epoch  492 :  0.10210431655203454
#
# Average loss after epoch  492 :  0.08598180401889707
#
# Average loss after epoch  492 :  0.08416567231116424
#
# Average loss after epoch  492 :  0.10928871658933854
#
# Average loss after epoch  492 :  0.11546495303333706
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  493 :  0.18018288271767752
#
# Average loss after epoch  493 :  0.1309160809127652
#
# Average loss after epoch  493 :  0.1263731861427296
#
# Average loss after epoch  493 :  0.1530644137541089
#
# Average loss after epoch  493 :  0.09337254392873413
#
# Average loss after epoch  493 :  0.12468996787906485
#
# Average loss after epoch  493 :  0.12768167480460293
#
# Average loss after epoch  493 :  0.11766692160469541
#
# Average loss after epoch  493 :  0.10546752112174478
#
# Average loss after epoch  493 :  0.11728470403315372
#
# Average loss after epoch  493 :  0.07989252811270224
#
# Average loss after epoch  493 :  0.11596196975423982
#
# Average loss after epoch  493 :  0.11924118235431547
#
# Average loss after epoch  493 :  0.10657003552766245
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  494 :  0.20053907803126744
#
# Average loss after epoch  494 :  0.1413835773662645
#
# Average loss after epoch  494 :  0.12934987381665422
#
# Average loss after epoch  494 :  0.1279648490147708
#
# Average loss after epoch  494 :  0.09776957508635606
#
# Average loss after epoch  494 :  0.10958873918844979
#
# Average loss after epoch  494 :  0.11073074148609079
#
# Average loss after epoch  494 :  0.1240247214170537
#
# Average loss after epoch  494 :  0.10383422690014217
#
# Average loss after epoch  494 :  0.09415839933027836
#
# Average loss after epoch  494 :  0.10726975459617519
#
# Average loss after epoch  494 :  0.1035973508150536
#
# Average loss after epoch  494 :  0.10643285994722132
#
# Average loss after epoch  494 :  0.09943054863739133
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  495 :  0.19878859179360525
#
# Average loss after epoch  495 :  0.18922124225266126
#
# Average loss after epoch  495 :  0.12265469199019341
#
# Average loss after epoch  495 :  0.11989809896661956
#
# Average loss after epoch  495 :  0.09452730546828829
#
# Average loss after epoch  495 :  0.1245746485750141
#
# Average loss after epoch  495 :  0.13094255663355378
#
# Average loss after epoch  495 :  0.12723094887492217
#
# Average loss after epoch  495 :  0.08536910632320611
#
# Average loss after epoch  495 :  0.0972847254638646
#
# Average loss after epoch  495 :  0.08741444712284616
#
# Average loss after epoch  495 :  0.10168216509861848
#
# Average loss after epoch  495 :  0.127299307274849
#
# Average loss after epoch  495 :  0.10234989428009524
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
# Average loss after epoch  496 :  0.19386751311165945
#
# Average loss after epoch  496 :  0.1398489694206082
#
# Average loss after epoch  496 :  0.12507518005093055
#
# Average loss after epoch  496 :  0.14316796112040686
#
# Average loss after epoch  496 :  0.08015150601521845
#
# Average loss after epoch  496 :  0.12388782471053353
#
# Average loss after epoch  496 :  0.1214423894666721
#
# Average loss after epoch  496 :  0.10089873075331314
#
# Average loss after epoch  496 :  0.09983916708390277
#
# Average loss after epoch  496 :  0.11313098358863902
#
# Average loss after epoch  496 :  0.10627015551481524
#
# Average loss after epoch  496 :  0.10893766093861056
#
# Average loss after epoch  496 :  0.11331535521618738
#
# Average loss after epoch  496 :  0.10029814154156065
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  497 :  0.19909868921552384
#
# Average loss after epoch  497 :  0.1438473706342736
#
# Average loss after epoch  497 :  0.12989067353590583
#
# Average loss after epoch  497 :  0.17142242996308368
#
# Average loss after epoch  497 :  0.08795658662802631
#
# Average loss after epoch  497 :  0.11722921751431528
#
# Average loss after epoch  497 :  0.11749582590268616
#
# Average loss after epoch  497 :  0.10451849379823787
#
# Average loss after epoch  497 :  0.10634273863880847
#
# Average loss after epoch  497 :  0.10525826512138689
#
# Average loss after epoch  497 :  0.08441158128519899
#
# Average loss after epoch  497 :  0.08509216705442897
#
# Average loss after epoch  497 :  0.10935874354234865
#
# Average loss after epoch  497 :  0.0890032021569294
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: market, Motor, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  498 :  0.199136597769601
#
# Average loss after epoch  498 :  0.14446726745488694
#
# Average loss after epoch  498 :  0.13804660759236306
#
# Average loss after epoch  498 :  0.13851464541317868
#
# Average loss after epoch  498 :  0.08149485130506033
#
# Average loss after epoch  498 :  0.11293070964827231
#
# Average loss after epoch  498 :  0.12024448134559541
#
# Average loss after epoch  498 :  0.13035678708699355
#
# Average loss after epoch  498 :  0.10158554985703953
#
# Average loss after epoch  498 :  0.09462774954706567
#
# Average loss after epoch  498 :  0.08192103332172558
#
# Average loss after epoch  498 :  0.10392637283027932
#
# Average loss after epoch  498 :  0.10046309745767341
#
# Average loss after epoch  498 :  0.07983939599171894
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Motor, market, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# --------------------------
#
# Average loss after epoch  499 :  0.19079084055764334
#
# Average loss after epoch  499 :  0.14076927365088948
#
# Average loss after epoch  499 :  0.1386719538067242
#
# Average loss after epoch  499 :  0.1600378297148323
#
# Average loss after epoch  499 :  0.10814422044284412
#
# Average loss after epoch  499 :  0.10992243862799753
#
# Average loss after epoch  499 :  0.12278238575845386
#
# Average loss after epoch  499 :  0.11891453013618036
#
# Average loss after epoch  499 :  0.09797474638748684
#
# Average loss after epoch  499 :  0.10547627501269786
#
# Average loss after epoch  499 :  0.09938772341508284
#
# Average loss after epoch  499 :  0.08964917192920234
#
# Average loss after epoch  499 :  0.1079915741583167
#
# Average loss after epoch  499 :  0.12093802846258919
# Similar to prices: SMMT, fac, check, intention, Dover,
# Similar to update: devastation, process, concessions, December, start,
# Similar to parliament: Motor, market, Secretary, Malaysia, Square,
# Similar to accession: leap, Czech, system, USChina, chocolate,
# Similar to Vince: District, providers, journey, Chris, beginning,
# Similar to impact: strain, table, imports, states, Oxford,
# Similar to Man: 45000, intention, beginning, dark, alert,
# Similar to caption: desk, Scottish, shakeup, Agreement, Dr,
# Saving model in  /notebooks/paper2/datasets/brexit/model.ckpt
# Trained for TSNE

# %%
from packages.gc.plotter import Plotter
wordInfo = word2vecProcessor.getPoints(50)
print(len(wordInfo))
    
linearPlotProcessor = Plotter(wordInfo)
linearPlotProcessor.displayPlot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1742c4037ee2> in <module>
#       1 from packages.gc.plotter import Plotter
# ----> 2 wordInfo = word2vecProcessor.getPoints(50)
#       3 print(len(wordInfo))
#       4
#       5 linearPlotProcessor = Plotter(wordInfo)
#
# /notebooks/paper2/packages/gc/word2vec.py in getPoints(self, totalToDisplay, attribute)
#     236             index = self.vocab[word]['index']
#     237             self.vocab[word]['topic'] = self.topics[word]
# --> 238             self.vocab[word]['x'] = self.learnedEmbeddings[index, 0]
#     239             self.vocab[word]['y'] = self.learnedEmbeddings[index, 1]
#     240
#
# TypeError: 'NoneType' object is not subscriptable
