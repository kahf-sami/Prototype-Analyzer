# %%
# Loading libraries
import sys, os, json, re

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
dir_path = os.path.dirname(os.path.realpath("__file__"))
DATASETSLIB_HOME = os.path.join(dir_path,'datasetslib')
print(DATASETSLIB_HOME)

import sys
if not DATASETSLIB_HOME in sys.path:
    sys.path.append(DATASETSLIB_HOME)
    
# IPython extension to reload modules before executing user code.
# autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %reload_ext autoreload
# %autoreload 2


import datasetslib
# Out:
# /notebooks/IS_w2v/datasetslib

# %%
from datasetslib.gc.lda import LDA

currentPath = os.path.dirname(os.path.realpath("__file__"))
dataSetPath = os.path.join(currentPath, 'datasets/brexit')

ldaProcessor = LDA(dataSetPath)
ldaProcessor.buildVocab()
# Out:
# Dataset path:  /notebooks/IS_w2v/datasets/brexit
# Total files 49
# -------------------------------
# --- Finishing building vocab ------
# {'<Undefined>': 0,
#  'brexit': 1,
#  'uk': 2,
#  'eu': 3,
#  'deal': 4,
#  'mp': 5,
#  'govern': 6,
#  'may': 7,
#  'mr': 8,
#  'border': 9,
#  'imag': 10,
#  'vote': 11,
#  'time': 12,
#  'trade': 13,
#  'plan': 14,
#  'parliament': 15,
#  'minist': 16,
#  'peopl': 17,
#  'custom': 18,
#  'labour': 19,
#  'busi': 20,
#  'backstop': 21,
#  'agreement': 22,
#  'compani': 23,
#  'day': 24,
#  'ireland': 25,
#  'countri': 26,
#  'year': 27,
#  'port': 28,
#  'march': 29,
#  'referendum': 30,
#  'month': 31,
#  'check': 32,
#  'way': 33,
#  'bbc': 34,
#  'withdraw': 35,
#  'leader': 36,
#  'theresa': 37,
#  'parti': 38,
#  'good': 39,
#  'support': 40,
#  'union': 41,
#  'caption': 42,
#  'week': 43,
#  'northern': 44,
#  'european': 45,
#  'event': 46,
#  'market': 47,
#  'firm': 48,
#  'amend': 49,
#  'product': 50,
#  'chang': 51,
# ...

# %%
ldaProcessor.buildWordCoOccurenceVectors(True)
# Out:
# Total files 49
# -------------------------------
# <835x835 sparse matrix of type '<class 'numpy.float64'>'
# 	with 44746 stored elements in Compressed Sparse Row format>

# %%
ldaProcessor.loadWordCoOccurenceVectorsFromFile()
# Out:
# <835x835 sparse matrix of type '<class 'numpy.float64'>'
# 	with 44746 stored elements in Compressed Sparse Row format>

# %%
#ldaProcessor.train()

# %%
from sklearn.manifold import TSNE


wordCoOccurenceVectors = ldaProcessor.loadWordCoOccurenceVectorsFromFile()
wordCoOccurenceVectors = wordCoOccurenceVectors.todense()
vocabId2Word = ldaProcessor.getId2Words()
tsne = TSNE(perplexity=20, n_components=10, init='pca', n_iter=250, method='exact')
tsneEmbeddings = tsne.fit_transform(wordCoOccurenceVectors.todense())
# Out:
# [[ 2.5665474e+01  8.0350275e+00 -5.4760537e+00 ...  3.1609702e+00
#    1.0935055e+01  6.9315448e+00]
#  [ 6.2235565e+02 -2.6152722e+02 -1.5815009e+02 ... -9.6059170e+00
#   -1.0643363e+00  1.3190112e+00]
#  [ 2.8207220e+02  2.5636807e+02 -8.8339569e+01 ... -6.1272426e+00
#   -1.4821826e+01 -1.3285553e+01]
#  ...
#  [-7.7449093e+00 -1.1399945e+00 -1.0473850e-01 ... -7.3718421e-02
#   -6.0567796e-01 -4.3902358e-01]
#  [-7.7471061e+00 -1.1441935e+00 -9.8223917e-02 ... -7.2613671e-02
#   -6.1210597e-01 -4.5588037e-01]
#  [-7.7506194e+00 -1.1467667e+00 -9.5105894e-02 ... -7.3846534e-02
#   -6.0503769e-01 -4.5094427e-01]]

# %%
import matplotlib.pyplot as plt
