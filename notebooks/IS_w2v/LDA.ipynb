# %%
# Loading libraries
import sys, os, json, re

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
dir_path = os.path.dirname(os.path.realpath("__file__"))
DATASETSLIB_HOME = os.path.join(dir_path,'datasetslib')
print(DATASETSLIB_HOME)

import sys
if not DATASETSLIB_HOME in sys.path:
    sys.path.append(DATASETSLIB_HOME)
    
# IPython extension to reload modules before executing user code.
# autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %reload_ext autoreload
# %autoreload 2


import datasetslib
# Out:
# /notebooks/IS_w2v/datasetslib

# %%
from datasetslib.gc.lda import LDA

currentPath = os.path.dirname(os.path.realpath("__file__"))
dataSetPath = os.path.join(currentPath, 'datasets/brexit')

ldaProcessor = LDA(dataSetPath)
ldaProcessor.buildVocab()
# Out:
# Dataset path:  /notebooks/IS_w2v/datasets/brexit
# Total files 49
# -------------------------------
# --- Finishing building vocab ------
# {'<Undefined>': 0,
#  'brexit': 1,
#  'uk': 2,
#  'eu': 3,
#  'deal': 4,
#  'mp': 5,
#  'govern': 6,
#  'may': 7,
#  'mr': 8,
#  'border': 9,
#  'imag': 10,
#  'vote': 11,
#  'time': 12,
#  'trade': 13,
#  'plan': 14,
#  'parliament': 15,
#  'minist': 16,
#  'peopl': 17,
#  'custom': 18,
#  'labour': 19,
#  'busi': 20,
#  'backstop': 21,
#  'agreement': 22,
#  'compani': 23,
#  'day': 24,
#  'ireland': 25,
#  'countri': 26,
#  'year': 27,
#  'port': 28,
#  'march': 29,
#  'referendum': 30,
#  'month': 31,
#  'check': 32,
#  'way': 33,
#  'bbc': 34,
#  'withdraw': 35,
#  'leader': 36,
#  'theresa': 37,
#  'parti': 38,
#  'good': 39,
#  'support': 40,
#  'union': 41,
#  'caption': 42,
#  'week': 43,
#  'northern': 44,
#  'european': 45,
#  'event': 46,
#  'market': 47,
#  'firm': 48,
#  'amend': 49,
#  'product': 50,
#  'chang': 51,
#  'articl': 52,
#  'dover': 53,
#  'export': 54,
#  'hous': 55,
#  'part': 56,
#  'common': 57,
#  'health': 58,
#  'report': 59,
#  'japan': 60,
#  'process': 61,
#  'period': 62,
#  'servic': 63,
#  'irish': 64,
#  'food': 65,
#  'scenario': 66,
#  'move': 67,
#  'suppli': 68,
#  'world': 69,
#  'solut': 70,
#  'job': 71,
#  'risk': 72,
#  'britain': 73,
#  'system': 74,
#  'delay': 75,
#  'issu': 76,
#  'oper': 77,
#  'legisl': 78,
#  'impact': 79,
#  'traffic': 80,
#  'europ': 81,
#  'uncertainti': 82,
#  'negoti': 83,
#  'point': 84,
#  'area': 85,
#  'law': 86,
#  'term': 87,
#  'car': 88,
#  'medicin': 89,
#  'price': 90,
#  'insur': 91,
#  'conserv': 92,
#  'exit': 93,
#  'nh': 94,
#  'secretari': 95,
#  'side': 96,
#  'place': 97,
#  'depart': 98,
#  'group': 99,
#  'corbyn': 100,
#  'pm': 101,
#  'disrupt': 102,
#  'extens': 103,
#  'transit': 104,
#  'offic': 105,
#  'thing': 106,
#  'tuesday': 107,
#  'brussel': 108,
#  'conting': 109,
#  'member': 110,
#  'channel': 111,
#  'ferri': 112,
#  'order': 113,
#  'end': 114,
#  'manufactur': 115,
#  'tori': 116,
#  'number': 117,
#  'freight': 118,
#  'lorri': 119,
#  'bank': 120,
#  'polici': 121,
#  'futur': 122,
#  'media': 123,
#  'option': 124,
#  'rout': 125,
#  'tariff': 126,
#  'council': 127,
#  'rule': 128,
#  'invest': 129,
#  'defeat': 130,
#  'offici': 131,
#  'soni': 132,
#  'sir': 133,
#  'problem': 134,
#  'hour': 135,
#  'industri': 136,
#  'cost': 137,
#  'commiss': 138,
#  'guid': 139,
#  'concern': 140,
#  'director': 141,
#  'inspect': 142,
#  'outcom': 143,
#  'staff': 144,
#  'sector': 145,
#  'london': 146,
#  'westminst': 147,
#  'elect': 148,
#  'money': 149,
#  'import': 150,
#  'someth': 151,
#  'netherland': 152,
#  'franc': 153,
#  'propos': 154,
#  'prepar': 155,
#  'meet': 156,
#  'one': 157,
#  'campaign': 158,
#  'execut': 159,
#  'talk': 160,
#  'state': 161,
#  'cours': 162,
#  'tomato': 163,
#  'driver': 164,
#  'decis': 165,
#  'case': 166,
#  'growth': 167,
#  'arrang': 168,
#  'trust': 169,
#  'shortag': 170,
#  'statement': 171,
#  'cross': 172,
#  'chain': 173,
#  'januari': 174,
#  'warn': 175,
#  'economi': 176,
#  'china': 177,
#  'copyrightgetti': 178,
#  'how': 179,
#  'dup': 180,
#  'territori': 181,
#  'opposit': 182,
#  'jeremi': 183,
#  'respons': 184,
#  'technolog': 185,
#  'island': 186,
#  'access': 187,
#  'transport': 188,
#  'author': 189,
#  'calai': 190,
#  'result': 191,
#  'dr': 192,
#  'spokesman': 193,
#  'wednesday': 194,
#  'us': 195,
#  'tax': 196,
#  'relationship': 197,
#  'headquart': 198,
#  'prime': 199,
#  'republ': 200,
#  'departur': 201,
#  'survey': 202,
#  'wale': 203,
#  'fear': 204,
#  'shelv': 205,
#  'fund': 206,
#  'news': 207,
#  'consequ': 208,
#  'cabinet': 209,
#  'unit': 210,
#  'rees-mogg': 211,
#  'capac': 212,
#  'data': 213,
#  'noth': 214,
#  'kuenssberg': 215,
#  'citizen': 216,
#  'polit': 217,
#  'bill': 218,
#  'public': 219,
#  'posit': 220,
#  'date': 221,
#  'commun': 222,
#  'hospit': 223,
#  'care': 224,
#  'mark': 225,
#  'major': 226,
#  'ro-ro': 227,
#  'andrew': 228,
#  'logist': 229,
#  'southampton': 230,
#  'felixstow': 231,
#  'post': 232,
#  'nation': 233,
#  'fact': 234,
#  'exampl': 235,
#  'regul': 236,
#  'prospect': 237,
#  'david': 238,
#  'idea': 239,
#  'standard': 240,
#  'effort': 241,
#  'histori': 242,
#  'debat': 243,
#  'john': 244,
#  'right': 245,
#  'secur': 246,
#  'monday': 247,
#  'critic': 248,
#  'cooper': 249,
#  'level': 250,
#  'possibl': 251,
#  'work': 252,
#  'pound': 253,
#  'confid': 254,
#  'guernsey': 255,
#  'deputi': 256,
#  'portsmouth': 257,
#  'control': 258,
#  'queue': 259,
#  'chao': 260,
#  'moment': 261,
#  'amount': 262,
#  'rotterdam': 263,
#  'measur': 264,
#  'consum': 265,
#  'margin': 266,
#  'face': 267,
#  'analysi': 268,
#  'slowdown': 269,
#  'approach': 270,
#  'pari': 271,
#  'need': 272,
#  'deadlin': 273,
#  'chanc': 274,
#  'barclay': 275,
#  'worker': 276,
#  'research': 277,
#  'stock': 278,
#  'discuss': 279,
#  'session': 280,
#  'chancellor': 281,
#  'graham': 282,
#  'text': 283,
#  'say': 284,
#  'circumst': 285,
#  'tunnel': 286,
#  'rest': 287,
#  'truck': 288,
#  'reason': 289,
#  'declar': 290,
#  'safeti': 291,
#  'ramsgat': 292,
#  'intern': 293,
#  'inform': 294,
#  'messag': 295,
#  'novemb': 296,
#  'bodi': 297,
#  'chief': 298,
#  'land': 299,
#  'gener': 300,
#  'februari': 301,
#  'institut': 302,
#  'tabl': 303,
#  'spain': 304,
#  'presid': 305,
#  'game': 306,
#  'return': 307,
#  'backbench': 308,
#  'copyright': 309,
#  'laura': 310,
#  'opportun': 311,
#  'agenc': 312,
#  'road': 313,
#  'patient': 314,
#  'clock': 315,
#  'board': 316,
#  'constitu': 317,
#  'card': 318,
#  'defenc': 319,
#  'politician': 320,
#  'st': 321,
#  'immigr': 322,
#  'congest': 323,
#  'organis': 324,
#  'minut': 325,
#  'committe': 326,
#  'threat': 327,
#  'journey': 328,
#  'thursday': 329,
#  'share': 330,
#  'altern': 331,
#  'univers': 332,
#  'question': 333,
#  'detail': 334,
#  'leaveeu': 335,
#  'friday': 336,
#  'twitter': 337,
#  'output': 338,
#  'thousand': 339,
#  'benefit': 340,
#  'simon': 341,
#  'editor': 342,
#  'figur': 343,
#  'south': 344,
#  'recess': 345,
#  'other': 346,
#  'jean-claud': 347,
#  'juncker': 348,
#  'singapor': 349,
#  'pressur': 350,
#  'compromis': 351,
#  'diplomat': 352,
#  'argument': 353,
#  'realiti': 354,
#  'paper': 355,
#  'snp': 356,
#  'kingdom': 357,
#  'develop': 358,
#  'abe': 359,
#  'bid': 360,
#  'mann': 361,
#  'stage': 362,
#  'activ': 363,
#  'coveney': 364,
#  'lot': 365,
#  'dublin': 366,
#  'programm': 367,
#  'dyson': 368,
#  'warehous': 369,
#  'mep': 370,
#  'plant': 371,
#  'blood': 372,
#  'ifg': 373,
#  'dutch': 374,
#  'rosser': 375,
#  'equip': 376,
#  'could': 377,
#  'natur': 378,
#  'destin': 379,
#  'motorway': 380,
#  'baxter': 381,
#  'second': 382,
#  'clearanc': 383,
#  'document': 384,
#  'ship': 385,
#  'sea': 386,
#  'challeng': 387,
#  'bip': 388,
#  'environ': 389,
#  'step': 390,
#  'beef': 391,
#  'produc': 392,
#  'court': 393,
#  'notic': 394,
#  'stephen': 395,
#  'forc': 396,
#  'duti': 397,
#  'new': 398,
#  'decemb': 399,
#  'word': 400,
#  'infrastructur': 401,
#  'favour': 402,
#  'east': 403,
#  'view': 404,
#  'radio': 405,
#  'live': 406,
#  'bloc': 407,
#  'today': 408,
#  'unionist': 409,
#  'correspond': 410,
#  'citi': 411,
#  'night': 412,
#  'motion': 413,
#  'nick': 414,
#  'morgan': 415,
#  'relat': 416,
#  'leav': 417,
#  'heart': 418,
#  'oppon': 419,
#  'financ': 420,
#  'yvett': 421,
#  'record': 422,
#  'sign': 423,
#  'show': 424,
#  'leo': 425,
#  'varadkar': 426,
#  'statu': 427,
#  'anyon': 428,
#  'manag': 429,
#  'procedur': 430,
#  'line': 431,
#  'spokesperson': 432,
#  'agricultur': 433,
#  'ce': 434,
#  'onion': 435,
#  'supermarket': 436,
#  'phw': 437,
#  'bradi': 438,
#  'memo': 439,
#  'pier': 440,
#  'prioriti': 441,
#  'attent': 442,
#  'folkeston': 443,
#  'home': 444,
#  'cargo': 445,
#  'anyth': 446,
#  'vehicl': 447,
#  'theori': 448,
#  'jacob': 449,
#  'contain': 450,
#  'plenti': 451,
#  'volum': 452,
#  'germani': 453,
#  'begin': 454,
#  'consensu': 455,
#  'no-deal': 456,
#  'breach': 457,
#  'commission': 458,
#  'evid': 459,
#  'cut': 460,
#  'sale': 461,
#  'jlr': 462,
#  'carmak': 463,
#  'deliveri': 464,
#  'wine': 465,
#  'contract': 466,
#  'progress': 467,
#  'mean': 468,
#  'ambassador': 469,
#  'climat': 470,
#  'basi': 471,
#  'effect': 472,
#  'action': 473,
#  'requir': 474,
#  'facil': 475,
#  'team': 476,
#  'west': 477,
#  'scale': 478,
#  'mind': 479,
#  'democraci': 480,
#  'frankfurt': 481,
#  'down': 482,
#  'street': 483,
#  'situat': 484,
#  'protest': 485,
#  'blackford': 486,
#  'lord': 487,
#  'call': 488,
#  'project': 489,
#  'reassur': 490,
#  'sunday': 491,
#  'head': 492,
#  'power': 493,
#  'democrat': 494,
#  'england': 495,
#  'juli': 496,
#  'buyer': 497,
#  'choic': 498,
#  'ice': 499,
#  'cream': 500,
#  'individu': 501,
#  'peac': 502,
#  'form': 503,
#  'judgement': 504,
#  'bit': 505,
#  'letter': 506,
#  'remain': 507,
#  'unilev': 508,
#  'inventori': 509,
#  'balanc': 510,
#  'tusk': 511,
#  'role': 512,
#  'success': 513,
#  'toyota': 514,
#  'si': 515,
#  'site': 516,
#  'maker': 517,
#  'osborn': 518,
#  'devic': 519,
#  'stockpil': 520,
#  'bonnysa': 521,
#  'erg': 522,
#  'codicil': 523,
#  'jope': 524,
#  'mine': 525,
#  'treati': 526,
#  'vinc': 527,
#  'cabl': 528,
#  'cope': 529,
#  'so': 530,
#  'matter': 531,
#  'europa': 532,
#  'worldwid': 533,
#  'termin': 534,
#  'paperwork': 535,
#  'farmer': 536,
#  'gove': 537,
#  'farm': 538,
#  'belgium': 539,
#  'potenti': 540,
#  'harbour': 541,
#  'potter': 542,
#  'expert': 543,
#  'ostend': 544,
#  'announc': 545,
#  'fine': 546,
#  'ico': 547,
#  'eldon': 548,
#  'smmt': 549,
#  'haw': 550,
#  'ford': 551,
#  'jack': 552,
#  'morn': 553,
#  'competit': 554,
#  'fall': 555,
#  'april': 556,
#  'gdp': 557,
#  'war': 558,
#  'distribut': 559,
#  'partnership': 560,
#  'resourc': 561,
#  'affair': 562,
#  'cover': 563,
#  'limit': 564,
#  'malthous': 565,
#  'domin': 566,
#  'think': 567,
#  'remark': 568,
#  'surpris': 569,
#  'le': 570,
#  'liber': 571,
#  'interest': 572,
#  'avail': 573,
#  'everyon': 574,
#  'start': 575,
#  'assur': 576,
#  'ian': 577,
#  'bbcpolit': 578,
#  'dem': 579,
#  'honda': 580,
#  'divorc': 581,
#  'organ': 582,
#  'happen': 583,
#  'poll': 584,
#  'shadow': 585,
#  'foreign': 586,
#  'midland': 587,
#  'properti': 588,
#  'increas': 589,
#  'barrier': 590,
#  'newsnight': 591,
#  'hundr': 592,
#  'magnum': 593,
#  'deadlock': 594,
#  'chicken': 595,
#  'basic': 596,
#  'dodd': 597,
#  'taoiseach': 598,
#  'reaction': 599,
#  'chairman': 600,
#  'jame': 601,
#  'client': 602,
#  'justic': 603,
#  'pace': 604,
#  'employ': 605,
#  'read': 606,
#  'rate': 607,
#  'shop': 608,
#  'donald': 609,
#  'base': 610,
#  'burnaston': 611,
#  'act': 612,
#  'halt': 613,
#  'donat': 614,
#  'fisheri': 615,
#  'passag': 616,
#  'rang': 617,
#  'june': 618,
#  'renishaw': 619,
#  'ukca': 620,
#  'assess': 621,
#  'fruit': 622,
#  'veget': 623,
#  'function': 624,
#  'lane': 625,
#  'panason': 626,
#  'hold': 627,
#  'drug': 628,
#  'type': 629,
#  'hunt': 630,
#  'cherri': 631,
#  'eurotunnel': 632,
#  'birmingham': 633,
#  'tomorrow': 634,
#  'motorist': 635,
#  'idp': 636,
#  'cash': 637,
#  'lammi': 638,
#  'redeploy': 639,
#  'updat': 640,
#  'energi': 641,
#  'hampshir': 642,
#  'provid': 643,
#  'advic': 644,
#  'assumpt': 645,
#  'six': 646,
#  'sheer': 647,
#  'anim': 648,
#  'entri': 649,
#  'district': 650,
#  'sail': 651,
#  'pool': 652,
#  'plymouth': 653,
#  'associ': 654,
#  'distanc': 655,
#  'length': 656,
#  'reduct': 657,
#  'protect': 658,
#  'purpos': 659,
#  'feel': 660,
#  'even': 661,
#  'speed': 662,
#  'jaguar': 663,
#  'rover': 664,
#  'model': 665,
#  'diesel': 666,
#  'danger': 667,
#  'korea': 668,
#  'pain': 669,
#  'worri': 670,
#  'valu': 671,
#  'emerg': 672,
#  'cptpp': 673,
#  'asset': 674,
#  'intent': 675,
#  'temperatur': 676,
#  'commit': 677,
#  'better': 678,
#  'arlen': 679,
#  'foster': 680,
#  'raab': 681,
#  'frontier': 682,
#  'it': 683,
#  'kind': 684,
#  'former': 685,
#  'queen': 686,
#  'seri': 687,
#  'newspap': 688,
#  'broadcast': 689,
#  'dynam': 690,
#  'figaro': 691,
#  'crisi': 692,
#  'resign': 693,
#  'zeitung': 694,
#  'die': 695,
#  'comment': 696,
#  'failur': 697,
#  'concess': 698,
#  'itali': 699,
#  'stampa': 700,
#  'disast': 701,
#  'deliv': 702,
#  'close': 703,
#  'box': 704,
#  'demonstr': 705,
#  'voic': 706,
#  'complex': 707,
#  'oblig': 708,
#  'violenc': 709,
#  'drive': 710,
#  'cliff': 711,
#  'specul': 712,
#  'visit': 713,
#  'michel': 714,
#  'barnier': 715,
#  'voter': 716,
#  'prosper': 717,
#  'draft': 718,
#  'default': 719,
#  'shinzo': 720,
#  'factor': 721,
#  'georg': 722,
#  'royal': 723,
#  'region': 724,
#  'north': 725,
#  'van': 726,
#  'lib': 727,
#  'ashworth': 728,
#  'leadership': 729,
#  'focu': 730,
#  'weekend': 731,
#  'statist': 732,
#  'transact': 733,
#  'lack': 734,
#  'robert': 735,
#  'sterl': 736,
#  'certainti': 737,
#  'studi': 738,
#  'capit': 739,
#  'troop': 740,
#  'ratif': 741,
#  'wall': 742,
#  'nigel': 743,
#  'languag': 744,
#  'polic': 745,
#  'presenc': 746,
#  'element': 747,
#  'promis': 748,
#  'duncan': 749,
#  'smith': 750,
#  'green': 751,
#  'rudd': 752,
#  'hope': 753,
#  'long-bailey': 754,
#  'ms': 755,
#  'zone': 756,
#  'cypru': 757,
#  'list': 758,
#  'malmesburi': 759,
#  'wiltshir': 760,
#  'rowan': 761,
#  'jargon': 762,
#  'post-brexit': 763,
#  'subsidiari': 764,
#  'approv': 765,
#  'sweden': 766,
#  'scheme': 767,
#  'materi': 768,
#  'ih': 769,
#  'ben': 770,
#  'jerri': 771,
#  'clariti': 772,
#  'buy': 773,
#  'gap': 774,
#  'barley': 775,
#  'tension': 776,
#  'british': 777,
#  'attempt': 778,
#  'financi': 779,
#  'tie': 780,
#  'packag': 781,
#  'round': 782,
#  'airlin': 783,
#  'haulier': 784,
#  'intervent': 785,
#  'donor': 786,
#  'eventu': 787,
#  'servant': 788,
#  'mani': 789,
#  'travel': 790,
#  'first': 791,
#  'tick': 792,
#  'light': 793,
#  'symbol': 794,
#  'item': 795,
#  'logo': 796,
#  'flexibl': 797,
#  'great': 798,
#  'wiskerk': 799,
#  'worth': 800,
#  'gert': 801,
#  'mulder': 802,
#  'grower': 803,
#  'advanc': 804,
#  'ministri': 805,
#  'hq': 806,
#  'recruit': 807,
#  'roulett': 808,
#  'philip': 809,
#  'hammond': 810,
#  'personnel': 811,
#  'contin': 812,
#  'trip': 813,
#  'electron': 814,
#  'brake': 815,
#  'mechan': 816,
#  'match': 817,
#  'brokenshir': 818,
#  'spend': 819,
#  'drugmak': 820,
#  'luxuri': 821,
#  'direct': 822,
#  'alicant': 823,
#  'factori': 824,
#  'trota': 825,
#  'everyth': 826,
#  'surgeri': 827,
#  'cancel': 828,
#  'colleagu': 829,
#  'norway': 830,
#  'whitehal': 831,
#  'holiday': 832,
#  'hgv': 833,
#  'auster': 834}

