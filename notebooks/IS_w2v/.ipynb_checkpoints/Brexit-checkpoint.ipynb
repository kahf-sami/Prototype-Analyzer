# %%
# Loading libraries
import sys, os, json, re

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import os

import numpy as np
np.random.seed(123)
print("NumPy:{}".format(np.__version__))

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=15,10
print("Matplotlib:{}".format(mpl.__version__))

import tensorflow as tf
tf.set_random_seed(123)
print("TensorFlow:{}".format(tf.__version__))
# Out:
# NumPy:1.15.4
# Matplotlib:3.0.2
# TensorFlow:1.12.0

# %%
dir_path = os.path.dirname(os.path.realpath("__file__"))
DATASETSLIB_HOME = os.path.join(dir_path,'datasetslib')
print(DATASETSLIB_HOME)

import sys
if not DATASETSLIB_HOME in sys.path:
    sys.path.append(DATASETSLIB_HOME)
    
# IPython extension to reload modules before executing user code.
# autoreload reloads modules automatically before entering the execution of code typed at the IPython prompt.
# %reload_ext autoreload
# %autoreload 2


import datasetslib
# Out:
# /notebooks/IS_w2v/datasetslib

# %%
from datasetslib.brexit import Brexit
brexitData = Brexit()
brexitData.loadData()
# Out:
# -- in Brexit --
# Dataset path: ./datasets/brexit
# -- End of constructor ---
# -- In load data ---
# Processing directory:  ./datasets/brexit
# Total files 49
# -------------------------------
# Training file count:  49
# Total files in list:  49
# -------------------------------
# -------------------------------
# Vocab size( train ):  2067
# -------------------------------
# {'<Undefined>': 0, 'guernsey': 1, 'minist': 2, 'point': 3, 'brexit': 4, 'island': 5, 'politician': 6, 'updat': 7, 'deputi': 8, 'gavin': 9, 'st': 10, 'pier': 11, 'food': 12, 'shortag': 13, 'scenario': 14, 'say': 15, 'referendum': 16, 'conting': 17, 'plan': 18, 'depend': 19, 'uk': 20, 'member': 21, 'eu': 22, 'jersey': 23, 'isl': 24, 'man': 25, 'trade': 26, 'access': 27, 'treati': 28, 'area': 29, 'immigr': 30, 'transport': 31, 'energi': 32, 'cooper': 33, 'process': 34, 'parliament': 35, 'time': 36, 'peopl': 37, 'money': 38, 'govern': 39, 'prioriti': 40, 'stori': 41, 'news': 42, 'imag': 43, 'caption': 44, 'sir': 45, 'vinc': 46, 'cabl': 47, 'congest': 48, 'portsmouth': 49, 'port': 50, 'problem': 51, 'suppli': 52, 'law': 53, 'extens': 54, 'world': 55, 'organis': 56, 'membership': 57, 'week': 58, 'concern': 59, 'major': 60, 'product': 61, 'earlier': 62, 'advisor': 63, 'theresa': 64, 'may': 65, 'resid': 66, 'joshua': 67, 'livestro': 68, 'medicin': 69, 'consequ': 70, 'price': 71, 'hampshir': 72, 'author': 73, 'provid': 74, 'impact': 75, 'could': 76, 'channel': 77, 'cope': 78, 'deal': 79, 'month': 80, 'attent': 81, 'rout': 82, 'english': 83, 'circumst': 84, 'secretari': 85, 'chri': 86, 'grayl': 87, 'bbc': 88, 'event': 89, 'withdraw': 90, 'agreement': 91, 'transit': 92, 'period': 93, 'advic': 94, 'statement': 95, 'cabinet': 96, 'offic': 97, 'assumpt': 98, 'worstcas': 99, 'strait': 100, 'dover': 101, 'calai': 102, 'thirdcountri': 103, 'control': 104, 'good': 105, 'import': 106, 'export': 107, 'folkeston': 108, 'home': 109, 'tunnel': 110, 'loop': 111, 'natur': 112, 'cross': 113, 'so': 114, 'system': 115, 'destin': 116, 'countri': 117, 'rolloff': 118, 'ferri': 119, 'roro': 120, 'cargo': 121, 'crane': 122, 'unit': 123, 'freight': 124, 'year': 125, 'lorri': 126, 'driver': 127, 'rest': 128, 'market': 129, 'motorway': 130, 'matter': 131, 'minut': 132, 'switzerland': 133, 'delay': 134, 'custom': 135, 'anyth': 136, 'vehicl': 137, 'hour': 138, 'decis': 139, 'andrew': 140, 'baxter': 141, 'director': 142, 'logist': 143, 'compani': 144, 'europa': 145, 'worldwid': 146, 'hous': 147, 'common': 148, 'committe': 149, 'documentari': 150, 'check': 151, 'inspect': 152, 'digit': 153, 'percentag': 154, 'term': 155, 'queue': 156, 'confin': 157, 'extent': 158, 'theori': 159, 'truck': 160, 'side': 161, 'six': 162, 'support': 163, 'threat': 164, 'chao': 165, 'mp': 166, 'jacob': 167, 'reesmogg': 168, 'second': 169, 'southampton': 170, 'reason': 171, 'dp': 172, 'contain': 173, 'termin': 174, 'declar': 175, 'clearanc': 176, 'vessel': 177, 'document': 178, 'day': 179, 'ship': 180, 'felixstow': 181, 'sea': 182, 'plenti': 183, 'paperwork': 184, 'order': 185, 'challeng': 186, 'journey': 187, 'sheer': 188, 'volum': 189, 'traffic': 190, 'someth': 191, 'nonstart': 192, 'solut': 193, 'one': 194, 'health': 195, 'safeti': 196, 'anim': 197, 'place': 198, 'inland': 199, 'border': 200, 'post': 201, 'bip': 202, 'entri': 203, 'nation': 204, 'farmer': 205, 'union': 206, 'part': 207, 'industri': 208, 'result': 209, 'environ': 210, 'michael': 211, 'gove': 212, 'moment': 213, 'mr': 214, 'oxford': 215, 'farm': 216, 'confer': 217, 'thursday': 218, 'step': 219, 'capac': 220, 'end': 221, 'march': 222, 'fact': 223, 'tariff': 224, 'beef': 225, 'meat': 226, 'case': 227, 'amount': 228, 'space': 229, 'way': 230, 'rotterdam': 231, 'netherland': 232, 'europ': 233, 'kilometr': 234, 'arriv': 235, 'produc': 236, 'effici': 237, 'spokeswoman': 238, 'eurofrigo': 239, 'share': 240, 'load': 241, 'strain': 242, 'ramsgat': 243, 'belgium': 244, 'thanet': 245, 'district': 246, 'council': 247, 'potenti': 248, 'sail': 249, 'dredg': 250, 'harbour': 251, 'busi': 252, 'ramsgateostend': 253, 'immingham': 254, 'pool': 255, 'plymouth': 256, 'franc': 257, 'germani': 258, 'dovercalai': 259, 'manufactur': 260, 'mitig': 261, 'measur': 262, 'paulin': 263, 'bastidon': 264, 'associ': 265, 'chain': 266, 'none': 267, 'intern': 268, 'exampl': 269, 'distanc': 270, 'checkin': 271, 'desk': 272, 'begin': 273, 'length': 274, 'lead ...
# -- Returning from load data --
# (None, None, None)

# %%
brexitData.resetIndex()
# in CBOW input is the context word and output is the target word
y_batch, x_batch = brexitData.next_batch_cbow()

print(y_batch)
print(x_batch)

skipWindow = 2

print('The CBOW pairs : context,target')
for i in range(5 * skipWindow):
    print('(', [brexitData.vocabId2Word[x_i] for x_i in x_batch[i] if x_i > -1],
          ',', y_batch[i], brexitData.vocabId2Word[y_batch[i]], ')')
# Out:
# [ 1  2  3  4  3  1  4  2  5  6  7  8  9 10 11  1 12 13 14 15 16  5 17 18
#   8 10 11 19 20 21 22  1 23 24 25 26 22 20 27 28 29 30 31 32 33 20  4 34
#   8 10 11  1 35 36 37 38 39 40 41 42  1 43 44 45 46 47 48 49 50  4 14 51
#   5 12 52 17 18 53 54 20 55 26 56 57  5 58  8 10 11 59 48 49 50 60  1 12
#  61 62 63 64 65  1 66 67 68 69 12 52 70  5  8 10 11 13 12 71  5 14  1 39
#  72 73 12 74 75  4 76 77]
# [[-1 -1  2 -1]
#  [-1  1 -1 -1]
#  [ 1  2 -1 -1]
#  [ 2  3 -1 -1]
#  [-1 -1  1  4]
#  [-1  3  4  2]
#  [ 3  1  2 -1]
#  [ 1  4 -1 -1]
#  [ 4  2 -1 -1]
#  [ 2  5 -1 -1]
#  [-1 -1  8  9]
#  [-1  7  9 10]
#  [ 7  8 10 11]
#  [ 8  9 11  1]
#  [ 9 10  1 12]
#  [10 11 12 -1]
#  [11  1 -1 -1]
#  [ 1 12 -1 -1]
#  [12 13 -1 -1]
#  [-1 -1 16  5]
#  [-1 15  5 17]
#  [15 16 17 18]
#  [16  5 18  8]
#  [ 5 17  8 -1]
#  [17 18 -1 -1]
#  [18  8 -1 -1]
#  [ 8 10 -1 -1]
#  [-1 -1 20 -1]
#  [-1 19 -1 -1]
#  [19 20 -1 -1]
#  [20 21 -1 -1]
#  [-1 -1 23 24]
#  [-1  1 24 25]
#  [ 1 23 25 26]
#  [23 24 26 22]
#  [24 25 22 20]
#  [25 26 20 -1]
#  [26 22 -1 -1]
#  [22 20 -1 -1]
#  [20 27 -1 -1]
#  [-1 -1 30 31]
#  [-1 29 31 32]
#  [29 30 32 -1]
#  [30 31 -1 -1]
#  [31 32 -1 -1]
#  [32 33 -1 -1]
#  [-1 -1 34  8]
#  [-1  4  8 10]
#  [ 4 34 10 11]
#  [34  8 11 -1]
#  [ 8 10 -1 -1]
#  [10 11 -1 -1]
#  [11  1 -1 -1]
#  [-1 -1 37 38]
#  [-1 36 38 -1]
#  [36 37 -1 -1]
#  [37 38 -1 -1]
#  [38 39 -1 -1]
#  [-1 -1 -1 -1]
#  [-1 41 -1 -1]
#  [41 42 -1 -1]
#  [-1 -1 44 45]
#  [-1 43 45 46]
#  [43 44 46 47]
#  [44 45 47 48]
#  [45 46 48 49]
#  [46 47 49 50]
#  [47 48 50  4]
#  [48 49  4 14]
#  [49 50 14 51]
#  [50  4 51  5]
#  [ 4 14  5 12]
#  [14 51 12 52]
#  [51  5 52 17]
#  [ 5 12 17 -1]
#  [12 52 -1 -1]
#  [52 17 -1 -1]
#  [17 18 -1 -1]
#  [-1 -1 20 55]
#  [-1 54 55 26]
#  [54 20 26 56]
#  [20 55 56 57]
#  [55 26 57  5]
#  [26 56  5 58]
#  [56 57 58  8]
#  [57  5  8 -1]
#  [ 5 58 -1 -1]
#  [58  8 -1 -1]
#  [ 8 10 -1 -1]
#  [-1 -1 48 49]
#  [-1 59 49 50]
#  [59 48 50 60]
#  [48 49 60  1]
#  [49 50  1 -1]
#  [50 60 -1 -1]
#  [60  1 -1 -1]
#  [ 1 12 -1 -1]
#  [-1 -1 63 64]
#  [-1 62 64 65]
#  [62 63 65  1]
#  [63 64  1 66]
#  [64 65 66 67]
#  [65  1 67 68]
#  [ 1 66 68 69]
#  [66 67 69 12]
#  [67 68 12 52]
#  [68 69 52 -1]
#  [69 12 -1 -1]
#  [12 52 -1 -1]
#  [52 70 -1 -1]
#  [-1 -1 10 11]
#  [-1  8 11 13]
#  [ 8 10 13 12]
#  [10 11 12 71]
#  [11 13 71 -1]
#  [13 12 -1 -1]
#  [12 71 -1 -1]
#  [71  5 -1 -1]
#  [-1 -1 39 72]
#  [-1  1 72 73]
#  [ 1 39 73 12]
#  [39 72 12 -1]
#  [72 73 -1 -1]
#  [73 12 -1 -1]
#  [12 74 -1 -1]
#  [-1 -1 76 77]
#  [-1  4 77 50]
#  [ 4 76 50 -1]]
# The CBOW pairs : context,target
# ( ['minist'] , 1 guernsey )
# ( ['guernsey'] , 2 minist )
# ( ['guernsey', 'minist'] , 3 point )
# ( ['minist', 'point'] , 4 brexit )
# ( ['guernsey', 'brexit'] , 3 point )
# ( ['point', 'brexit', 'minist'] , 1 guernsey )
# ( ['point', 'guernsey', 'minist'] , 4 brexit )
# ( ['guernsey', 'brexit'] , 2 minist )
# ( ['brexit', 'minist'] , 5 island )
# ( ['minist', 'island'] , 6 politician )

# %%
skipWindow = 2
brexitData.resetIndex()
# in skip-gram input is the target word and output is the context word
x_batch, y_batch = brexitData.next_batch_sg()

print('The skip-gram pairs : target,context')
for i in range(2 * skipWindow):
    print('(', x_batch[i], brexitData.vocabId2Word[x_batch[i]],
          ',', y_batch[i], brexitData.vocabId2Word[y_batch[i]], ')')
# Out:
# The skip-gram pairs : target,context
# ( 1 guernsey , 2 minist )
# ( 1 guernsey , 3 point )
# ( 2 minist , 1 guernsey )
# ( 2 minist , 3 point )

# %%
valid_size = 8

x_valid = np.random.choice(valid_size * 10, valid_size, replace=False)
print('valid: ',x_valid)
# Out:
# valid:  [64 58 59  4 69 53 31 77]

# %%
batch_size = 128 * 4
embedding_size = 128 * 4
n_negative_samples = 64


# clear the effects of previous sessions in the Jupyter Notebook
tf.reset_default_graph()

inputs = tf.placeholder(dtype=tf.int32, shape=[batch_size])
outputs = tf.placeholder(dtype=tf.int32, shape=[batch_size,1])
inputs_valid = tf.constant(x_valid, dtype=tf.int32)

# %%
# define embeddings matrix with vocab_len rows and embedding_size columns
# each row represents vectore representation or embedding of a word
# in the vocbulary

embed_dist = tf.random_uniform(shape=[brexitData.vocab_size, embedding_size],
                               minval=-1.0,
                               maxval=1.0
                               )
embed_matrix = tf.Variable(embed_dist,
                           name='embed_matrix'
                           )
# define the embedding lookup table
# provides the embeddings of the word ids in the input tensor
embed_ltable = tf.nn.embedding_lookup(embed_matrix, inputs)

# %%
# define noise-contrastive estimation (NCE) loss layer

nce_dist = tf.truncated_normal(shape=[brexitData.vocab_size, embedding_size],
                               stddev=1.0 /
                               tf.sqrt(embedding_size * 1.0)
                               )
nce_w = tf.Variable(nce_dist)
nce_b = tf.Variable(tf.zeros(shape=[brexitData.vocab_size]))

loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_w,
                                     biases=nce_b,
                                     inputs=embed_ltable,
                                     labels=outputs,
                                     num_sampled=n_negative_samples,
                                     num_classes=brexitData.vocab_size
                                     )
                      )

# %%
# Compute the cosine similarity between validation set samples
# and all embeddings.
norm = tf.sqrt(tf.reduce_sum(tf.square(embed_matrix), 1, 
                             keep_dims=True))
normalized_embeddings = embed_matrix / norm
embed_valid = tf.nn.embedding_lookup(normalized_embeddings, 
                                     inputs_valid)
similarity = tf.matmul(
    embed_valid, normalized_embeddings, transpose_b=True)
# Out:
# WARNING:tensorflow:From <ipython-input-11-fa352dc11208>:4: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
n_epochs = 1000
learning_rate = 0.5
n_batches = brexitData.n_batches_wv()
print('Batches: ', n_batches)
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

with tf.Session() as tfs:
    tf.global_variables_initializer().run()
    for epoch in range(n_epochs):
        epoch_loss = 0
        brexitData.resetIndex()
        for step in range(n_batches):
            x_batch, y_batch = brexitData.next_batch_sg()
            #print(x_batch)
            #print('----------')
            #print(y_batch)
            #print('----------')
            y_batch = brexitData.to2d(y_batch, unit_axis=1)
            feed_dict = {inputs: x_batch, outputs: y_batch}
            _, batch_loss = tfs.run([optimizer, loss], feed_dict=feed_dict)
            epoch_loss += batch_loss
        epoch_loss = epoch_loss / n_batches
        print('\nAverage loss after epoch ', epoch, ': ', epoch_loss)

        # print closest words to validation set at end of every epoch
        similarity_scores = tfs.run(similarity)
        top_k = 5
        for i in range(valid_size):
            similar_words = (-similarity_scores[i, :]
                             ).argsort()[1:top_k + 1]
            similar_str = 'Similar to {0:}:'.format(
                brexitData.vocabId2Word[x_valid[i]])
            for k in range(top_k):
                similar_str = '{0:} {1:},'.format(
                    similar_str, brexitData.vocabId2Word[similar_words[k]])
            print(similar_str)
    final_embeddings = tfs.run(normalized_embeddings)
# Out:
# Batches:  16
#
# Average loss after epoch  0 :  137.04199123382568
# Similar to theresa: traffic, investig, harder, scenario, check,
# Similar to week: april, inflat, weyand, distribut, bradi,
# Similar to concern: place, wale, affair, jet, fee,
# Similar to brexit: compani, mp, trade, ford, pact,
# Similar to medicin: newsnight, peac, financ, technolog, statut,
# Similar to law: land, secreci, oper, pace, europ,
# Similar to transport: doctor, wrong, stupid, mondelez, sturgeon,
# Similar to channel: britain, food, secretari, oliv, minist,
#
# Average loss after epoch  1 :  105.61260557174683
# Similar to theresa: traffic, scenario, investig, check, harder,
# Similar to week: april, distribut, inflat, weyand, bradi,
# Similar to concern: place, wale, affair, jet, fee,
# Similar to brexit: compani, mp, trade, ford, wonder,
# Similar to medicin: newsnight, peac, financ, technolog, statut,
# Similar to law: land, secreci, oper, europ, pace,
# Similar to transport: doctor, wrong, stupid, mondelez, sturgeon,
# Similar to channel: britain, food, secretari, minist, oliv,
#
# Average loss after epoch  2 :  85.48951029777527
# Similar to theresa: traffic, scenario, check, investig, backstop,
# Similar to week: april, distribut, weyand, inflat, bradi,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, mp, trade, declar, ford,
# Similar to medicin: newsnight, peac, financ, technolog, statut,
# Similar to law: land, secreci, oper, mp, europ,
# Similar to transport: doctor, wrong, stupid, mondelez, sturgeon,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  3 :  69.53505849838257
# Similar to theresa: traffic, scenario, check, investig, backstop,
# Similar to week: april, distribut, weyand, inflat, hampshir,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, mp, trade, declar, ford,
# Similar to medicin: newsnight, peac, financ, technolog, statut,
# Similar to law: land, mp, secreci, oper, europ,
# Similar to transport: doctor, wrong, stupid, mondelez, consumpt,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  4 :  62.8206627368927
# Similar to theresa: traffic, scenario, check, investig, backstop,
# Similar to week: april, distribut, weyand, inflat, hampshir,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, mp, trade, declar, ford,
# Similar to medicin: newsnight, peac, financ, technolog, statut,
# Similar to law: land, mp, oper, secreci, europ,
# Similar to transport: doctor, wrong, stupid, mondelez, campaign,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  5 :  46.15747606754303
# Similar to theresa: traffic, scenario, check, investig, backstop,
# Similar to week: april, distribut, weyand, hampshir, inflat,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, trade, mp, declar, suzuki,
# Similar to medicin: newsnight, financ, peac, statut, technolog,
# Similar to law: land, mp, europ, oper, secreci,
# Similar to transport: doctor, wrong, mondelez, stupid, campaign,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  6 :  35.62708032131195
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, britain, weyand,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, trade, mp, declar, suzuki,
# Similar to medicin: newsnight, financ, peac, statut, stabil,
# Similar to law: land, mp, europ, oper, secreci,
# Similar to transport: doctor, campaign, wrong, mondelez, stupid,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  7 :  30.85171639919281
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, britain, andrew,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, trade, mp, declar, suzuki,
# Similar to medicin: financ, newsnight, peac, statut, stabil,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: doctor, campaign, stephen, mondelez, wrong,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  8 :  24.756604433059692
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, andrew, britain,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, trade, declar, suzuki, mp,
# Similar to medicin: financ, newsnight, peac, stabil, statut,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: doctor, campaign, stephen, mondelez, wrong,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  9 :  23.21099227666855
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, andrew, britain,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, suzuki, declar, trade, pact,
# Similar to medicin: financ, newsnight, peac, stabil, statut,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: doctor, campaign, stephen, mondelez, misus,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  10 :  22.77841505408287
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, andrew, britain,
# Similar to concern: place, wale, affair, fee, jet,
# Similar to brexit: compani, suzuki, declar, pact, job,
# Similar to medicin: financ, newsnight, peac, stabil, conting,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: doctor, campaign, stephen, misus, mondelez,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  11 :  18.782115519046783
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, andrew, britain,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, declar, ford,
# Similar to medicin: financ, newsnight, peac, stabil, conting,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, doctor, stephen, misus, secur,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  12 :  15.429843246936798
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, andrew, britain,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, declar,
# Similar to medicin: financ, newsnight, peac, stabil, conting,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, doctor, stephen, misus, secur,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  13 :  14.564023107290268
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, andrew, britain,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, declar, ford,
# Similar to medicin: financ, newsnight, stabil, peac, conting,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, doctor, misus, secur,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  14 :  14.10044251382351
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, declar,
# Similar to medicin: financ, stabil, newsnight, conting, peac,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, doctor, misus, secur,
# Similar to channel: britain, food, minist, secretari, may,
#
# Average loss after epoch  15 :  12.246217772364616
# Similar to theresa: traffic, scenario, check, investig, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, job,
# Similar to medicin: financ, stabil, conting, newsnight, peac,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, doctor, misus, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  16 :  10.245173439383507
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, declar,
# Similar to medicin: financ, stabil, conting, newsnight, peac,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, doctor, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
# Average loss after epoch  17 :  8.816266238689423
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, declar,
# Similar to medicin: financ, stabil, conting, newsnight, peac,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, doctor, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  18 :  9.329799488186836
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, job,
# Similar to medicin: financ, stabil, conting, newsnight, code,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, doctor, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  19 :  7.012063905596733
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, declar,
# Similar to medicin: financ, stabil, conting, newsnight, code,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, doctor, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  20 :  6.409676179289818
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, declar,
# Similar to medicin: financ, stabil, conting, code, newsnight,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, doctor, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  21 :  4.5851665288209915
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, declar,
# Similar to medicin: financ, stabil, conting, code, newsnight,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, doctor, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  22 :  4.930657476186752
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: financ, stabil, conting, code, newsnight,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, secur, doctor,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  23 :  4.910767987370491
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: financ, stabil, conting, code, newsnight,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, secur, uschina,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  24 :  5.817674994468689
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, jet,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: financ, stabil, conting, code, newsnight,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  25 :  4.651291623711586
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: stabil, financ, conting, code, newsnight,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, secur, uschina,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  26 :  2.8729563653469086
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: stabil, financ, conting, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  27 :  3.5021101534366608
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: stabil, financ, conting, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  28 :  2.8976516127586365
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: stabil, financ, conting, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  29 :  3.5082416757941246
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: stabil, financ, conting, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  30 :  4.903600871562958
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, ford, inhabit,
# Similar to medicin: stabil, financ, conting, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  31 :  3.2893120795488358
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, financ, conting, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  32 :  2.6776871234178543
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, financ, conting, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  33 :  3.212718680500984
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, financ, conting, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  34 :  2.59573607891798
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
# Average loss after epoch  35 :  2.5734828412532806
# Similar to theresa: traffic, scenario, investig, check, part,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  36 :  2.9643618911504745
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  37 :  2.894913613796234
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, fee, le,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  38 :  2.543979287147522
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, fee,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  39 :  2.8161153942346573
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, fee,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  40 :  2.8663578405976295
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, fee,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  41 :  2.387248896062374
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, fee,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  42 :  2.6592486053705215
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, fee,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, secretari, oliv,
#
# Average loss after epoch  43 :  2.5077653229236603
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, fee,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  44 :  2.045503221452236
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, fee,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  45 :  2.754596635699272
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, fee,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  46 :  2.3799660727381706
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  47 :  1.9852610155940056
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  48 :  2.2889484614133835
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  49 :  2.039234794676304
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  50 :  1.9792028591036797
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  51 :  2.0916997864842415
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
# Average loss after epoch  52 :  1.9192621633410454
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  53 :  1.9588400200009346
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, europ, mp, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  54 :  2.0124888941645622
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  55 :  2.2955718263983727
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  56 :  2.2893098816275597
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  57 :  1.916032649576664
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, financ, code, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  58 :  1.9508576393127441
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, europ, mp, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  59 :  1.9388749599456787
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, mp, europ, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  60 :  1.9015166908502579
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, appeal, andrew,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  61 :  1.948531061410904
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, appeal, andrew,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  62 :  1.8323611915111542
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  63 :  1.898140273988247
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, mp, europ, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  64 :  2.2799866050481796
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, europ, mp, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  65 :  1.8882326558232307
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  66 :  1.8731817454099655
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, europ, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  67 :  1.793617993593216
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, europ, mp, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  68 :  1.9075190275907516
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
# Average loss after epoch  69 :  1.8571147471666336
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  70 :  1.869633637368679
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, europ, mp, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  71 :  1.9082618579268456
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: campaign, stephen, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  72 :  1.882165104150772
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, mp, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  73 :  1.8645027950406075
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, europ, oper, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  74 :  1.9410830736160278
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, europ, oper, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  75 :  1.8881111294031143
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, europ, oper, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  76 :  1.934678927063942
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, europ, oper, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  77 :  1.8169175311923027
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  78 :  1.9383606910705566
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  79 :  1.7689872309565544
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  80 :  1.825093001127243
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  81 :  1.9531186893582344
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  82 :  1.8423812612891197
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, mp, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  83 :  1.8357331082224846
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  84 :  1.8194748386740685
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, europ, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
# Average loss after epoch  85 :  1.699925035238266
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, europ, oper, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  86 :  1.8804256916046143
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, europ, oper, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  87 :  1.7818748578429222
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, europ, oper, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  88 :  1.8707532957196236
# Similar to theresa: traffic, investig, scenario, throw, check,
# Similar to week: april, distribut, hampshir, appeal, andrew,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, europ, oper, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  89 :  1.8243810310959816
# Similar to theresa: traffic, scenario, investig, check, throw,
# Similar to week: april, distribut, hampshir, appeal, andrew,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  90 :  1.8308070823550224
# Similar to theresa: traffic, investig, scenario, throw, check,
# Similar to week: april, distribut, hampshir, appeal, andrew,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, oper, europ, mp, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  91 :  1.793878085911274
# Similar to theresa: traffic, investig, scenario, check, throw,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, minist, oliv, secretari,
#
# Average loss after epoch  92 :  1.7826633006334305
# Similar to theresa: traffic, investig, scenario, throw, check,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, conting, code, financ, expert,
# Similar to law: land, mp, europ, oper, talk,
# Similar to transport: stephen, campaign, misus, uschina, secur,
# Similar to channel: britain, food, oliv, minist, secretari,
#
# Average loss after epoch  93 :  1.85094403475523
# Similar to theresa: traffic, investig, scenario, throw, check,
# Similar to week: april, distribut, hampshir, andrew, appeal,
# Similar to concern: place, affair, wale, le, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# ...
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, secretari,
#
# Average loss after epoch  970 :  1.6319807767868042
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, associ,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  971 :  1.6625944525003433
# Similar to theresa: traffic, scenario, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  972 :  1.6366258189082146
# Similar to theresa: traffic, scenario, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, minist, polit,
# Average loss after epoch  973 :  1.6425805166363716
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, secretari,
#
# Average loss after epoch  974 :  1.6653055921196938
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, secretari,
#
# Average loss after epoch  975 :  1.6922418773174286
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, may,
#
# Average loss after epoch  976 :  1.6384555324912071
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  977 :  1.6580391451716423
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, may, polit,
#
# Average loss after epoch  978 :  1.6015901565551758
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  979 :  1.6546511426568031
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  980 :  1.6159945875406265
# Similar to theresa: traffic, scenario, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, ford,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  981 :  1.7633493766188622
# Similar to theresa: traffic, scenario, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, secretari,
#
# Average loss after epoch  982 :  1.6031773760914803
# Similar to theresa: traffic, scenario, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, it,
#
# Average loss after epoch  983 :  1.6082403808832169
# Similar to theresa: traffic, scenario, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, minist, polit,
#
# Average loss after epoch  984 :  1.6359060034155846
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, minist, polit,
#
# Average loss after epoch  985 :  1.5349062755703926
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, minist, polit,
#
# Average loss after epoch  986 :  1.6538950502872467
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, minist, polit,
#
# Average loss after epoch  987 :  1.6383826956152916
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, campaign, misus, uschina, suzuki,
# Similar to channel: britain, oliv, food, minist, polit,
#
# Average loss after epoch  988 :  1.623511403799057
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, minist, polit,
#
# Average loss after epoch  989 :  1.7319386005401611
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  990 :  1.6071191504597664
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
# Average loss after epoch  991 :  1.7441434040665627
# Similar to theresa: scenario, investig, traffic, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  992 :  1.6963467076420784
# Similar to theresa: scenario, investig, traffic, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, inhabit, pact, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  993 :  1.5426546931266785
# Similar to theresa: scenario, investig, traffic, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, inhabit, pact, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  994 :  1.6434965953230858
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, inhabit, pact, declar,
# Similar to medicin: stabil, code, conting, expert, competit,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  995 :  1.7592733427882195
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, inhabit, pact, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, deal, uschina,
# Similar to channel: britain, oliv, food, polit, secretari,
#
# Average loss after epoch  996 :  1.6552596986293793
# Similar to theresa: scenario, investig, traffic, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, inhabit, pact, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,
#
# Average loss after epoch  997 :  1.675295777618885
# Similar to theresa: scenario, investig, traffic, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, pact, inhabit, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, deal,
# Similar to channel: britain, oliv, food, minist, polit,
#
# Average loss after epoch  998 :  1.6562789529561996
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, declar, uk,
# Similar to brexit: compani, suzuki, inhabit, pact, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, minist, polit,
#
# Average loss after epoch  999 :  1.636718139052391
# Similar to theresa: scenario, traffic, investig, throw, unionist,
# Similar to week: april, distribut, switzerland, hampshir, appeal,
# Similar to concern: place, affair, le, uk, declar,
# Similar to brexit: compani, suzuki, inhabit, pact, declar,
# Similar to medicin: stabil, code, conting, expert, despair,
# Similar to law: land, mp, oper, europ, talk,
# Similar to transport: stephen, misus, campaign, uschina, suzuki,
# Similar to channel: britain, oliv, food, polit, minist,

# %%
def plot_with_labels(low_dim_embs, labels):
    assert low_dim_embs.shape[0] >= len(
        labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(perplexity=30, n_components=2,
            init='pca', n_iter=500, method='exact')
n_embeddings = 500
low_dim_embeddings = tsne.fit_transform(final_embeddings[:n_embeddings, :])
labels = [brexitData.vocabId2Word[i] for i in range(n_embeddings)]

plot_with_labels(low_dim_embeddings, labels)
