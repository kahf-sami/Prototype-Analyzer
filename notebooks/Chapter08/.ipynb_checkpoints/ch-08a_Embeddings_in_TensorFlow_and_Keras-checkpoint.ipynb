# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#Embeddings-with-PTB-Data-in-TensorFlow" data-toc-modified-id="Embeddings-with-PTB-Data-in-TensorFlow-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Embeddings with PTB Data in TensorFlow</a></span><ul class="toc-item"><li><span><a href="#Load-and-Prepare-PTB-data" data-toc-modified-id="Load-and-Prepare-PTB-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Load and Prepare PTB data</a></span></li><li><span><a href="#Train-the-skip-gram-model-for-PTB-Data-in-TensorFlow" data-toc-modified-id="Train-the-skip-gram-model-for-PTB-Data-in-TensorFlow-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Train the skip-gram model for PTB Data in TensorFlow</a></span></li></ul></li><li><span><a href="#Embeddings-with-Text8-data-in-TensorFlow" data-toc-modified-id="Embeddings-with-Text8-data-in-TensorFlow-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Embeddings with Text8 data in TensorFlow</a></span></li><li><span><a href="#skip-gram-model-with-Keras" data-toc-modified-id="skip-gram-model-with-Keras-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>skip-gram model with Keras</a></span></li><li><span><a href="#word2vec-or-embeddings-visualisation-using-TensorBoard" data-toc-modified-id="word2vec-or-embeddings-visualisation-using-TensorBoard-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>word2vec or embeddings visualisation using TensorBoard</a></span></li><li><span><a href="#The-word2id-and-id2word-code-explained" data-toc-modified-id="The-word2id-and-id2word-code-explained-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>The word2id and id2word code explained</a></span></li></ul></div>

# %% [markdown]
# # Word Vectors and Embeddings in TensorFlow and Keras <a class="tocSkip">

# %%
import os

import numpy as np
np.random.seed(123)
print("NumPy:{}".format(np.__version__))

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=15,10
print("Matplotlib:{}".format(mpl.__version__))

import tensorflow as tf
tf.set_random_seed(123)
print("TensorFlow:{}".format(tf.__version__))
# Out:
# NumPy:1.15.4
# Matplotlib:3.0.2
# TensorFlow:1.12.0

# %%
dir_path = os.path.dirname(os.path.realpath("__file__"))
DATASETSLIB_HOME = os.path.join(dir_path,'datasetslib')
print(DATASETSLIB_HOME)

import sys
if not DATASETSLIB_HOME in sys.path:
    sys.path.append(DATASETSLIB_HOME)


# %reload_ext autoreload
# %autoreload 2


import datasetslib

from datasetslib import util as dsu
import datasetslib.utils.nputil as nputil1

datasetslib.datasets_root = os.path.join(dir_path,'datasets')
print(datasetslib.datasets_root)
# Out:
# /notebooks/Chapter08/datasetslib
# /notebooks/Chapter08/datasets

# %% [markdown]
# # Embeddings with PTB Data in TensorFlow

# %% [markdown]
# ## Load and Prepare PTB data

# %%
# !pip3 install future
# Out:
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages

# %%
from datasetslib.ptb import PTBSimple
ptb = PTBSimple()
# downloads data, converts words to ids, converts files to a list of ids
ptb.load_data()
print('Train :', ptb.part['train'][0:5])
print('Test: ', ptb.part['test'][0:5])
print('Valid: ', ptb.part['valid'][0:5])
print('Vocabulary Length = ', ptb.vocab_len)
# Out:
# Already exists: ./datasets/ptb-simple/simple-examples.tgz
# Train : [9970 9971 9972 9974 9975]
# Test:  [102  14  24  32 752]
# Valid:  [1132   93  358    5  329]
# Vocabulary Length =  10000

# %%
ptb.skip_window = 2
ptb.reset_index()
# in CBOW input is the context word and output is the target word
y_batch, x_batch = ptb.next_batch_cbow()

print('The CBOW pairs : context,target')
for i in range(5 * ptb.skip_window):
    print('(', [ptb.id2word[x_i] for x_i in x_batch[i]],
          ',', y_batch[i], ptb.id2word[y_batch[i]], ')')
# Out:
# The CBOW pairs : context,target
# ( ['aer', 'banknote', 'calloway', 'centrust'] , 9972 berlitz )
# ( ['banknote', 'berlitz', 'centrust', 'cluett'] , 9974 calloway )
# ( ['berlitz', 'calloway', 'cluett', 'fromstein'] , 9975 centrust )
# ( ['calloway', 'centrust', 'fromstein', 'gitano'] , 9976 cluett )
# ( ['centrust', 'cluett', 'gitano', 'guterman'] , 9980 fromstein )
# ( ['cluett', 'fromstein', 'guterman', 'hydro-quebec'] , 9981 gitano )
# ( ['fromstein', 'gitano', 'hydro-quebec', 'ipo'] , 9982 guterman )
# ( ['gitano', 'guterman', 'ipo', 'kia'] , 9983 hydro-quebec )
# ( ['guterman', 'hydro-quebec', 'kia', 'memotec'] , 9984 ipo )
# ( ['hydro-quebec', 'ipo', 'memotec', 'mlx'] , 9986 kia )

# %%
ptb.skip_window = 2
ptb.reset_index()
# in skip-gram input is the target word and output is the context word
x_batch, y_batch = ptb.next_batch_sg()

print('The skip-gram pairs : target,context')
for i in range(5 * ptb.skip_window):
    print('(', x_batch[i], ptb.id2word[x_batch[i]],
          ',', y_batch[i], ptb.id2word[y_batch[i]], ')')
# Out:
# The skip-gram pairs : target,context
# ( 9972 berlitz , 9970 aer )
# ( 9972 berlitz , 9971 banknote )
# ( 9972 berlitz , 9974 calloway )
# ( 9972 berlitz , 9975 centrust )
# ( 9974 calloway , 9971 banknote )
# ( 9974 calloway , 9972 berlitz )
# ( 9974 calloway , 9975 centrust )
# ( 9974 calloway , 9976 cluett )
# ( 9975 centrust , 9972 berlitz )
# ( 9975 centrust , 9974 calloway )

# %%
valid_size = 8
x_valid = np.random.choice(valid_size * 10, valid_size, replace=False)
print('valid: ',x_valid)
# Out:
# valid:  [64 58 59  4 69 53 31 77]

# %% [markdown]
# ## Train the skip-gram model for PTB Data in TensorFlow

# %%
batch_size = 128
embedding_size = 128  
n_negative_samples = 64
ptb.skip_window=2

# %%
# clear the effects of previous sessions in the Jupyter Notebook
tf.reset_default_graph()

# %%
inputs = tf.placeholder(dtype=tf.int32, shape=[batch_size])
outputs = tf.placeholder(dtype=tf.int32, shape=[batch_size,1])
inputs_valid = tf.constant(x_valid, dtype=tf.int32)

# %%
# define embeddings matrix with vocab_len rows and embedding_size columns
# each row represents vectore representation or embedding of a word
# in the vocbulary

embed_dist = tf.random_uniform(shape=[ptb.vocab_len, embedding_size],
                               minval=-1.0,
                               maxval=1.0
                               )
embed_matrix = tf.Variable(embed_dist,
                           name='embed_matrix'
                           )
# define the embedding lookup table
# provides the embeddings of the word ids in the input tensor
embed_ltable = tf.nn.embedding_lookup(embed_matrix, inputs)

# %%
# define noise-contrastive estimation (NCE) loss layer

nce_dist = tf.truncated_normal(shape=[ptb.vocab_len, embedding_size],
                               stddev=1.0 /
                               tf.sqrt(embedding_size * 1.0)
                               )
nce_w = tf.Variable(nce_dist)
nce_b = tf.Variable(tf.zeros(shape=[ptb.vocab_len]))

loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_w,
                                     biases=nce_b,
                                     inputs=embed_ltable,
                                     labels=outputs,
                                     num_sampled=n_negative_samples,
                                     num_classes=ptb.vocab_len
                                     )
                      )

# %%
# Compute the cosine similarity between validation set samples
# and all embeddings.
norm = tf.sqrt(tf.reduce_sum(tf.square(embed_matrix), 1, 
                             keep_dims=True))
normalized_embeddings = embed_matrix / norm
embed_valid = tf.nn.embedding_lookup(normalized_embeddings, 
                                     inputs_valid)
similarity = tf.matmul(
    embed_valid, normalized_embeddings, transpose_b=True)
# Out:
# WARNING:tensorflow:From <ipython-input-13-fa352dc11208>:4: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
n_epochs = 1
learning_rate = 0.9
n_batches = ptb.n_batches_wv()
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

with tf.Session() as tfs:
    tf.global_variables_initializer().run()
    for epoch in range(n_epochs):
        epoch_loss = 0
        ptb.reset_index()
        for step in range(n_batches):
            x_batch, y_batch = ptb.next_batch_sg()
            y_batch = nputil1.to2d(y_batch, unit_axis=1)
            feed_dict = {inputs: x_batch, outputs: y_batch}
            _, batch_loss = tfs.run([optimizer, loss], feed_dict=feed_dict)
            epoch_loss += batch_loss
        epoch_loss = epoch_loss / n_batches
        print('\nAverage loss after epoch ', epoch, ': ', epoch_loss)

        # print closest words to validation set at end of every epoch
        similarity_scores = tfs.run(similarity)
        top_k = 5
        for i in range(valid_size):
            similar_words = (-similarity_scores[i, :]
                             ).argsort()[1:top_k + 1]
            similar_str = 'Similar to {0:}:'.format(
                ptb.id2word[x_valid[i]])
            for k in range(top_k):
                similar_str = '{0:} {1:},'.format(
                    similar_str, ptb.id2word[similar_words[k]])
            print(similar_str)
    final_embeddings = tfs.run(normalized_embeddings)
# Out:
# Average loss after epoch  0 :  114.08558142490877
# Similar to we: computer, signs, before, seymour, moreover,
# Similar to been: fannie, <unk>, expected, ', president,
# Similar to also: 's, research, reacted, posner, N,
# Similar to of: <eos>, dodge, million, its, with,
# Similar to last: software, abused, business, chairman, about,
# Similar to u.s.: market, residential, dodge, reserves, hard,
# Similar to an: rise, co., force, closely, no,
# Similar to trading: some, have, do, milk, higher,
#
# Average loss after epoch  1 :  50.3495614528656
# Similar to we: computer, signs, filters, moreover, amount,
# Similar to been: fannie, expected, simon, outstanding, ',
# Similar to also: compared, 's, N, research, among,
# Similar to of: <eos>, relatively, dodge, its, with,
# Similar to last: software, turf, business, abused, chairman,
# Similar to u.s.: residential, market, list, still, incentive,
# Similar to an: class, rise, excess, force, closely,
# Similar to trading: some, do, higher, out, have,
#
# Average loss after epoch  2 :  27.74095525497045
# Similar to we: computer, signs, filters, moreover, j.p.,
# Similar to been: simon, fannie, outstanding, expected, regulation,
# Similar to also: compared, N, percentage, among, 's,
# Similar to of: <eos>, relatively, project, its, dodge,
# Similar to last: software, turf, business, intensity, abused,
# Similar to u.s.: residential, market, list, incentive, depend,
# Similar to an: class, rise, excess, force, closely,
# Similar to trading: some, do, higher, milk, out,
#
# Average loss after epoch  3 :  19.446764059555836
# Similar to we: computer, signs, moreover, filters, j.p.,
# Similar to been: simon, fannie, regulation, remaining, expected,
# Similar to also: compared, percentage, among, temporarily, climbing,
# Similar to of: relatively, renewal, <eos>, paul, its,
# Similar to last: software, turf, business, intensity, abused,
# Similar to u.s.: residential, market, list, incentive, depend,
# Similar to an: class, rise, force, excess, closely,
# Similar to trading: some, do, higher, milk, out,
#
# Average loss after epoch  4 :  14.514970352252325
# Similar to we: computer, signs, moreover, filters, j.p.,
# Similar to been: simon, fannie, regulation, remaining, expected,
# Similar to also: compared, percentage, dumped, temporarily, among,
# Similar to of: renewal, relatively, paul, premium, dodge,
# Similar to last: software, turf, business, intensity, abused,
# Similar to u.s.: residential, list, market, incentive, depend,
# Similar to an: class, rise, excess, force, closely,
# Similar to trading: some, do, higher, milk, out,
#
# Average loss after epoch  5 :  10.607750076514025
# Similar to we: computer, signs, moreover, filters, j.p.,
# Similar to been: simon, regulation, fannie, remaining, expected,
# Similar to also: compared, dumped, percentage, climbing, temporarily,
# Similar to of: renewal, relatively, paul, minister, expenses,
# Similar to last: software, turf, business, intensity, abused,
# Similar to u.s.: residential, market, list, incentive, depend,
# Similar to an: class, rise, force, excess, closely,
# Similar to trading: some, do, milk, higher, out,
#
# Average loss after epoch  6 :  7.9012370468714295
# Similar to we: computer, signs, moreover, j.p., filters,
# Similar to been: simon, regulation, remaining, fannie, expected,
# Similar to also: compared, dumped, climbing, percentage, temporarily,
# Similar to of: renewal, relatively, paul, premium, minister,
# Similar to last: software, turf, business, intensity, point,
# Similar to u.s.: residential, market, depend, list, incentive,
# Similar to an: class, rise, excess, force, closely,
# Similar to trading: some, do, higher, milk, attention,
#
# Average loss after epoch  7 :  7.423665680946448
# Similar to we: computer, moreover, signs, j.p., filters,
# Similar to been: simon, regulation, remaining, fannie, expected,
# Similar to also: compared, dumped, temporarily, club, climbing,
# Similar to of: renewal, paul, relatively, premium, minister,
# Similar to last: software, turf, business, point, intensity,
# Similar to u.s.: residential, depend, market, list, incentive,
# Similar to an: class, rise, excess, force, closely,
# Similar to trading: some, do, milk, higher, out,
#
# Average loss after epoch  8 :  6.300312975278268
# Similar to we: computer, moreover, signs, filters, j.p.,
# Similar to been: regulation, simon, remaining, fannie, expected,
# Similar to also: compared, dumped, club, temporarily, climbing,
# Similar to of: renewal, premium, paul, minister, relatively,
# Similar to last: software, turf, business, point, intensity,
# Similar to u.s.: residential, depend, market, list, incentive,
# Similar to an: class, rise, excess, force, closely,
# Similar to trading: some, do, milk, higher, attention,
#
# Average loss after epoch  9 :  5.325592666864395
# Similar to we: computer, moreover, signs, filters, j.p.,
# Similar to been: regulation, remaining, simon, fannie, expected,
# Similar to also: compared, dumped, club, temporarily, climbing,
# Similar to of: renewal, premium, minister, relatively, improved,
# Similar to last: software, turf, business, pharmaceutical, point,
# Similar to u.s.: residential, depend, list, market, incentive,
# Similar to an: class, rise, excess, force, closely,
# Similar to trading: some, do, milk, higher, attention,

# %%
n_epochs = 5
learning_rate = 0.9

n_batches = ptb.n_batches_wv()

optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

with tf.Session() as tfs:
    tfs.run(tf.global_variables_initializer())
    epoch_loss = 0
    for epoch in range(n_epochs):
        epoch_loss = 0
        ptb.reset_index()
        for step in range(n_batches):
            x_batch, y_batch = ptb.next_batch_sg()
            y_batch = nputil1.to2d(y_batch, unit_axis=1)
            feed_dict = {inputs: x_batch, outputs: y_batch}
            _, batch_loss = tfs.run([optimizer, loss], feed_dict=feed_dict)
            epoch_loss += batch_loss
        epoch_loss = epoch_loss / n_batches
        if epoch + 1 % 1000 == 0:
            print('epoch done: ', epoch)
    print('\nAverage loss after epoch ', epoch, ': ', epoch_loss)

    # print closest words to validation set at end of training

    similarity_scores = tfs.run(similarity)
    top_k = 5
    for i in range(valid_size):
        similar_words = (-similarity_scores[i, :]).argsort()[1:top_k + 1]
        similar_str = 'Similar to {0:}:'.format(ptb.id2word[x_valid[i]])
        for k in range(top_k):
            similar_str = '{0:} {1:},'.format(
                similar_str, ptb.id2word[similar_words[k]])
        print(similar_str)

    final_embeddings = tfs.run(normalized_embeddings)
# Out:
# Average loss after epoch  4999 :  2.740168252052405
# Similar to we: girlfriend, noted, markets, weeks, computer,
# Similar to been: precedent, bearing, dozen, duty-free, conference,
# Similar to also: introduce, index, saying, england, oversee,
# Similar to of: label, offers, lord, grace, netherlands,
# Similar to last: january, donoghue, inched, decision, feb.,
# Similar to u.s.: recognizing, netherlands, label, fannie, charts,
# Similar to an: believed, allen, rooted, paid, jet,
# Similar to trading: nasdaq, money, pioneer, analyst, task,

# %%
def plot_with_labels(low_dim_embs, labels):
    assert low_dim_embs.shape[0] >= len(
        labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(perplexity=30, n_components=2,
            init='pca', n_iter=5000, method='exact')
n_embeddings = 500
low_dim_embeddings = tsne.fit_transform(final_embeddings[:n_embeddings, :])
labels = [ptb.id2word[i] for i in range(n_embeddings)]

plot_with_labels(low_dim_embeddings, labels)

# %% [markdown]
# # Embeddings with Text8 data in TensorFlow

# %%
from datasetslib.text8 import Text8
text8 = Text8()
# downloads data, converts words to ids, converts files to a list of ids
text8.load_data()
print('Train:', text8.part['train'][0:5])
# print(text8.part['test'][0:5])
# print(text8.part['valid'][0:5])
print('Vocabulary Length = ', text8.vocab_len)
# Out:
# Already exists: /notebooks/Chapter08/datasets/text8/text8.zip
# Train: [5233 3083   11    5  194]
# Vocabulary Length =  253854

# %%
text8.skip_window = 2
text8.reset_index()
# in CBOW input is the context word and output is the target word
y_batch, x_batch = text8.next_batch_cbow()

print('The CBOW pairs : context,target')
for i in range(5 * text8.skip_window):
    print('(', [text8.id2word[x_i] for x_i in x_batch[i]],
          ',', y_batch[i], text8.id2word[y_batch[i]], ')')
# Out:
# The CBOW pairs : context,target
# ( ['anarchism', 'originated', 'a', 'term'] , 11 as )
# ( ['originated', 'as', 'term', 'of'] , 5 a )
# ( ['as', 'a', 'of', 'abuse'] , 194 term )
# ( ['a', 'term', 'abuse', 'first'] , 1 of )
# ( ['term', 'of', 'first', 'used'] , 3133 abuse )
# ( ['of', 'abuse', 'used', 'against'] , 45 first )
# ( ['abuse', 'first', 'against', 'early'] , 58 used )
# ( ['first', 'used', 'early', 'working'] , 155 against )
# ( ['used', 'against', 'working', 'class'] , 127 early )
# ( ['against', 'early', 'class', 'radicals'] , 741 working )

# %%
text8.skip_window = 2
text8.reset_index()
# in skip-gram input is the target word and output is the context word
x_batch, y_batch = text8.next_batch_sg()

print('The skip-gram pairs : target,context')
for i in range(5 * text8.skip_window):
    print('(', x_batch[i], text8.id2word[x_batch[i]],
          ',', y_batch[i], text8.id2word[y_batch[i]], ')')
# Out:
# The skip-gram pairs : target,context
# ( 11 as , 5233 anarchism )
# ( 11 as , 3083 originated )
# ( 11 as , 5 a )
# ( 11 as , 194 term )
# ( 5 a , 3083 originated )
# ( 5 a , 11 as )
# ( 5 a , 194 term )
# ( 5 a , 1 of )
# ( 194 term , 11 as )
# ( 194 term , 5 a )

# %%
valid_size = 8
x_valid = np.random.choice(valid_size * 10, valid_size, replace=False)
print('valid: ',x_valid)
# Out:
# valid:  [20 49 77  5 19  7 10 75]

# %%
batch_size = 128
embedding_size = 128  
n_negative_samples = 64
text8.skip_window=2

# %%
# clear the effects of previous sessions in the Jupyter Notebook
tf.reset_default_graph()

# %%
inputs = tf.placeholder(dtype=tf.int32, shape=[batch_size])
outputs = tf.placeholder(dtype=tf.int32, shape=[batch_size,1])
inputs_valid = tf.constant(x_valid, dtype=tf.int32)

# %%
# define embeddings matrix with vocab_len rows and embedding_size columns
# each row represents vectore representation or embedding of a word in the vocbulary

embed_matrix = tf.Variable(tf.random_uniform(shape=[text8.vocab_len, embedding_size], 
                                           minval = -1.0, 
                                           maxval = 1.0
                                          ),
                           name='embed_matrix'
                        )

# define the embedding lookup table
# provides the embeddings of the word ids in the input tensor
embed_ltable = tf.nn.embedding_lookup(embed_matrix, inputs)

# %%
# define noise-contrastive estimation (NCE) loss function

nce_w = tf.Variable(tf.truncated_normal(shape=[text8.vocab_len, embedding_size],
                                        stddev=1.0 / tf.sqrt(embedding_size*1.0)
                                       )
                   )
nce_b = tf.Variable(tf.zeros(shape=[text8.vocab_len]))

loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_w,
                                     biases=nce_b,
                                     inputs=embed_ltable,
                                     labels=outputs,
                                     num_sampled=n_negative_samples,
                                     num_classes=text8.vocab_len
                                    )
                     )

# %%
# Compute the cosine similarity between minibatch examples and all embeddings.
norm = tf.sqrt(tf.reduce_sum(tf.square(embed_matrix), 1, keep_dims=True))
normalized_embeddings = embed_matrix / norm
valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, inputs_valid)
similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
n_epochs = 5
learning_rate = 0.9
text8.reset_index()
n_batches = text8.n_batches_wv()

optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

with tf.Session() as tfs:
    tf.global_variables_initializer().run()

    for epoch in range(n_epochs):
        epoch_loss = 0
        for step in range(n_batches):
            x_batch, y_batch = text8.next_batch_sg()
            y_batch = nputil1.to2d(y_batch,unit_axis=1)
            feed_dict = {inputs: x_batch, outputs: y_batch}

            _, batch_loss = tfs.run([optimizer, loss], feed_dict=feed_dict)
            epoch_loss += batch_loss
        epoch_loss = epoch_loss / n_batches 

        print('\nAverage loss after epoch ', epoch, ': ', epoch_loss)
        
        # validating at end of every epoch

    
        similarity_scores = tfs.run(similarity)
        for i in range(valid_size):
            top_k = 5
            similar_words = (-similarity_scores[i, :]).argsort()[1:top_k + 1]
            similar_str = 'Similar to {0:}:'.format(text8.id2word[x_valid[i]])
            for k in range(top_k):
                similar_str = '{0:} {1:},'.format(similar_str, text8.id2word[similar_words[k]])
            print(similar_str)
        
    final_embeddings = tfs.run(normalized_embeddings)
# Out:
# Average loss after epoch  0 :  135.43318296621018
# Similar to four: nine, gland, and, exception, percent,
# Similar to all: execution, higher, eumetazoans, variance, contains,
# Similar to between: component, archaeological, appear, governor, albania,
# Similar to a: the, an, control, in, saul,
# Similar to that: brooke, urgell, for, romaniadanubedelta, photos,
# Similar to zero: albania, one, df, vivipara, basins,
# Similar to is: saul, americans, corals, frankenstein, rationality,
# Similar to no: greatest, denotes, feel, authority, thus,
#
# Average loss after epoch  1 :  70.70307991376022
# Similar to four: radiohead, nine, altenberg, zero, one,
# Similar to all: altenberg, expatriation, contains, higher, xyston,
# Similar to between: altenberg, component, ditko, gimme, landed,
# Similar to a: the, gyrus, chemicals, and, an,
# Similar to that: for, altenberg, ivan, to, psi,
# Similar to zero: nine, one, fam, two, three,
# Similar to is: basins, tessenow, phi, psi, diario,
# Similar to no: greatest, denotes, authority, frontal, execution,
#
# Average loss after epoch  2 :  48.89544546631208
# Similar to four: six, eight, three, nine, zero,
# Similar to all: altenberg, which, mathbf, in, a,
# Similar to between: abbates, altenberg, component, agatha, landed,
# Similar to a: the, or, abbates, gyrus, by,
# Similar to that: psi, ameriko, altenberg, in, for,
# Similar to zero: three, eight, nine, one, six,
# Similar to is: was, abbates, are, tessenow, basins,
# Similar to no: greatest, denotes, abbates, execution, francisco,
#
# Average loss after epoch  3 :  37.327481256671106
# Similar to four: six, nine, zero, three, two,
# Similar to all: agouti, and, in, which, arouet,
# Similar to between: abbates, altenberg, agouti, taber, agni,
# Similar to a: the, and, this, operatorname, abbates,
# Similar to that: agouti, operatorname, for, psi, this,
# Similar to zero: six, nine, eight, four, two,
# Similar to is: was, abbates, operatorname, are, acacia,
# Similar to no: denotes, greatest, dasyprocta, operatorname, abbates,
#
# Average loss after epoch  4 :  28.636682513471932
# Similar to four: three, six, eight, five, seven,
# Similar to all: agouti, dasyprocta, operatorname, that, arouet,
# Similar to between: and, altenberg, of, abbates, jewel,
# Similar to a: the, this, an, or, dasyprocta,
# Similar to that: this, agouti, which, operatorname, and,
# Similar to zero: five, two, six, eight, four,
# Similar to is: was, are, operatorname, dasyprocta, abbates,
# Similar to no: dasyprocta, operatorname, denotes, greatest, abbates,
#
# Average loss after epoch  5 :  22.099310618004772
# Similar to four: three, six, five, eight, seven,
# Similar to all: agouti, two, operatorname, dasyprocta, some,
# Similar to between: and, altenberg, abbates, agouti, of,
# Similar to a: the, operatorname, an, this, and,
# Similar to that: which, this, operatorname, and, agouti,
# Similar to zero: two, operatorname, five, eight, seven,
# Similar to is: was, are, operatorname, bpp, dasyprocta,
# Similar to no: operatorname, dasyprocta, abbates, a, execution,
#
# Average loss after epoch  6 :  19.813771362323923
# Similar to four: six, seven, five, eight, three,
# Similar to all: agouti, some, operatorname, dasyprocta, reuptake,
# Similar to between: altenberg, and, abbates, agouti, webshots,
# Similar to a: an, the, or, trinomial, reuptake,
# Similar to that: this, which, it, operatorname, agouti,
# Similar to zero: seven, five, two, eight, operatorname,
# Similar to is: was, are, operatorname, trinomial, dasyprocta,
# Similar to no: a, operatorname, dasyprocta, abbates, reuptake,
#
# Average loss after epoch  7 :  17.001003201898758
# Similar to four: five, six, two, three, seven,
# Similar to all: some, agouti, operatorname, or, and,
# Similar to between: of, in, and, altenberg, webshots,
# Similar to a: the, or, an, operatorname, dasyprocta,
# Similar to that: which, this, operatorname, it, agouti,
# Similar to zero: five, four, two, nine, eight,
# Similar to is: was, are, or, operatorname, has,
# Similar to no: a, it, that, operatorname, dasyprocta,
#
# Average loss after epoch  8 :  14.089463311887664
# Similar to four: five, six, three, two, seven,
# Similar to all: some, the, agouti, operatorname, dasyprocta,
# Similar to between: of, webshots, in, one, altenberg,
# Similar to a: the, this, or, which, an,
# Similar to that: which, this, it, but, operatorname,
# Similar to zero: five, four, six, eight, seven,
# Similar to is: was, are, has, operatorname, wattle,
# Similar to no: it, a, four, some, that,
#
# Average loss after epoch  9 :  13.008502964653635
# Similar to four: six, three, five, seven, one,
# Similar to all: some, these, operatorname, agouti, dasyprocta,
# Similar to between: and, in, recitative, of, with,
# Similar to a: the, an, this, albury, or,
# Similar to that: which, this, it, operatorname, and,
# Similar to zero: five, six, four, seven, three,
# Similar to is: was, are, operatorname, has, bpp,
# Similar to no: that, a, some, it, four,
#
# Average loss after epoch  10 :  11.514296781202187
# Similar to four: five, three, seven, six, eight,
# Similar to all: some, these, operatorname, dasyprocta, agouti,
# Similar to between: of, in, recitative, with, six,
# Similar to a: the, an, this, or, albury,
# Similar to that: which, this, it, but, however,
# Similar to zero: five, eight, seven, six, three,
# Similar to is: was, are, has, operatorname, bpp,
# Similar to no: some, it, this, battledores, a,
#
# Average loss after epoch  11 :  10.59063691390745
# Similar to four: three, six, seven, five, eight,
# Similar to all: some, these, maritimequest, or, operatorname,
# Similar to between: in, with, recitative, and, on,
# Similar to a: the, this, an, recitative, reuptake,
# Similar to that: which, this, it, but, however,
# Similar to zero: seven, eight, five, six, three,
# Similar to is: was, are, has, operatorname, or,
# Similar to no: a, which, it, maritimequest, four,
#
# Average loss after epoch  12 :  9.675273453984907
# Similar to four: three, six, seven, five, two,
# Similar to all: some, maritimequest, these, operatorname, many,
# Similar to between: with, in, from, and, recitative,
# Similar to a: the, this, an, which, dasyprocta,
# Similar to that: which, this, it, but, however,
# Similar to zero: six, seven, four, five, nine,
# Similar to is: was, are, has, were, operatorname,
# Similar to no: a, this, which, maritimequest, some,
#
# Average loss after epoch  13 :  9.50218194164054
# Similar to four: six, seven, five, eight, three,
# Similar to all: some, these, maritimequest, or, operatorname,
# Similar to between: in, with, from, and, recitative,
# Similar to a: the, this, an, which, albury,
# Similar to that: which, this, but, it, however,
# Similar to zero: six, five, eight, three, four,
# Similar to is: was, are, has, operatorname, wct,
# Similar to no: a, maritimequest, some, that, this,
#
# Average loss after epoch  14 :  9.033581123259474
# Similar to four: seven, five, six, three, eight,
# Similar to all: some, these, michelob, maritimequest, operatorname,
# Similar to between: in, with, and, of, from,
# Similar to a: the, an, this, reuptake, recitative,
# Similar to that: which, this, but, however, it,
# Similar to zero: five, six, three, eight, seven,
# Similar to is: was, are, has, operatorname, wct,
# Similar to no: a, three, this, maritimequest, pulau,
#
# Average loss after epoch  15 :  8.180744711521955
# Similar to four: three, six, seven, five, eight,
# Similar to all: some, these, maritimequest, michelob, other,
# Similar to between: with, in, of, or, recitative,
# Similar to a: the, an, this, albury, reuptake,
# Similar to that: which, this, however, but, it,
# Similar to zero: five, three, four, seven, six,
# Similar to is: was, are, operatorname, wct, has,
# Similar to no: three, maritimequest, that, but, pulau,
#
# Average loss after epoch  16 :  8.265362156982441
# Similar to four: three, seven, five, six, eight,
# Similar to all: some, these, many, michelob, maritimequest,
# Similar to between: with, in, of, or, and,
# Similar to a: the, this, an, albury, or,
# Similar to that: which, this, but, however, it,
# Similar to zero: five, six, seven, four, eight,
# Similar to is: was, are, wct, operatorname, or,
# Similar to no: but, maritimequest, pulau, four, which,
#
# Average loss after epoch  17 :  8.148020626947968
# Similar to four: three, five, six, seven, eight,
# Similar to all: some, these, many, maritimequest, michelob,
# Similar to between: with, in, or, from, four,
# Similar to a: the, this, an, or, reuptake,
# Similar to that: which, this, however, but, when,
# Similar to zero: five, six, eight, seven, four,
# Similar to is: was, are, has, operatorname, or,
# Similar to no: but, a, four, maritimequest, pulau,
#
# Average loss after epoch  18 :  7.500664049997152
# Similar to four: three, six, five, seven, eight,
# Similar to all: some, these, many, both, maritimequest,
# Similar to between: with, in, from, of, four,
# Similar to a: the, this, an, ffffcc, albury,
# Similar to that: which, this, however, but, when,
# Similar to zero: five, six, four, seven, eight,
# Similar to is: was, are, has, operatorname, wct,
# Similar to no: a, but, which, that, maritimequest,
#
# Average loss after epoch  19 :  8.259224027981375
# Similar to four: five, six, three, seven, two,
# Similar to all: some, these, many, both, other,
# Similar to between: with, of, from, including, in,
# Similar to a: the, or, an, this, albury,
# Similar to that: which, however, this, when, but,
# Similar to zero: four, five, six, seven, two,
# Similar to is: was, are, has, operatorname, wct,
# Similar to no: but, a, maritimequest, pulau, which,
#
# Average loss after epoch  20 :  7.717444800963861
# Similar to four: six, five, three, seven, eight,
# Similar to all: some, these, both, many, other,
# Similar to between: with, in, including, from, of,
# Similar to a: the, or, any, this, an,
# Similar to that: which, however, this, but, when,
# Similar to zero: five, six, four, three, seven,
# Similar to is: was, are, has, wct, operatorname,
# Similar to no: but, pulau, maritimequest, jessops, a,
#
# Average loss after epoch  21 :  7.5578983277909035
# Similar to four: three, five, six, seven, eight,
# Similar to all: some, these, many, both, other,
# Similar to between: with, in, including, from, or,
# Similar to a: the, any, this, or, albury,
# Similar to that: which, however, this, but, when,
# Similar to zero: five, four, six, seven, eight,
# Similar to is: was, are, operatorname, has, wct,
# Similar to no: but, which, pulau, a, only,
#
# Average loss after epoch  22 :  7.393038898150366
# Similar to four: five, three, seven, six, zero,
# Similar to all: some, these, many, both, other,
# Similar to between: with, including, of, in, or,
# Similar to a: the, any, this, or, another,
# Similar to that: which, however, this, but, michelob,
# Similar to zero: five, seven, four, six, three,
# Similar to is: was, has, operatorname, are, wct,
# Similar to no: a, but, only, pulau, maritimequest,
#
# Average loss after epoch  23 :  7.1426513159870195
# Similar to four: three, five, six, seven, eight,
# Similar to all: some, both, many, these, maritimequest,
# Similar to between: with, in, including, from, stenella,
# Similar to a: the, any, this, reuptake, another,
# Similar to that: which, however, this, but, when,
# Similar to zero: five, seven, eight, six, four,
# Similar to is: was, are, has, operatorname, being,
# Similar to no: a, that, which, but, this,
#
# Average loss after epoch  24 :  6.971269066818904
# Similar to four: three, five, seven, eight, six,
# Similar to all: some, many, these, both, other,
# Similar to between: with, in, including, seven, stenella,
# Similar to a: the, any, this, another, or,
# Similar to that: which, however, this, but, when,
# Similar to zero: eight, four, five, nine, six,
# Similar to is: was, are, has, wct, stenella,
# Similar to no: a, pulau, but, that, which,
#
# Average loss after epoch  25 :  7.164597276329573
# Similar to four: three, five, seven, six, eight,
# Similar to all: some, many, both, these, maritimequest,
# Similar to between: with, in, including, from, stenella,
# Similar to a: the, any, cra, another, this,
# Similar to that: which, however, this, but, when,
# Similar to zero: five, three, eight, four, two,
# Similar to is: was, are, has, operatorname, stenella,
# Similar to no: this, any, only, but, that,
#
# Average loss after epoch  26 :  7.003876384278168
# Similar to four: three, five, seven, six, eight,
# Similar to all: some, many, these, both, other,
# Similar to between: with, in, including, stenella, or,
# Similar to a: the, any, this, another, albury,
# Similar to that: which, however, this, but, when,
# Similar to zero: five, eight, seven, four, six,
# Similar to is: was, are, has, operatorname, wct,
# Similar to no: this, a, any, three, but,
#
# Average loss after epoch  27 :  7.121929730571885
# Similar to four: five, three, six, seven, eight,
# Similar to all: some, these, both, many, other,
# Similar to between: with, in, including, into, within,
# Similar to a: the, any, another, each, or,
# Similar to that: which, however, but, this, when,
# Similar to zero: seven, eight, six, five, nine,
# Similar to is: was, are, being, stenella, operatorname,
# Similar to no: any, only, this, but, a,
#
# Average loss after epoch  28 :  6.567529837981776
# Similar to four: five, three, six, seven, eight,
# Similar to all: some, many, both, these, other,
# Similar to between: with, in, including, into, within,
# Similar to a: the, another, any, this, albury,
# Similar to that: which, however, this, but, when,
# Similar to zero: five, six, operatorname, four, seven,
# Similar to is: was, are, stenella, being, operatorname,
# Similar to no: any, this, only, a, however,
#
# Average loss after epoch  29 :  6.951580547378692
# Similar to four: five, six, three, seven, eight,
# Similar to all: some, many, these, both, other,
# Similar to between: with, including, in, within, stenella,
# Similar to a: the, another, any, this, an,
# Similar to that: which, however, when, this, but,
# Similar to zero: four, six, seven, five, three,
# Similar to is: was, are, being, operatorname, has,
# Similar to no: any, a, however, only, this,
#
# Average loss after epoch  30 :  6.946033118922964
# Similar to four: five, three, six, seven, eight,
# Similar to all: some, many, these, both, other,
# Similar to between: with, in, including, within, from,
# Similar to a: any, the, another, albury, cra,
# Similar to that: which, however, when, this, but,
# Similar to zero: four, five, six, three, seven,
# Similar to is: was, are, has, operatorname, wct,
# Similar to no: any, only, this, a, however,
#
# Average loss after epoch  31 :  7.0626841670806755
# Similar to four: five, three, six, seven, eight,
# Similar to all: some, many, these, both, other,
# Similar to between: with, in, of, within, including,
# Similar to a: the, any, another, albury, an,
# Similar to that: which, however, when, this, but,
# Similar to zero: six, five, four, three, seven,
# Similar to is: was, are, has, stenella, being,
# Similar to no: any, a, only, also, maritimequest,
#
# Average loss after epoch  32 :  7.148966643194688
# Similar to four: five, three, six, seven, eight,
# Similar to all: some, many, these, both, other,
# Similar to between: with, in, including, within, from,
# Similar to a: another, the, any, this, each,
# Similar to that: which, however, when, but, although,
# Similar to zero: five, six, four, eight, three,
# Similar to is: was, are, being, has, stenella,
# Similar to no: any, a, maritimequest, only, pulau,
#
# Average loss after epoch  33 :  6.627283450484697
# Similar to four: three, five, six, seven, eight,
# Similar to all: some, many, both, these, other,
# Similar to between: with, including, in, within, through,
# Similar to a: the, any, another, albury, each,
# Similar to that: which, however, this, when, but,
# Similar to zero: seven, five, six, eight, nine,
# Similar to is: was, are, being, has, stenella,
# Similar to no: any, a, only, jessops, maritimequest,
#
# Average loss after epoch  34 :  6.572954220568599
# Similar to four: five, three, six, two, seven,
# Similar to all: some, many, both, these, other,
# Similar to between: with, in, including, within, from,
# Similar to a: the, another, any, no, each,
# Similar to that: which, however, but, this, when,
# Similar to zero: five, six, albury, michelob, operatorname,
# Similar to is: was, are, has, being, stenella,
# Similar to no: any, a, only, jessops, maritimequest,
#
# Average loss after epoch  35 :  7.938172353363013
# Similar to four: five, three, six, seven, eight,
# Similar to all: some, many, both, these, several,
# Similar to between: with, within, including, in, among,
# Similar to a: the, another, any, dasyprocta, each,
# Similar to that: which, however, but, when, this,
# Similar to zero: five, six, eight, three, two,
# Similar to is: was, has, are, being, stenella,
# Similar to no: jessops, any, pulau, maritimequest, only,
# Average loss after epoch  36 :  6.492726818846743
# Similar to four: five, three, six, seven, two,
# Similar to all: both, some, many, these, several,
# Similar to between: with, in, within, including, among,
# Similar to a: the, another, any, each, albury,
# Similar to that: which, however, when, this, but,
# Similar to zero: five, eight, seven, two, three,
# Similar to is: was, are, stenella, being, has,
# Similar to no: any, this, only, jessops, which,
#
# Average loss after epoch  37 :  6.151112422099092
# Similar to four: five, three, seven, six, eight,
# Similar to all: both, many, some, these, several,
# Similar to between: with, in, within, from, including,
# Similar to a: another, any, the, each, dasyprocta,
# Similar to that: which, however, when, this, but,
# Similar to zero: three, seven, five, two, four,
# Similar to is: was, are, being, became, operatorname,
# Similar to no: any, only, this, however, jessops,
#
# Average loss after epoch  38 :  6.504756984630139
# Similar to four: five, six, three, seven, eight,
# Similar to all: both, many, some, these, other,
# Similar to between: with, within, among, in, from,
# Similar to a: another, the, any, or, each,
# Similar to that: which, however, when, this, because,
# Similar to zero: six, five, four, seven, three,
# Similar to is: was, are, being, became, stenella,
# Similar to no: only, any, this, still, however,
#
# Average loss after epoch  39 :  6.504431634690506
# Similar to four: five, three, six, eight, seven,
# Similar to all: both, some, many, these, several,
# Similar to between: with, within, in, through, among,
# Similar to a: another, the, any, this, albury,
# Similar to that: which, however, when, because, what,
# Similar to zero: five, six, seven, four, eight,
# Similar to is: was, are, being, became, wct,
# Similar to no: any, only, this, still, little,
#
# Average loss after epoch  40 :  6.602814567461798
# Similar to four: three, five, six, seven, eight,
# Similar to all: both, many, some, these, several,
# Similar to between: with, within, in, through, among,
# Similar to a: another, the, any, albury, or,
# Similar to that: which, however, when, what, although,
# Similar to zero: five, three, six, seven, four,
# Similar to is: was, are, became, has, being,
# Similar to no: a, only, any, this, still,
#
# Average loss after epoch  41 :  6.087001517693081
# Similar to four: six, three, five, seven, eight,
# Similar to all: both, many, some, these, several,
# Similar to between: with, within, in, through, among,
# Similar to a: another, any, the, this, each,
# Similar to that: which, however, when, because, what,
# Similar to zero: six, seven, five, eight, four,
# Similar to is: was, are, has, being, became,
# Similar to no: any, only, a, still, even,
#
# Average loss after epoch  42 :  6.135993715614246
# Similar to four: six, five, three, eight, seven,
# Similar to all: both, many, some, several, these,
# Similar to between: with, within, through, among, in,
# Similar to a: another, the, any, albury, cra,
# Similar to that: which, however, when, this, what,
# Similar to zero: five, seven, eight, three, six,
# Similar to is: was, are, wct, became, being,
# Similar to no: any, only, still, even, little,
#
# Average loss after epoch  43 :  6.197803742691416
# Similar to four: five, six, three, seven, eight,
# Similar to all: both, many, some, these, several,
# Similar to between: with, within, through, in, among,
# Similar to a: another, any, the, each, this,
# Similar to that: which, however, when, although, this,
# Similar to zero: five, seven, six, four, three,
# Similar to is: was, are, being, became, wct,
# Similar to no: any, still, little, however, only,
#
# Average loss after epoch  44 :  6.063628883747759
# Similar to four: five, six, three, eight, seven,
# Similar to all: both, some, many, these, various,
# Similar to between: with, within, through, in, among,
# Similar to a: another, the, any, or, this,
# Similar to that: which, however, when, although, this,
# Similar to zero: five, six, four, three, eight,
# Similar to is: was, are, became, being, wct,
# Similar to no: any, still, only, a, little,
#
# Average loss after epoch  45 :  6.265191629160791
# Similar to four: five, three, six, eight, seven,
# Similar to all: both, some, many, these, various,
# Similar to between: with, within, through, among, in,
# Similar to a: another, any, the, albury, piovra,
# Similar to that: which, however, when, although, because,
# Similar to zero: six, five, four, seven, eight,
# Similar to is: was, are, wct, being, became,
# Similar to no: any, a, still, little, only,
#
# Average loss after epoch  46 :  6.107208195684898
# Similar to four: six, three, five, seven, eight,
# Similar to all: both, some, many, these, various,
# Similar to between: with, within, through, among, in,
# Similar to a: another, the, any, each, albury,
# Similar to that: which, however, when, if, although,
# Similar to zero: five, eight, six, seven, four,
# Similar to is: was, are, being, became, has,
# Similar to no: any, only, little, still, however,
#
# Average loss after epoch  47 :  6.150399831107213
# Similar to four: three, michelob, six, five, recitative,
# Similar to all: both, some, many, these, several,
# Similar to between: with, within, through, among, in,
# Similar to a: another, any, the, albury, reuptake,
# Similar to that: which, however, when, where, this,
# Similar to zero: michelob, six, eight, operatorname, five,
# Similar to is: was, are, being, became, stenella,
# Similar to no: only, however, any, still, little,
#
# Average loss after epoch  48 :  6.306281916492826
# Similar to four: five, three, six, seven, eight,
# Similar to all: both, some, many, these, various,
# Similar to between: with, within, among, through, in,
# Similar to a: another, the, any, this, piovra,
# Similar to that: which, however, when, although, if,
# Similar to zero: five, seven, eight, four, six,
# Similar to is: was, are, operatorname, became, being,
# Similar to no: any, only, still, however, little,
#
# Average loss after epoch  49 :  5.770455599282044
# Similar to four: five, six, three, seven, eight,
# Similar to all: both, some, many, these, various,
# Similar to between: within, with, in, through, among,
# Similar to a: another, the, any, this, albury,
# Similar to that: which, however, although, when, because,
# Similar to zero: five, eight, six, seven, three,
# Similar to is: was, are, became, being, operatorname,
# Similar to no: any, only, little, still, however,

# %%
def plot_with_words(low_dim_embeddings, words):
  assert low_dim_embeddings.shape[0] >= len(words), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, words in enumerate(words):
    x, y = low_dim_embeddings[i, :]
    plt.scatter(x, y)
    plt.annotate(words,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')
  plt.show()


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
n_embeddings = 300
low_dim_embeddings = tsne.fit_transform(final_embeddings[:n_embeddings, :])
words = [text8.id2word[i] for i in range(n_embeddings)]
  
plot_with_words(low_dim_embeddings, words)

# %% [markdown]
# # skip-gram model with Keras

# %%
from keras.models import Model
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.layers import Input, Dense, Reshape, Dot, merge
import keras
# Out:
# Using TensorFlow backend.

# %%
# reset the jupyter buffers
tf.reset_default_graph()
keras.backend.clear_session()

# %%
valid_size = 8
x_valid = np.random.choice(valid_size * 10, valid_size, replace=False)
print('valid: ',x_valid)
# Out:
# valid:  [55 49 64 69 53 23 32 42]

# %%
embedding_size = 512  
n_negative_samples = 64
ptb.skip_window=2

# %%
sample_table = sequence.make_sampling_table(ptb.vocab_len)
pairs, labels= sequence.skipgrams(ptb.part['train'],
                        ptb.vocab_len,
                        window_size=ptb.skip_window,
                        sampling_table=sample_table)

# %%
print('The skip-gram pairs : target,context')
for i in range(5 * ptb.skip_window):
    print(['{} {}'.format(id,ptb.id2word[id]) for id in pairs[i]],':',labels[i])
# Out:
# The skip-gram pairs : target,context
# ['6733 adult', '1074 tons'] : 0
# ['2591 claimed', '4476 full-year'] : 0
# ['21 million', '292 already'] : 0
# ['5299 assumes', '4696 expertise'] : 0
# ['3160 category', '7 in'] : 1
# ['2107 singapore', '490 proposal'] : 0
# ['1767 professional', '4216 visible'] : 0
# ['1939 meetings', '2979 writer'] : 0
# ['4 of', '5781 premier'] : 0
# ['2710 aetna', '2240 technologies'] : 0

# %%
x,y=zip(*pairs)
x=np.array(x,dtype=np.int32)
x=nputil1.to2d(x,unit_axis=1)
y=np.array(y,dtype=np.int32)
y=nputil1.to2d(y,unit_axis=1)
labels=np.array(labels,dtype=np.int32)
labels=nputil1.to2d(labels,unit_axis=1)

# %%
# build the target word model
target_in = Input(shape=(1,),name='target_in')
target = Embedding(ptb.vocab_len,embedding_size,input_length=1,name='target_em')(target_in)
target = Reshape((embedding_size,1),name='target_re')(target)

# build the context word model
context_in = Input((1,),name='context_in')
context = Embedding(ptb.vocab_len,embedding_size,input_length=1,name='context_em')(context_in)
context = Reshape((embedding_size,1),name='context_re')(context)

# merge the models with the dot product to check for similarity and add sigmoid layer
output = Dot(axes=1,name='output_dot')([target,context])
output = Reshape((1,),name='output_re')(output)
output = Dense(1,activation='sigmoid',name='output_sig')(output)

# create the functional model for finding word vectors
model = Model(inputs=[target_in,context_in],outputs=output)
model.compile(loss='binary_crossentropy', optimizer='adam')

# merge the models and create model to check for cosine similarity
similarity = Dot(axes=0,normalize=True,name='sim_dot')([target,context])
similarity_model = Model(inputs=[target_in,context_in],outputs=similarity)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# target_in (InputLayer)          (None, 1)            0
# __________________________________________________________________________________________________
# context_in (InputLayer)         (None, 1)            0
# __________________________________________________________________________________________________
# target_em (Embedding)           (None, 1, 512)       5120000     target_in[0][0]
# __________________________________________________________________________________________________
# context_em (Embedding)          (None, 1, 512)       5120000     context_in[0][0]
# __________________________________________________________________________________________________
# target_re (Reshape)             (None, 512, 1)       0           target_em[0][0]
# __________________________________________________________________________________________________
# context_re (Reshape)            (None, 512, 1)       0           context_em[0][0]
# __________________________________________________________________________________________________
# output_dot (Dot)                (None, 1, 1)         0           target_re[0][0]
#                                                                  context_re[0][0]
# __________________________________________________________________________________________________
# output_re (Reshape)             (None, 1)            0           output_dot[0][0]
# __________________________________________________________________________________________________
# output_sig (Dense)              (None, 1)            2           output_re[0][0]
# ==================================================================================================
# Total params: 10,240,002
# Trainable params: 10,240,002
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# train the model
n_epochs = 5
batch_size = 1024
model.fit([x,y],labels,batch_size=batch_size, epochs=n_epochs)
# Out:
# Epoch 1/5
# 1095780/1095780 [==============================] - 95s 87us/step - loss: 0.4543
# Epoch 2/5
# 1095780/1095780 [==============================] - 92s 84us/step - loss: 0.2874
# Epoch 3/5
# 1095780/1095780 [==============================] - 92s 84us/step - loss: 0.1123
# Epoch 4/5
# 1095780/1095780 [==============================] - 92s 84us/step - loss: 0.0288
# Epoch 5/5
# 1095780/1095780 [==============================] - 91s 83us/step - loss: 0.0215

# %%
# print closest words to validation set at end of training
top_k = 5  
y_val = np.arange(ptb.vocab_len, dtype=np.int32)
y_val = nputil1.to2d(y_val,unit_axis=1)
for i in range(valid_size):
    x_val = np.full(shape=(ptb.vocab_len,1),fill_value=x_valid[i], dtype=np.int32)
    similarity_scores = similarity_model.predict([x_val,y_val])
    similarity_scores=similarity_scores.flatten()
    similar_words = (-similarity_scores).argsort()[1:top_k + 1]
    similar_str = 'Similar to {0:}:'.format(ptb.id2word[x_valid[i]])
    for k in range(top_k):
        similar_str = '{0:} {1:},'.format(similar_str, ptb.id2word[similar_words[k]])
    print(similar_str)
# Out:
# Similar to than: more, years, rather, have, as,
# Similar to his: affidavit, <unk>, soon, even, a,
# Similar to we: <eos>, is, we, so, that,
# Similar to last: week, month, N, 's, million,
# Similar to u.s.: is, N, will, dipped, from,
# Similar to mr.: some, with, bush, said, says,
# Similar to n't: we, it, does, that, did,
# Similar to would: be, i, mentality, taxpayers, one,

# %% [markdown]
# # word2vec or embeddings visualisation using TensorBoard

# %%
# clear the effects of previous sessions in the Jupyter Notebook
tf.reset_default_graph()

# %%
from tensorflow.contrib.tensorboard.plugins import projector

batch_size = 128
embedding_size = 128  
n_negative_samples = 64
ptb.skip_window=2

inputs = tf.placeholder(dtype=tf.int32, shape=[batch_size],name='inputs')
outputs = tf.placeholder(dtype=tf.int32, shape=[batch_size,1],name='outputs')
inputs_valid = tf.constant(x_valid, dtype=tf.int32,name='inputs_valid')

# define embeddings matrix with vocab_len rows and embedding_size columns
# each row represents vectore representation or embedding of a word in the vocbulary

embed_matrix = tf.Variable(tf.random_uniform(shape=[ptb.vocab_len, embedding_size], 
                                           minval = -1.0, 
                                           maxval = 1.0
                                          ),
                           name='embed_matrix'
                        )
# define the embedding lookup table
# provides the embeddings of the word ids in the input tensor
embed_ltable = tf.nn.embedding_lookup(embed_matrix, inputs)

# define noise-contrastive estimation (NCE) loss layer

nce_w = tf.Variable(tf.truncated_normal(shape=[ptb.vocab_len, embedding_size],
                                        stddev=1.0 / tf.sqrt(embedding_size*1.0)
                                       ),
                    name='nce_w'
                   )
nce_b = tf.Variable(tf.zeros(shape=[ptb.vocab_len]), name='nce_b')

loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_w,
                                     biases=nce_b,
                                     inputs=embed_ltable,
                                     labels=outputs,
                                     num_sampled=n_negative_samples,
                                     num_classes=ptb.vocab_len
                                    ),
                      name='nce_loss'
                     )

# Compute the cosine similarity between validation set samples and all embeddings.
norm = tf.sqrt(tf.reduce_sum(tf.square(embed_matrix), 1, keep_dims=True),name='norm')
normalized_embeddings = tf.divide(embed_matrix,norm,name='normalized_embeddings')
embed_valid = tf.nn.embedding_lookup(normalized_embeddings, inputs_valid)
similarity = tf.matmul(embed_valid, normalized_embeddings, transpose_b=True, name='similarity')

n_epochs = 1
learning_rate = 0.9

n_batches = ptb.n_batches_wv()

optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

log_dir = 'tflogs'

# save the vocabulary
vocabfile = 'word2id.tsv'
ptb.save_word2id(os.path.join(log_dir, vocabfile))

# create summary variable
tf.summary.scalar('epoch_loss_scalar',epoch_loss)
tf.summary.histogram('epoch_loss_histogram',epoch_loss)

merged = tf.summary.merge_all()
    

with tf.Session() as tfs:

    saver = tf.train.Saver()
    
    # Declare projector config
    config=projector.ProjectorConfig()

    # add embedding variable to the config
    embed_conf1 = config.embeddings.add()
    embed_conf1.tensor_name = embed_matrix.name
    embed_conf1.metadata_path = vocabfile
    
    
    file_writer = tf.summary.FileWriter(log_dir,tfs.graph)

    # save embeddings config that TensorBoard will read and visualize
    projector.visualize_embeddings(file_writer,config)
    


    tf.global_variables_initializer().run()

    for epoch in range(n_epochs):
        epoch_loss = 0
        ptb.reset_index()
        for step in range(n_batches):
            x_batch, y_batch = ptb.next_batch_sg()
            y_batch = nputil1.to2d(y_batch,unit_axis=1)
            feed_dict = {inputs: x_batch, outputs: y_batch}
            summary, _, batch_loss = tfs.run([merged, optimizer, loss], feed_dict=feed_dict)
            epoch_loss += batch_loss
            saver.save(tfs, 
                       os.path.join(log_dir, 'model.ckpt'), 
                       global_step = epoch * n_batches + step)
        epoch_loss = epoch_loss / n_batches
        file_writer.add_summary(summary,global_step = epoch * n_batches + step)

        print('\nAverage loss after epoch ', epoch, ': ', epoch_loss)
        
        # print closest words to validation set at end of every epoch

        similarity_scores = tfs.run(similarity)
        top_k = 5  
        for i in range(valid_size):
            similar_words = (-similarity_scores[i, :]).argsort()[1:top_k + 1]
            similar_str = 'Similar to {0:}:'.format(ptb.id2word[x_valid[i]])
            for k in range(top_k):
                similar_str = '{0:} {1:},'.format(similar_str, ptb.id2word[similar_words[k]])
            print(similar_str)
        
    final_embeddings = tfs.run(normalized_embeddings)
# Out:
# WARNING:tensorflow:From <ipython-input-7-7ac837f90e2b>:45: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7ac837f90e2b> in <module>
#      62
#      63 # create summary variable
# ---> 64 tf.summary.scalar('epoch_loss_scalar',epoch_loss)
#      65 tf.summary.histogram('epoch_loss_histogram',epoch_loss)
#      66
#
# NameError: name 'epoch_loss' is not defined

# %% [markdown]
# # The word2id and id2word code explained

# %%
import collections
counter=collections.Counter(['a','b','a','c','a','c'])
l=lambda x: (-x[1],x[0])
count_pairs=sorted(counter.items(),key=l)
words,_=list(zip(*count_pairs))
print(words)

word2id = dict(zip(words, range(len(words))))
print(word2id)
id2word = dict(zip(word2id.values(), word2id.keys()))
print(id2word)
